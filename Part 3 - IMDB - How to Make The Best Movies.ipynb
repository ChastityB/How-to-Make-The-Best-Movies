# %% [markdown]
# # How to Make The Best Movies Part 3

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy.types import *
from sqlalchemy_utils import create_database, database_exists

# %% [markdown]
# ## Normalize Genre:
#
# * convert the single string of genres from title basics into 2 new tables
#     * title genres: with the columns:
#         * tconst
#         * genre_id
#     * genres:
#         * genre_id
#         * genre_name

# %% [markdown]
# ### title_basics

# %%
#load file and disply rows
df_title_basics = pd.read_csv('Data/title_basics.csv.gz')

# %%
#create a col with a list of genres
df_title_basics['genres_split'] = df_title_basics['genres'].str.split(',')
df_title_basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 84503  tt9914942     movie                             Life Without Sara Amat
# 84504  tt9915872     movie                               The Last White Witch
# 84505  tt9916170     movie                                      The Rehearsal
# 84506  tt9916190     movie                                          Safeguard
# 84507  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                           Crime and Punishment        0       2002      NaN
# ...                                          ...      ...        ...      ...
# 84503                 La vida sense la Sara Amat        0       2019      NaN
# 84504                  My Girlfriend is a Wizard        0       2019      NaN
# 84505                                   O Ensaio        0       2019      NaN
# 84506                                  Safeguard        0       2020      NaN
# 84507                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 84503              74                      Drama
# 84504              97       Comedy,Drama,Fantasy
# 84505              51                      Drama
# 84506              95  Action,Adventure,Thriller
# 84507              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 84503                        [Drama]
# 84504       [Comedy, Drama, Fantasy]
# 84505                        [Drama]
# 84506  [Action, Adventure, Thriller]
# 84507               [Drama, History]
#
# [84508 rows x 10 columns]

# %%
#separate list of genres into new rows
exploded_genres = df_title_basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 84506  tt9916190     movie                                          Safeguard
# 84506  tt9916190     movie                                          Safeguard
# 84506  tt9916190     movie                                          Safeguard
# 84507  tt9916362     movie                                              Coven
# 84507  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 84506                                  Safeguard        0       2020      NaN
# 84506                                  Safeguard        0       2020      NaN
# 84506                                  Safeguard        0       2020      NaN
# 84507                                   Akelarre        0       2020      NaN
# 84507                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 84506              95  Action,Adventure,Thriller       Action
# 84506              95  Action,Adventure,Thriller    Adventure
# 84506              95  Action,Adventure,Thriller     Thriller
# 84507              92              Drama,History        Drama
# 84507              92              Drama,History      History
#
# [157899 rows x 10 columns]

# %%
#display unique genres
unique_genres = sorted(exploded_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
#save just tconst and genres_split as new df
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
#make a genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
#make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)
title_genres = title_genres.drop(columns='genres_split')
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0069049         7

# %%
#manually make dataframe with named cols from the .keyd and .values
genre_lookup = pd.DataFrame({'genre_name': genre_map.keys(),
                            'genre_id': genre_map.values()})
genre_lookup.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# ### Title Crew

# %%
df_title_crew = pd.read_csv('Data/title_crew.csv.gz')
df_title_crew.head()
# Out:
#       tconst            directors writers
# 0  tt0000001            nm0005690     NaN
# 1  tt0000002            nm0721526     NaN
# 2  tt0000005            nm0005690     NaN
# 3  tt0000006            nm0005690     NaN
# 4  tt0000007  nm0005690,nm0374658     NaN

# %%
#create a col with a list of writers
writers = df_title_crew['writers'].str.split(',')
writers
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#                                 ...
# 1318611                                       [nm0103043]
# 1318612                                       [nm7311709]
# 1318613                                      [nm10538223]
# 1318614                                      [nm10538639]
# 1318615    [nm6687687, nm10538642, nm9641593, nm10538643]
# Name: writers, Length: 1318616, dtype: object

# %%
#separate list of writers into new row groups
exploded_writers = writers.explode()
exploded_writers
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#               ...
# 1318614    nm10538639
# 1318615     nm6687687
# 1318615    nm10538642
# 1318615     nm9641593
# 1318615    nm10538643
# Name: writers, Length: 2396728, dtype: object

# %%
#display a unique list of writers
unique_writers = exploded_writers.unique()
unique_writers
# Out:
# array([nan, 'nm0085156', 'nm0410331', ..., 'nm10538642', 'nm9641593',
#        'nm10538643'], dtype=object)

# %%
#create a col with a list of directors
directors = df_title_crew['directors'].str.split(',')
directors
# Out:
# 0                     [nm0005690]
# 1                     [nm0721526]
# 2                     [nm0005690]
# 3                     [nm0005690]
# 4          [nm0005690, nm0374658]
#                     ...
# 1318611               [nm0232902]
# 1318612                       NaN
# 1318613               [nm3038589]
# 1318614              [nm10538639]
# 1318615               [nm6685122]
# Name: directors, Length: 1318616, dtype: object

# %%
#separate list of directors into new row groups
exploded_directors = directors.explode()
exploded_directors
# Out:
# 0           nm0005690
# 1           nm0721526
# 2           nm0005690
# 3           nm0005690
# 4           nm0005690
#               ...
# 1318611     nm0232902
# 1318612           NaN
# 1318613     nm3038589
# 1318614    nm10538639
# 1318615     nm6685122
# Name: directors, Length: 1565873, dtype: object

# %%
#display a unique list of directors
unique_directors = exploded_directors.unique()
unique_directors
# Out:
# array(['nm0005690', 'nm0721526', 'nm0374658', ..., 'nm10538028',
#        'nm5412267', 'nm10538639'], dtype=object)

# %%
#create a unique list for just nconsts from both the writers and directors
unique_nconst = unique_writers.tolist()
unique_nconst.extend(unique_directors.tolist())
unique_nconst = np.unique(unique_nconst)

# %%
#check out the list
unique_nconst
# Out:
# array(['nan', 'nm0000004', 'nm0000005', ..., 'nm9993708', 'nm9993709',
#        'nm9993713'], dtype='<U32')

# %%
#create melted dataframes
title_crew_melt = pd.melt(df_title_crew, id_vars='tconst', 
                         var_name='role', value_name='nconst')
title_crew_melt['role'] = title_crew_melt['role'].replace({'directors':'director',
                                'writers':'writer'})
title_crew_melt
# Out:
#             tconst      role                                     nconst
# 0        tt0000001  director                                  nm0005690
# 1        tt0000002  director                                  nm0721526
# 2        tt0000005  director                                  nm0005690
# 3        tt0000006  director                                  nm0005690
# 4        tt0000007  director                        nm0005690,nm0374658
# ...            ...       ...                                        ...
# 2637227  tt9916560    writer                                  nm0103043
# 2637228  tt9916620    writer                                  nm7311709
# 2637229  tt9916702    writer                                 nm10538223
# 2637230  tt9916756    writer                                 nm10538639
# 2637231  tt9916764    writer  nm6687687,nm10538642,nm9641593,nm10538643
#
# [2637232 rows x 3 columns]

# %%
title_crew_melt['nconst'] =  title_crew_melt['nconst'].str.split(',')
title_crew_melt
# Out:
#             tconst      role                                          nconst
# 0        tt0000001  director                                     [nm0005690]
# 1        tt0000002  director                                     [nm0721526]
# 2        tt0000005  director                                     [nm0005690]
# 3        tt0000006  director                                     [nm0005690]
# 4        tt0000007  director                          [nm0005690, nm0374658]
# ...            ...       ...                                             ...
# 2637227  tt9916560    writer                                     [nm0103043]
# 2637228  tt9916620    writer                                     [nm7311709]
# 2637229  tt9916702    writer                                    [nm10538223]
# 2637230  tt9916756    writer                                    [nm10538639]
# 2637231  tt9916764    writer  [nm6687687, nm10538642, nm9641593, nm10538643]
#
# [2637232 rows x 3 columns]

# %%
table_title_crew = title_crew_melt.explode('nconst')
table_title_crew
# Out:
#             tconst      role      nconst
# 0        tt0000001  director   nm0005690
# 1        tt0000002  director   nm0721526
# 2        tt0000005  director   nm0005690
# 3        tt0000006  director   nm0005690
# 4        tt0000007  director   nm0005690
# ...            ...       ...         ...
# 2637230  tt9916756    writer  nm10538639
# 2637231  tt9916764    writer   nm6687687
# 2637231  tt9916764    writer  nm10538642
# 2637231  tt9916764    writer   nm9641593
# 2637231  tt9916764    writer  nm10538643
#
# [3962601 rows x 3 columns]

# %% [markdown]
# ### Name Basics

# %%
df_name_basics = pd.read_csv('Data/name_basics.csv.gz')
df_name_basics.head()
# Out:
#       nconst      primaryName  birthYear  deathYear  \
# 0  nm0000001     Fred Astaire     1899.0     1987.0
# 1  nm0000002    Lauren Bacall     1924.0     2014.0
# 2  nm0000003  Brigitte Bardot     1934.0        NaN
# 3  nm0000004     John Belushi     1949.0     1982.0
# 4  nm0000005   Ingmar Bergman     1918.0     2007.0
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0053137,tt0045537,tt0072308
# 1  tt0117057,tt0038355,tt0037382,tt0071877
# 2  tt0056404,tt0054452,tt0049189,tt0057345
# 3  tt0078723,tt0072562,tt0077975,tt0080455
# 4  tt0060827,tt0083922,tt0050986,tt0050976

# %%
#for name basics, keep only the directors and writers from the US
#we do this by using the nconsts to filter our needed movies
keepers = df_name_basics['nconst'].isin(unique_nconst)
keepers
# Out:
# 0           False
# 1           False
# 2           False
# 3            True
# 4            True
#             ...
# 12210096    False
# 12210097    False
# 12210098    False
# 12210099    False
# 12210100    False
# Name: nconst, Length: 12210101, dtype: bool

# %%
#filter name basics and ensure it is correct
df_name_basics = df_name_basics[keepers]
df_name_basics
# Out:
#              nconst     primaryName  birthYear  deathYear  \
# 3         nm0000004    John Belushi     1949.0     1982.0
# 4         nm0000005  Ingmar Bergman     1918.0     2007.0
# 7         nm0000008   Marlon Brando     1924.0     2004.0
# 8         nm0000009  Richard Burton     1925.0     1984.0
# 9         nm0000010    James Cagney     1899.0     1986.0
# ...             ...             ...        ...        ...
# 12210045  nm9993657     Jason Green        NaN        NaN
# 12210062  nm9993679       Art Jones        NaN        NaN
# 12210090  nm9993708      Eli Bevins        NaN        NaN
# 12210091  nm9993709       Lu Bevins        NaN        NaN
# 12210095  nm9993713   Sambit Mishra        NaN        NaN
#
#                   primaryProfession  \
# 3           actor,soundtrack,writer
# 4             writer,director,actor
# 7         actor,soundtrack,director
# 8         actor,soundtrack,producer
# 9         actor,soundtrack,director
# ...                             ...
# 12210045                     writer
# 12210062                   director
# 12210090   producer,director,writer
# 12210091   producer,director,writer
# 12210095            writer,producer
#
#                                        knownForTitles
# 3             tt0078723,tt0072562,tt0077975,tt0080455
# 4             tt0060827,tt0083922,tt0050986,tt0050976
# 7             tt0078788,tt0068646,tt0070849,tt0047296
# 8             tt0059749,tt0061184,tt0087803,tt0057877
# 9             tt0035575,tt0042041,tt0029870,tt0031867
# ...                                               ...
# 12210045                                    tt8187876
# 12210062                                    tt8744074
# 12210090  tt11702702,tt11772904,tt11772812,tt14508814
# 12210091  tt17717854,tt11772812,tt11697102,tt11772904
# 12210095  tt10449366,tt10709066,tt15134202,tt21147342
#
# [642949 rows x 6 columns]

# %% [markdown]
# ### professions

# %%
professions = df_name_basics[['nconst','primaryProfession']]
professions
# Out:
#              nconst          primaryProfession
# 3         nm0000004    actor,soundtrack,writer
# 4         nm0000005      writer,director,actor
# 7         nm0000008  actor,soundtrack,director
# 8         nm0000009  actor,soundtrack,producer
# 9         nm0000010  actor,soundtrack,director
# ...             ...                        ...
# 12210045  nm9993657                     writer
# 12210062  nm9993679                   director
# 12210090  nm9993708   producer,director,writer
# 12210091  nm9993709   producer,director,writer
# 12210095  nm9993713            writer,producer
#
# [642949 rows x 2 columns]

# %%
professions['profession'] = professions['primaryProfession'].str.split(',')
professions
# Out:
# /var/folders/tc/tt7jrftn7g510vxnf1thdhl80000gn/T/ipykernel_11905/1575924440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   professions['profession'] = professions['primaryProfession'].str.split(',')
#              nconst          primaryProfession                     profession
# 3         nm0000004    actor,soundtrack,writer    [actor, soundtrack, writer]
# 4         nm0000005      writer,director,actor      [writer, director, actor]
# 7         nm0000008  actor,soundtrack,director  [actor, soundtrack, director]
# 8         nm0000009  actor,soundtrack,producer  [actor, soundtrack, producer]
# 9         nm0000010  actor,soundtrack,director  [actor, soundtrack, director]
# ...             ...                        ...                            ...
# 12210045  nm9993657                     writer                       [writer]
# 12210062  nm9993679                   director                     [director]
# 12210090  nm9993708   producer,director,writer   [producer, director, writer]
# 12210091  nm9993709   producer,director,writer   [producer, director, writer]
# 12210095  nm9993713            writer,producer             [writer, producer]
#
# [642949 rows x 3 columns]

# %%
professions = professions.explode('profession')[['nconst','profession']]
professions
# Out:
#              nconst  profession
# 3         nm0000004       actor
# 3         nm0000004  soundtrack
# 3         nm0000004      writer
# 4         nm0000005      writer
# 4         nm0000005    director
# ...             ...         ...
# 12210091  nm9993709    producer
# 12210091  nm9993709    director
# 12210091  nm9993709      writer
# 12210095  nm9993713      writer
# 12210095  nm9993713    producer
#
# [1567319 rows x 2 columns]

# %% [markdown]
# ### Known for titles

# %%
known = df_name_basics[['nconst','knownForTitles']]
known
# Out:
#              nconst                               knownForTitles
# 3         nm0000004      tt0078723,tt0072562,tt0077975,tt0080455
# 4         nm0000005      tt0060827,tt0083922,tt0050986,tt0050976
# 7         nm0000008      tt0078788,tt0068646,tt0070849,tt0047296
# 8         nm0000009      tt0059749,tt0061184,tt0087803,tt0057877
# 9         nm0000010      tt0035575,tt0042041,tt0029870,tt0031867
# ...             ...                                          ...
# 12210045  nm9993657                                    tt8187876
# 12210062  nm9993679                                    tt8744074
# 12210090  nm9993708  tt11702702,tt11772904,tt11772812,tt14508814
# 12210091  nm9993709  tt17717854,tt11772812,tt11697102,tt11772904
# 12210095  nm9993713  tt10449366,tt10709066,tt15134202,tt21147342
#
# [642949 rows x 2 columns]

# %%
known['knownForTitles'] = known['knownForTitles'].str.split(',')
known
# Out:
# /var/folders/tc/tt7jrftn7g510vxnf1thdhl80000gn/T/ipykernel_11905/502330472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   known['knownForTitles'] = known['knownForTitles'].str.split(',')
#              nconst                                    knownForTitles
# 3         nm0000004      [tt0078723, tt0072562, tt0077975, tt0080455]
# 4         nm0000005      [tt0060827, tt0083922, tt0050986, tt0050976]
# 7         nm0000008      [tt0078788, tt0068646, tt0070849, tt0047296]
# 8         nm0000009      [tt0059749, tt0061184, tt0087803, tt0057877]
# 9         nm0000010      [tt0035575, tt0042041, tt0029870, tt0031867]
# ...             ...                                               ...
# 12210045  nm9993657                                       [tt8187876]
# 12210062  nm9993679                                       [tt8744074]
# 12210090  nm9993708  [tt11702702, tt11772904, tt11772812, tt14508814]
# 12210091  nm9993709  [tt17717854, tt11772812, tt11697102, tt11772904]
# 12210095  nm9993713  [tt10449366, tt10709066, tt15134202, tt21147342]
#
# [642949 rows x 2 columns]

# %%
known = known.explode('knownForTitles')
known
# Out:
#              nconst knownForTitles
# 3         nm0000004      tt0078723
# 3         nm0000004      tt0072562
# 3         nm0000004      tt0077975
# 3         nm0000004      tt0080455
# 4         nm0000005      tt0060827
# ...             ...            ...
# 12210091  nm9993709     tt11772904
# 12210095  nm9993713     tt10449366
# 12210095  nm9993713     tt10709066
# 12210095  nm9993713     tt15134202
# 12210095  nm9993713     tt21147342
#
# [1863152 rows x 2 columns]

# %% [markdown]
# ### title principals

# %%
principals = pd.read_csv('Data/title_principals.csv.gz')
principals
# Out:
#             tconst  ordering      nconst         category  \
# 0        tt0000001         1   nm1588970             self
# 1        tt0000001         2   nm0005690         director
# 2        tt0000001         3   nm0374658  cinematographer
# 3        tt0000002         1   nm0721526         director
# 4        tt0000002         2   nm1335271         composer
# ...            ...       ...         ...              ...
# 8465504  tt9916764         5   nm6685122         director
# 8465505  tt9916764         6   nm6687687           writer
# 8465506  tt9916764         7  nm10538642           writer
# 8465507  tt9916764         8   nm9641593           writer
# 8465508  tt9916764         9  nm10538643           writer
#
#                              job characters
# 0                            NaN   ["Self"]
# 1                            NaN        NaN
# 2        director of photography        NaN
# 3                            NaN        NaN
# 4                            NaN        NaN
# ...                          ...        ...
# 8465504                      NaN        NaN
# 8465505               written by        NaN
# 8465506               written by        NaN
# 8465507             developed by        NaN
# 8465508               written by        NaN
#
# [8465509 rows x 6 columns]

# %%
#extract the characters
characters = principals[['nconst','characters']]

#remove the double quotes
characters = characters.dropna()
characters = characters[~characters['characters'].str.contains(r'\\N')]
characters
# Out:
#              nconst                                characters
# 0         nm1588970                                  ["Self"]
# 5         nm0443482                            ["Blacksmith"]
# 6         nm0653042                             ["Assistant"]
# 15        nm0653028                          ["Sneezing Man"]
# 18        nm0063086  ["Miss Geraldine Holbrook (Miss Jerry)"]
# ...             ...                                       ...
# 8465498  nm10781824                              ["Lakeisha"]
# 8465500  nm10538641                              ["Waitress"]
# 8465501   nm7614214                                ["Shelah"]
# 8465502   nm0307727                        ["Business Man 1"]
# 8465503   nm7403794                          ["Judah Harris"]
#
# [3964389 rows x 2 columns]

# %%
#apply to whole column
characters['characters'] = characters['characters'].apply(lambda x: json.loads(x))
characters
# Out:
#              nconst                              characters
# 0         nm1588970                                  [Self]
# 5         nm0443482                            [Blacksmith]
# 6         nm0653042                             [Assistant]
# 15        nm0653028                          [Sneezing Man]
# 18        nm0063086  [Miss Geraldine Holbrook (Miss Jerry)]
# ...             ...                                     ...
# 8465498  nm10781824                              [Lakeisha]
# 8465500  nm10538641                              [Waitress]
# 8465501   nm7614214                                [Shelah]
# 8465502   nm0307727                        [Business Man 1]
# 8465503   nm7403794                          [Judah Harris]
#
# [3964389 rows x 2 columns]

# %%
#explode the columns
characters_exploded = characters.explode('characters')
characters_exploded
# Out:
#              nconst                            characters
# 0         nm1588970                                  Self
# 5         nm0443482                            Blacksmith
# 6         nm0653042                             Assistant
# 15        nm0653028                          Sneezing Man
# 18        nm0063086  Miss Geraldine Holbrook (Miss Jerry)
# ...             ...                                   ...
# 8465498  nm10781824                              Lakeisha
# 8465500  nm10538641                              Waitress
# 8465501   nm7614214                                Shelah
# 8465502   nm0307727                        Business Man 1
# 8465503   nm7403794                          Judah Harris
#
# [4217976 rows x 2 columns]

# %% [markdown]
# ### TMDB

# %%
tmdb_df = pd.read_csv('Data/final_combined_tmdb_results.csv.gz', lineterminator='\n')
tmdb_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1  tt0113092    0.0                               NaN                   NaN
# 2  tt0116391    0.0                               NaN                   NaN
# 3  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4  tt0118852    0.0                               NaN                   NaN
#
#        budget                                             genres  \
# 0  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 2         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4         0.0                      [{'id': 18, 'name': 'Drama'}]
#
#                                homepage        id original_language  \
# 0                                   NaN   62127.0                en
# 1                                   NaN  110977.0                en
# 2                                   NaN  442869.0                hi
# 3  http://www.wkw-inthemoodforlove.com/     843.0                cn
# 4                                   NaN   49511.0                en
#
#     original_title  ...     revenue  runtime  \
# 0  The Fantasticks  ...         0.0     86.0
# 1    For the Cause  ...         0.0    100.0
# 2             Gang  ...         0.0    152.0
# 3             花樣年華  ...  12854953.0     99.0
# 4   Chinese Coffee  ...         0.0     99.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average vote_count certification
# 0    0.0           5.4       21.0           NaN
# 1    0.0           4.4        7.0           NaN
# 2    0.0           0.0        0.0           NaN
# 3    0.0           8.1     1863.0            PG
# 4    0.0           6.9       45.0             R
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Belongs to Collection

# %%
#examine a single value from the belongs_to_collection column
#there is a lot of nan's in collection. Filter the non null entries
non_null_tmdb = tmdb_df[~tmdb_df['belongs_to_collection'].isna()]

# %%
#examine the non_null columns
non_null_tmdb
# Out:
#          imdb_id  adult                     backdrop_path  \
# 5      tt0119273    0.0  /fClJrAmJQ90zg9gWnfHVYSMiDTv.jpg
# 12     tt0120630    0.0  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 16     tt0120755    0.0  /8XaohdSqoBEWHhW40q2VTdMBrV0.jpg
# 17     tt0120903    0.0  /u4gOTZLplCbP3IgcYcZ7e1zgOAo.jpg
# 19     tt0120917    0.0  /mZj8EUr6F1x2PWZjKPxaeYd5WRw.jpg
# ...          ...    ...                               ...
# 61274  tt9701942    0.0  /6viJBbovWxJYavdjPy7UPTLvaOS.jpg
# 61294  tt9777666    0.0  /yizL4cEKsVvl17Wc1mGEIrQtM2F.jpg
# 61306  tt9819258    0.0  /c08OtT9w78BSxA2wU2GHhyAEi1q.jpg
# 61309  tt9844522    0.0  /dsdbViTNjLu4DbgkkYmuY4xDQ20.jpg
# 61316  tt9857850    0.0                               NaN
#
#                                    belongs_to_collection       budget  \
# 5      {'id': 141086, 'name': 'Heavy Metal Collection...   15000000.0
# 12     {'id': 718551, 'name': 'Chicken Run Collection...   45000000.0
# 16     {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
# 17     {'id': 748, 'name': 'X-Men Collection', 'poste...   75000000.0
# 19     {'id': 178117, 'name': "The Emperor's New Groo...  100000000.0
# ...                                                  ...          ...
# 61274  {'id': 790370, 'name': 'Fear Street Collection...          0.0
# 61294  {'id': 848922, 'name': 'The Tomorrow War Colle...  200000000.0
# 61306  {'id': 897708, 'name': '12 Westerns in 12 Mont...          0.0
# 61309  {'id': 769423, 'name': 'Escape Room Collection...   15000000.0
# 61316  {'id': 897708, 'name': '12 Westerns in 12 Mont...          0.0
#
#                                                   genres  \
# 5      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 12     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 16     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 17     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 19     [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# ...                                                  ...
# 61274  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 61294  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 61306  [{'id': 28, 'name': 'Action'}, {'id': 36, 'nam...
# 61309  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 61316                    [{'id': 37, 'name': 'Western'}]
#
#                                                 homepage        id  \
# 5                                                    NaN   16225.0
# 12                                                   NaN    7443.0
# 16                                                   NaN     955.0
# 17                                                   NaN   36657.0
# 19                                                   NaN   11688.0
# ...                                                  ...       ...
# 61274             https://www.netflix.com/title/81334750  591275.0
# 61294               https://www.amazon.com/dp/B093CQZ2SM  588228.0
# 61306                                                NaN  739393.0
# 61309  https://www.sonypictures.com/movies/escaperoom...  585216.0
# 61316                                                NaN  791112.0
#
#       original_language                           original_title  ...  \
# 5                    en                         Heavy Metal 2000  ...
# 12                   en                              Chicken Run  ...
# 16                   en                   Mission: Impossible II  ...
# 17                   en                                    X-Men  ...
# 19                   en                 The Emperor's New Groove  ...
# ...                 ...                                      ...  ...
# 61274                en                        Fear Street: 1666  ...
# 61294                en                         The Tomorrow War  ...
# 61306                en                                Texas Red  ...
# 61309                en     Escape Room: Tournament of Champions  ...
# 61316                en  A Guide to Gunfighters of the Wild West  ...
#
#            revenue  runtime  \
# 5              0.0     88.0
# 12     224834564.0     84.0
# 16     546388105.0    123.0
# 17     296339527.0    104.0
# 19     169327687.0     78.0
# ...            ...      ...
# 61274          0.0    114.0
# 61294          0.0    138.0
# 61306          0.0     84.0
# 61309   44888959.0     88.0
# 61316          0.0     74.0
#
#                                         spoken_languages    status  \
# 5      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 12     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 16     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 17     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 19     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                  ...       ...
# 61274  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61294  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61306                                                 []  Released
# 61309  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61316  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                  tagline  \
# 5      not to survive the fight in the external world...
# 12     This ain't no chick flick. It's poultry in mot...
# 16                          Expect the impossible again.
# 17                                      Evolution Begins
# 19                                 It's all about... ME!
# ...                                                  ...
# 61274                                     End the curse.
# 61294               The fight for tomorrow begins today.
# 61306                                                NaN
# 61309                    Winning was just the beginning.
# 61316                                                NaN
#
#                                          title  video  vote_average  \
# 5                             Heavy Metal 2000    0.0           6.1
# 12                                 Chicken Run    0.0           6.7
# 16                      Mission: Impossible II    0.0           6.1
# 17                                       X-Men    0.0           7.0
# 19                    The Emperor's New Groove    0.0           7.5
# ...                                        ...    ...           ...
# 61274                        Fear Street: 1666    0.0           7.3
# 61294                         The Tomorrow War    0.0           8.0
# 61306                                Texas Red    0.0           4.5
# 61309     Escape Room: Tournament of Champions    0.0           6.7
# 61316  A Guide to Gunfighters of the Wild West    0.0           0.0
#
#       vote_count certification
# 5          149.0             R
# 12        3993.0             G
# 16        5271.0         PG-13
# 17        9548.0         PG-13
# 19        5433.0             G
# ...          ...           ...
# 61274     1100.0             R
# 61294     5381.0         PG-13
# 61306        2.0           NaN
# 61309     1130.0         PG-13
# 61316        0.0           NaN
#
# [3817 rows x 26 columns]

# %%
#there is a couple of things to fix in the belongs_to_collection column
#a function will make this faster
def collectionsFix(data):
    try:
        data = data.replace('None','"None"')
        data = data.replace('\\','')
        data = data.replace("'s",'s')
        for quotes in ['id','poster_path','name','backdrop_path']:
            data = data.replace(f"'{quotes}'",f'"{quotes}"')

        data = data.replace("'",'"')

        data = json.loads(data)
    except:
        return None
    
    if isinstance(data,dict):
        collections= data['name']
        
    elif isinstance(data,list):
        collections = []
        for collect in data:
            collections.append(collect['name'])
    else:
        collections = "MISSING"
    return collections

# %%
#test one line of the belongs_to_collections column
#19 seems to have the most issues. 
collect = non_null_tmdb.iloc[19]['belongs_to_collection']
collect
# Out:
# "{'id': 211721, 'name': 'Taxi Collection', 'poster_path': '/nCzy28TbMJDJLxuaPgQZrLgmuT7.jpg', 'backdrop_path': '/74R8bq4RDuxK3F0VPGlse4YH3Ab.jpg'}"

# %%
#apply the function to the test
collectionsFix(collect)
# Out:
# 'Taxi Collection'

# %%
#create a new column that will have the applied function to the column
tmdb_df['collection'] = tmdb_df['belongs_to_collection'].apply(collectionsFix)
tmdb_df
# Out:
#          imdb_id  adult                     backdrop_path  \
# 0      tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1      tt0113092    0.0                               NaN
# 2      tt0116391    0.0                               NaN
# 3      tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 4      tt0118852    0.0                               NaN
# ...          ...    ...                               ...
# 61326  tt9895024    0.0   /S1kutYyoyuBJKGS0mXxv2fZNbr.jpg
# 61327  tt9896876    0.0  /hMvRbT6HOqERhh3K8kXbaLz9LlZ.jpg
# 61328  tt9898844    0.0  /q2KFBGyUSzHDhNqXEYv2LqTWVSz.jpg
# 61329  tt9900940    0.0  /3jjWLg5bevWqReyVroYqxwVrH0k.jpg
# 61330  tt9907782    0.0  /gRTYArznK1MLAq7opC1tYHnTwM3.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN  10000000.0
# 1                       NaN         0.0
# 2                       NaN         0.0
# 3                       NaN    150000.0
# 4                       NaN         0.0
# ...                     ...         ...
# 61326                   NaN         0.0
# 61327                   NaN         0.0
# 61328                   NaN         0.0
# 61329                   NaN         0.0
# 61330                   NaN         0.0
#
#                                                   genres  \
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1               [{'id': 878, 'name': 'Science Fiction'}]
# 2      [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                          [{'id': 18, 'name': 'Drama'}]
# ...                                                  ...
# 61326  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 61327  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 61328                     [{'id': 27, 'name': 'Horror'}]
# 61329  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 61330  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
#
#                                    homepage        id original_language  \
# 0                                       NaN   62127.0                en
# 1                                       NaN  110977.0                en
# 2                                       NaN  442869.0                hi
# 3      http://www.wkw-inthemoodforlove.com/     843.0                cn
# 4                                       NaN   49511.0                en
# ...                                     ...       ...               ...
# 61326                                   NaN  834443.0                de
# 61327                                   NaN  821493.0                en
# 61328                                   NaN  870671.0                en
# 61329                                   NaN  861294.0                en
# 61330                                   NaN  630392.0                en
#
#                 original_title  ... runtime  \
# 0              The Fantasticks  ...    86.0
# 1                For the Cause  ...   100.0
# 2                         Gang  ...   152.0
# 3                         花樣年華  ...    99.0
# 4               Chinese Coffee  ...    99.0
# ...                        ...  ...     ...
# 61326              Heikos Welt  ...   118.0
# 61327  India Sweets and Spices  ...   101.0
# 61328              The Hunting  ...    91.0
# 61329             The Scrapper  ...    87.0
# 61330               The Cursed  ...   111.0
#
#                                         spoken_languages    status  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3      [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                  ...       ...
# 61326  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 61327  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61328  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61329  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61330  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                  tagline  \
# 0          Try to remember the first time magic happened
# 1           The ultimate showdown on a forbidden planet.
# 2                                                    NaN
# 3      Feel the heat, keep the feeling burning, let t...
# 4      There's a fine line between friendship and bet...
# ...                                                  ...
# 61326                                                NaN
# 61327                              Let the aunties talk.
# 61328                                  Hunger runs deep.
# 61329                        You can't escape your past.
# 61330                                                NaN
#
#                          title video  vote_average  vote_count certification  \
# 0              The Fantasticks   0.0           5.4        21.0           NaN
# 1                For the Cause   0.0           4.4         7.0           NaN
# 2                         Gang   0.0           0.0         0.0           NaN
# 3         In the Mood for Love   0.0           8.1      1863.0            PG
# 4               Chinese Coffee   0.0           6.9        45.0             R
# ...                        ...   ...           ...         ...           ...
# 61326            Heiko's World   0.0           0.0         0.0           NaN
# 61327  India Sweets and Spices   0.0           6.0         2.0         PG-13
# 61328              The Hunting   0.0           4.9        20.0           NaN
# 61329             The Scrapper   0.0           6.0         2.0           NaN
# 61330               The Cursed   0.0           7.0        55.0             R
#
#       collection
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 61326       None
# 61327       None
# 61328       None
# 61329       None
# 61330       None
#
# [61331 rows x 27 columns]

# %%
tmdb_df['collection'].value_counts()
# Out:
# Troublesome Night Collection              20
# Detective Conan Collection                19
# Doraemon Collection                       17
# One Piece Collection                      14
# Madea - Collection                        11
#                                           ..
# Easy Rider Collection                      1
# Tinker Bell Collection                     1
# The Man with the Iron Fists Collection     1
# Armour of God Collection                   1
# The Tomorrow War Collection                1
# Name: collection, Length: 1846, dtype: int64

# %%
#display unique list of collections
unique_collection = sorted(tmdb_df['collection'].dropna().unique())
unique_collection
# Out:
# ['#TemanTapiMenikah',
#  '... Cameras Collection',
#  '.hack Collection',
#  '10 giorni... - Collezione',
#  '100 Girls Collection',
#  '100% Coco Collection',
#  '101 Dalmatians (Live-Action) Collection',
#  '12 Dogs of Christmas Collection',
#  '12 Rounds Collection',
#  '12 Westerns in 12 Months Collection',
#  '14+ (Коллекция)',
#  '1920 Collection',
#  '1981 Collection',
#  '2 Days In... Collection',
#  '2001 Maniacs Collection',
#  '20th Century Boys Collection',
#  '28 Days/Weeks Later Collection',
#  '3 A.M. Collection',
#  '3 Braves Universe',
#  '3 Little Pigs collection',
#  '30 Days of Night Collection',
#  '300 Collection',
#  '365 Days Collection',
#  '47 Meters Down Collection',
#  '47 Ronin Collection',
#  '64 Collection',
#  '666 Collection',
#  '8 свиданий (Коллекция)',
#  'A California Christmas Collection',
#  'A Chinese Odyssey Collection',
#  'A Christmas Prince Collection',
#  'A Doggone Collection',
#  'A Dogs Purpose Collection',
#  'A Few Best Men Collection',
#  'A Frozen Christmas Collection',
#  'A Haunted House Collection',
#  'A Man and a Woman Collection',
#  'A Menina que Matou os Pais',
#  'A Meowy Collection',
#  'A Monkeys Tale',
#  'A Quiet Place Collection',
#  'A Second Chance Collection',
#  'A Very Special Love Collection',
#  'ABCD Collection',
#  'AMV Hell',
#  'ARCHIE Collection',
#  'AVP Collection',
#  'Aadu Collection',
#  'Aashiqui Collection',
#  'Ab Tak Chhappan Collection',
#  'About Love Collection',
#  'Accident Man Collection',
#  'Achtung, fertig Filmreihe',
#  'Ada Apa Dengan Cinta? Collection',
#  'Admiral Yi',
#  'Adventures of Bailey Collection',
#  'After Collection',
#  'Against the Wild Collection',
#  'Agent Cody Banks Collection',
#  'Ah Boys to Men Collection',
#  'Aileen Wuornos Collection',
#  'Ajin Collection',
#  'Akihabara Trilogy',
#  'Aladdin (Live-Action) Collection',
#  'Aldo Giovanni e Giacomo Collection',
#  'Alex Cross Collection',
#  'Algjör Sveppi',
#  'Alice in Wonderland Collection',
#  'Alien Factor Collection',
#  'Alien Sex Files',
#  'Aliens Ate My Homework Collection',
#  'All Hallows Eve Collection',
#  'All for ...',
#  'Alligator Ladies Collection',
#  'Alls Well, Ends Well',
#  'Almighty Collection',
#  'Alone in the Dark Collection',
#  'Along Came the Devil Collection',
#  'Along with the Gods Collection',
#  'Alpha and Omega Collection',
#  'Alvin and the Chipmunks Collection',
#  'Always: Sunset on Third Street Collection',
#  'Amateur Porn Star Killer Collection',
#  'Ambra Collection',
#  'American Civil War Collection',
#  'American Guinea Pig Collection',
#  'American Pie Collection',
#  'American Poltergeist',
#  'American Psycho Collection',
#  'Amityville Scarecrow Collection',
#  'An American Girl Collection',
#  'Anaconda Collection',
#  'Analyze Collection',
#  'Anatomy Collection',
#  'Anatomy of an Antihero Collection',
#  'Anchorman Collection',
#  'Android Kunjappan Collection',
#  'Anděl Páně (kolekce)',
#  'Ang Tanging Ina Collection',
#  'Angelas Christmas Collection',
#  'Animal Collection',
#  'Anja & Viktor Collection',
#  'Annabelle Collection',
#  'Annika Bengtzon Collection',
#  'Annika Bengtzon Collection (Helena Bergström)',
#  'Another Gay Movie Collection',
#  'Ant-Man Collection',
#  'Antboy Collection',
#  'Antelope Valley Collection',
#  'Antisocial Collection',
#  'Ants in the Pants Collection',
#  'Apocalypse Collection',
#  'Appleseed Collection',
#  'Aqua Teen Hunger Force Colon Movie Film for Theaters Collection',
#  'Aquaman Collection',
#  'Arabian Nights Collection',
#  'Aranmanai Collection',
#  'Ardaas Collection',
#  'Argo Collection',
#  'Armored Trooper VOTOMS Collection',
#  'Armour of God Collection',
#  'Army of the Dead Collection',
#  'Arn Collection',
#  'Arpeggio of blue steel',
#  'Art of the Devil Collection',
#  'Arthur and the Invisibles Collection',
#  'Ash Lad Collection',
#  'Ashens Collection',
#  'Ask Me Anything Collection',
#  'Assassination Classroom Collection',
#  'Asterix & Obelix Collection',
#  'Asterix and Obelix (Animation) Collection',
#  'Atlantic Rim Collection',
#  'Atlantis Collection',
#  'Atlas Shrugged Collection',
#  'Atomic Blonde Collection',
#  'Attack on Titan (Anime) Collection',
#  'Attack on Titan Collection',
#  'Attack the Block Collection',
#  'Attack the Gas Station Collection',
#  'Attraction Collection',
#  'Austin Powers Collection',
#  'Avatar Collection',
#  'Avenger Dogs',
#  'Avengers Grimm Collection',
#  'Avunu Collection',
#  'Aşk Tesadüfleri Sever [Seri]',
#  'Baaghi Collection',
#  'Baahubali Collection',
#  'Baby Driver Collection',
#  'Baby Geniuses Collection',
#  'Babysitting Collection',
#  'Bad Ass Collection',
#  'Bad Ben Collection',
#  'Bad Boys Collection',
#  'Bad Kids Collection',
#  'Bad Moms Collection',
#  'Bad Santa Collection',
#  'Balala the Fairies series',
#  'Bamse Collection',
#  'BanG Dream! Episode of Roselia Collection',
#  'Bang Rajan Collection',
#  'Barbershop Collection',
#  'Barbie & Kendra Collection',
#  'Barbie Mariposa Collection',
#  'Basic Instinct Collection',
#  'Batman (DC Universe Animated) Collection',
#  'Batman Animation Collection (Adam West)',
#  'Batman: The Long Halloween Collection',
#  'Battle Royale Collection',
#  'Battle of the Brides',
#  'Bayside Shakedown Collection',
#  'Baztan Trilogy',
#  'Be My Slave Collection',
#  'Bearcity Collection',
#  'Before... Collection',
#  'Behind Enemy Lines Collection',
#  'Belle & Sebastian',
#  'Benvenuti al... Collection',
#  'Benvenuto Presidente - Collezione',
#  'Benyamin The Troublemaker',
#  'Bernie the Dolphin Collection',
#  'Berserk: Golden Age Arc Collection',
#  'Best Exotic Marigold Hotel Collection',
#  'Best F(r)iends Collection',
#  'Beverly Hills Chihuahua Collection',
#  'Bhai - Vyakti ki Valli',
#  'Bheja Fry Collection',
#  'Bhoothnath Collection',
#  'Bibi & Tina Collection',
#  'Bibi Blocksberg Collection',
#  'Big Brother Collection',
#  'Big Fat Liar Collection',
#  'Big Mommas House Collection',
#  'Bigfoot Collection',
#  'Bill & Teds Most Excellent Collection',
#  'Bird Box Collection',
#  'Birdemic Collection',
#  'Black & White Collection',
#  'Black Panther Collection',
#  'Black Water Collection',
#  'Blade Collection',
#  'Blade Runner Collection',
#  'Blair Witch Collection',
#  'Bleach Collection',
#  'Blood Feast Collection',
#  'BloodRayne Collection',
#  'Bloodbath at Pinky High Collection',
#  'Bloodshot Collection',
#  'Bloody Chainsaw Girl Collection',
#  'Blue Crush Collection',
#  'BoBoiBoy Collection',
#  'Bob The Cat Collection',
#  'Bon Bini Holland Collectie',
#  'Bon Cop Bad Cop Collection',
#  'Bonded by Blood Collection',
#  'Boon Collection',
#  'Boonie Bears Collection',
#  'Borat Moviefilms Collection',
#  'Borgríki Collection',
#  'Boule & Bill',
#  'Bound Heat',
#  'Boys Life (Collection)',
#  'Bratz Collection',
#  'Brice Collection',
#  'Bridget Jones Collection',
#  'Brigada Z Collection',
#  'Bright Collection',
#  'Bring It On Collection',
#  'Broken Blade Collection',
#  'Brother Bear Collection',
#  'Brother Collection',
#  'Brotherhood of Blades Collection',
#  'Bulletproof Collection',
#  'Bunker of Blood Collection',
#  'Bunnyman Collection',
#  'Bunty Aur Babli',
#  'Buppah Ratree Collection',
#  'Burg Schreckenstein Filmreihe',
#  'Burnout Collection',
#  'Burnt by the Sun Trilogy',
#  'Cabin Fever Collection',
#  'Caesar and Otto Collection',
#  'Cal Collection',
#  'Camp Blood Collection',
#  'Camping Collection',
#  'Candyman Collection',
#  'Captain America Collection',
#  'Captain Marvel Collection',
#  'Captain Underpants Collection',
#  'Cardcaptor Sakura Collection',
#  'Carmina - Colección',
#  'CarousHELL Collection',
#  'Carpenter Andersen Collection',
#  'Cars Collection',
#  'Carters Collection',
#  'Carved Collection',
#  'Casper and Emma Collection',
#  'Cat Run Collection',
#  'Cats & Dogs Collection',
#  'Cattle Hill Collection',
#  'Cementerio General Collection',
#  'Center Stage Collection',
#  'Charlies Angels Collection',
#  'Charter Trips',
#  'Chasing The Dragon Collection',
#  'Che Collection',
#  'Cheaper by the Dozen (2003) Collection',
#  'Cheech & Chong Collection',
#  'Cherry Blossoms',
#  'Chhakka Panja Collection',
#  'Chicken Run Collection',
#  'Chief Daddy Collection',
#  'Chihayafuru Collection',
#  'Children of the Corn Collection',
#  'Childs Play Collection',
#  'Chili Palmer Collection',
#  'Chocolate City Collection',
#  'Christmas Thieves (Collection)',
#  'Christmas with a Prince Collection',
#  'Chronicle Collection',
#  'Cinderella Story Collection',
#  'Cities of Love Collection',
#  'Clash of the Titans Collection',
#  'Class Reunion Collection',
#  'Clerks Collection',
#  'Clint Eastwoods Iwo Jima Collection',
#  'Cloudy with a Chance of Meatballs Collection',
#  'Clubhouse Detectives Collection',
#  'Coconut The Little Dragon Collection',
#  'Code Geass: Akito the Exiled',
#  'Code Geass: Lelouch of the Rebellion Recap Film Trilogy',
#  'Cold Prey Collection',
#  'Cold Pursuit Collection',
#  'Cold War Collection',
#  'Coletânea Nada a Perder',
#  'Come un gatto in tangenziale - Collezione',
#  'Coming to America Collection',
#  'Commander Kellie & the Superkids Collection',
#  'Commando Collection',
#  'Confession Executive Committee (Series)',
#  'Confidential Assignment',
#  'Contracted Collection',
#  'Corky St. Clair Collection',
#  'Corpse Party Collection',
#  'Corpse Prison Collection',
#  'Corto Maltese Collection',
#  'Cowboy Filmreihe',
#  'Crackerjack Collection',
#  'Crank Collection',
#  'Crayon Shin-chan Collection',
#  'Crazy Rich Asians Collection',
#  'Crazy Wedding Collection',
#  'Creed Collection',
#  'Creep Collection',
#  'Crimes of Passion: The Maria Lang Collection',
#  'Crocodile Collection',
#  'Crocodile Dundee Collection',
#  'Cross Collection',
#  'Crouching Tiger, Hidden Dragon Collection',
#  'Crows Collection',
#  'Cruella Collection',
#  'Cube Collection',
#  'Cuccioli - Collezione',
#  'Curious George Collection',
#  'Cyborg 009 Collection',
#  'DAU Cinema',
#  'Dabangg Collection',
#  'Dabbe [Seri]',
#  'Daddy Day Camp Collection',
#  'Daddys Home Collection',
#  'Danur Collection',
#  'Dark Planet Collection',
#  'Dark Woods Collection',
#  'Dark World Collection',
#  'Darko Collection',
#  'Darling Collection',
#  'Darna Hai Collection',
#  'Dawn of the Dragonslayer Collection',
#  'De Club van Sinterklaas',
#  'De Pernas Pro Ar - Coleção',
#  'De forbandede år (samling)',
#  'Dead Rising Collection',
#  'Dead River Collection',
#  'Dead Snow Collection',
#  'Dead or Alive Collection',
#  'Deadlands Collection',
#  'Deadly Prey Collection',
#  'Deadpool Collection',
#  'Deadtime Stories',
#  'Dear God No!',
#  'Death Bell Collection',
#  'Death Forest Collection',
#  'Death Note Collection',
#  'Death Race Collection',
#  'Deco Truck Gal Nami',
#  'Decoys Collection',
#  'Deep Blue Sea Collection',
#  'Deep Sea Monster Raiga Collection',
#  'Demon Slayer',
#  'Den of Thieves Collection',
#  'Den som dræber',
#  'Department Q Collection',
#  'Der kleine Rabe Socke Filmreihe',
#  'Despicable Me Collection',
#  'Detective Chinatown Collection',
#  'Detective Conan Collection',
#  'Detective Dee Collection',
#  'Detective K Collection',
#  'Detective bureau nr. 2',
#  'Detective in the Bar',
#  'Deuce Bigalow Collection',
#  'Devi Collection',
#  'Devil in the Flesh',
#  'Dhamaal Collection',
#  'Dhoom Collection',
#  'Diabolik - Collezione',
#  'Diary of a Wimpy Kid (Animated) Collection',
#  'Diary of a Wimpy Kid Collection',
#  'Die Hard Collection',
#  'Die Vampirschwestern Collection',
#  'Digimon Adventure tri. Collection',
#  'Digimon Collection',
#  'Dilan',
#  'Diplomat Kosaku Kuroda',
#  'Dirty Dancing Collection',
#  'District 13 Collection',
#  'Divergent Collection',
#  'Divã: Coleção',
#  'Doctor Strange Collection',
#  'Dolemite Collection',
#  'Dolphin Tale Collection',
#  'Don Collection',
#  'Doom Collection',
#  'Doraemon Collection',
#  'Dorm Daze Collection',
#  'Dostana Collection',
#  'Downton Abbey Collection',
#  'Dr. Dolittle Collection',
#  'Dracula 2000 Collection',
#  'Dragon Ball Super Collection',
#  'Dragon Inn',
#  'Dragon Loaded Collection',
#  'Dragon Nest Collection',
#  'DragonHeart Collection',
#  'Drishya Collection',
#  'Drishyam Collection',
#  'Drumline - Collection',
#  'Drushyam Collection',
#  'Ducobu Collection',
#  'Dulhania Collection',
#  'Dumb and Dumber Collection',
#  'Dummie the Mummy Collection',
#  'Dune Collection',
#  'Dungeons & Dragons Collection',
#  'Dynamic Pro Super Robot Collection',
#  'Eagle Talon Collection',
#  'Easy Money Collection',
#  'Easy Rider Collection',
#  'Eating Out Collection',
#  'Eberhofer',
#  'Eden of the East Collection',
#  'Eight Ranger Collection',
#  'El Bosque Animado',
#  'El Crack Collection',
#  'El Gezira Collection',
#  'Election Collection',
#  'Elektra Luxx Collection',
#  'Elias the Little Rescue Boat Collection',
#  'Elite Squad Collection',
#  'Elizabeth Collection',
#  'Ella and Friends Collection',
#  'Ellembi Series',
#  'Elling Collection',
#  'Elvira Collection',
#  'Emmanuelle Through Time Collection',
#  'Enchanted Collection',
#  'Enola Holmes Collection',
#  'Erkan & Stefan Collection',
#  'Escape Plan Collection',
#  'Escape Room Collection',
#  'Essex Boys',
#  'Eureka Seven Hi-Evolution Collection',
#  'Euthanizer Collection',
#  'Evil Bong Collection',
#  'Evil Dead Collection',
#  'Ex Collection',
#  'Ex-Files',
#  'Extraction Collection',
#  'Eye of the Dolphin Collection',
#  'F*ck You, Goethe Collection',
#  'Faces of Dying Collection',
#  'Fairy Tail Collection',
#  'Fallen',
#  'Familien Jul (Samling)',
#  'Famous Five Collection',
#  'Fantastic Beasts Collection',
#  'Fantastic Four Collection',
#  'Fantastic Journey To Oz',
#  'Fat Pizza Collection',
#  'Fate/Stay Night: Heavens Feel Collection',
#  'Father and Guns Collection',
#  'Father of Four Collection',
#  'Fear PHarm Collection',
#  'Fear Street Collection',
#  'Feast Collection',
#  'Felix the Rabbit Collection',
#  'Feluda Collection',
#  'Female Ninjas Magic Chronicles Collection',
#  'Femalien Collection',
#  'Fifty Shades Collection',
#  'Filthy McNasty Collection',
#  'Fimfárum',
#  'Final Destination Collection',
#  'Final Fantasy VII Collection',
#  'Finding Jesus Collection',
#  'Finding Mr. Right Collection',
#  'Finding Nemo Collection',
#  'Firefly Collection',
#  'First Lady Collection',
#  'Fishermans Friends Collection',
#  'Fishtales Collection',
#  'Fist of the North Star: The Legends of the True Savior',
#  'Flicka Collection',
#  'Flower and Snake (Remake) Collection',
#  'Fool for Love',
#  'Forbidden Fruit Collection',
#  'Force Collection',
#  'Fortress Collection',
#  'Four Sisters and a Wedding Collection',
#  'Four Taxidrivers and a Dog Collection',
#  'Franklin Collection',
#  'Free Guy Collection',
#  'Free!',
#  'Freedom Trilogy',
#  'Freier Fall Collection',
#  'French Fried Vacation',
#  'Friday Collection',
#  'Friday the 13th Collection',
#  'Friend Collection',
#  'Fright Night (Reboot) Collection',
#  'From Vegas to Macau Collection',
#  'Frozen Collection',
#  'Fubar Collection',
#  'Fuerzas Especiales Collection',
#  'Fuga de cerebros - Collection',
#  'Fukrey Collection',
#  'Full Out Collection',
#  'Fullmetal Alchemist Collection',
#  'G.I. Joe (Live-Action) Collection',
#  'G.O.R.A. Collection',
#  'GALILEO collection',
#  'Gabriels Inferno Collection',
#  'Gamera (Heisei) Collection',
#  'Gang of Roses Collection',
#  'Gangs of Wasseypur Collection',
#  'Gantz Collection',
#  'Garfield Collection',
#  'Gatao Collection',
#  'Gautas Iškvietimas Collection',
#  'Gen-X Cops Collections',
#  'Geniş Aile [Seri]',
#  'Gett Collection',
#  'Ghayal Collection',
#  'Ghost In The Shell: Arise Collection',
#  'Ghost Rider Collection',
#  'Ghost Shark Collection',
#  'Ghost in the Shell (Animated) Collection',
#  'Ghostbusters Collection',
#  'Ginger Snaps Collection',
#  'Gintama Collection',
#  'Gintama Movie Collection',
#  'Girls & Panzer Filmreihe',
#  'Girls on Top Collection',
#  'Glass Tiger collection',
#  'Gloria Duque - Colección',
#  'Gnomeo & Juliet Collection',
#  'Go For Broke Collection',
#  'Go Goa Gone Collection',
#  'Go Lala Go Collection',
#  'Go! Go! Cory Carson Collection',
#  'Goal! Collection',
#  'Goat Story Collection',
#  'God of Gamblers Collection',
#  'Gods Not Dead Collection',
#  'Godzilla (Millennium) Collection',
#  'Godzilla Anime Trilogy',
#  'Godzilla Collection',
#  'Goenda Shabor Collection',
#  'Gogol Collection',
#  'Golden Chicken Collection',
#  'Golden Winter Collection',
#  'Golmaal Collection',
#  'Gomez & Tavarès Collection',
#  'Gonin Collection',
#  'Good Take Collection',
#  'Gooische Vrouwen Collection',
#  'Goon Collection',
#  'Goosebumps Collection',
#  'Grave Encounters Collection',
#  'Green Street Hooligans Collection',
#  'Greenland Collection',
#  'Grindsploitation Collection',
#  'Grizzly Collection',
#  'Groundhog Dave Collection',
#  'Grown Ups Collection',
#  'Guardians of the Galaxy Collection',
#  'Gukga daepyo Collection',
#  'Gumball 3000 Collection',
#  'Gundala',
#  'Gundam Reconguista in G Collection',
#  'Gunpowder Milkshake Collection',
#  'Gwendolyn Shepherd Collection',
#  'HIT: Cases Collection',
#  'Hababam Sınıfı [Seri]',
#  'Habibie & Ainun Collection',
#  'Haikyu!! - Movie Collection',
#  'Hakuouki Movie Collection',
#  'Half Past Dead Collection',
#  'Halloween (Rob Zombie Series) Collection',
#  'Halloween Collection',
#  'Hamilton Collection',
#  'Hana and Alice Collection',
#  'Hana-Dama Collection',
#  'Hanni & Nanni Filmreihe',
#  'Happiness Collection',
#  'Happy Bhag Jayegi Collection',
#  'Happy Death Day Collection',
#  'Happy Feet Collection',
#  'Harihar Nagar  Collection',
#  'Harold & Kumar Collection',
#  'Harry Potter Collection',
#  'Has Fallen Collection',
#  'Hatchet Collection',
#  'Hate Story Collection',
#  'Haunted Road Collection',
#  'Haunted School Collection',
#  'Haunted Transylvania Collection',
#  'Havoc Collection',
#  'Hayflower and Quiltshoe Collection',
#  'Hayride Collection',
#  'He Who Dares Collection',
#  'Head Cases',
#  'Headless Hero Collection',
#  'Healed by Grace Collection',
#  'Heaven, Hell and Purgatory Collection',
#  'Heavens Lost Property',
#  'Heavy Metal Collection',
#  'Hell House LLC Collection',
#  'Hellboy Collection',
#  'Hellcats Revenge Collection',
#  'Hellraiser Collection',
#  'Help, I Shrunk My...',
#  'Henry Fool Collection',
#  'Hentai Kamen Collection',
#  'Hera Pheri Collection',
#  'Herbie Collection',
#  'Hercule Poirot Collection',
#  'Herr Lehmann Filmreihe',
#  'Hey Arnold Movie Collection',
#  'Hideshi Hinos Theater of Horror',
#  'High School Musical Collection',
#  'High Strung Collection',
#  'High&Low The Movie Collection',
#  'Highlander Collection',
#  'Hitman Collection',
#  'Hobbs & Shaw Collection',
#  'Hollow Man Collection',
#  'Home Alone Collection',
#  'Honest Candidate Collection',
#  'Honey Collection',
#  'Hoodwinked! Collection',
#  'Hooked Collection',
#  'Horrible Bosses Collection',
#  'Horror Stories Collection',
#  'Hostel Collection',
#  'Hot Tub Time Machine Collection',
#  'Hotel Inferno Collection',
#  'Hotel Transylvania Collection',
#  'House of the Dead Collection',
#  'Housefull Collection',
#  'How High Collection',
#  'How to Train Your Dragon Collection',
#  'Howard Lovecraft Collection',
#  'Howling Village',
#  'Huevos - Collection',
#  'Hunter x Hunter Collection',
#  'Hurricane Bianca Collection',
#  'I Am Legend Collection',
#  'I Am Vengeance Collection',
#  'I Can Quit Whenever I Want Collection',
#  'I Give You My Word Collection',
#  'I Got Five on It Collection',
#  'I Got the Hook Up Collection',
#  'I Love Hong Kong Collection',
#  'I Spit on Your Grave (Original) Collection',
#  'I Spit on Your Grave Collection',
#  'Ice Age Collection',
#  'Ice Collection',
#  'Iceman Collection',
#  'If You Are the One (Collection)',
#  'Il peggio della mia vita',
#  'Immaturi Collection',
#  'Impy Collection',
#  'In the Name of the King Collection',
#  'Inadequate People Collection',
#  'Independence Day Collection',
#  'Indian Gangster Trilogy',
#  'Indiana Jones Collection',
#  'Infernal Affairs Collection',
#  'Initial D',
#  'Inmu',
#  'Inside Man Collection',
#  'Insidious Collection',
#  'Into the Blue Collection',
#  'Inuyasha Collection',
#  'Ip Man Collection',
#  'Iqbal (Samling)',
#  'Iris Collection',
#  'Iron Girl Collection',
#  'Iron Man Collection',
#  'Iron Sky Collection',
#  'Ironclad Collection',
#  'It Collection',
#  'Ivan Tsarevich & the Grey Wolf Collection',
#  'Jack Reacher Collection',
#  'Jack in the Box Collection',
#  'Jack vs. Collection',
#  'Jacqueline Mazerin Collection',
#  'James Bond Collection',
#  'Jan Dara',
#  'Jannat Collection',
#  'Jarhead Collection',
#  'Jarle Klepp-trilogien',
#  'Jay and Silent Bob Collection',
#  'Jeepers Creepers Collection',
#  'Jet Set - Saga',
#  'Jiivi Collection',
#  'Jim Button Collection',
#  'Jism Collection',
#  'Joan of Arc Collection',
#  'Jodorowskys film autobiography',
#  'Joe Dirt Collection',
#  'John Wick Collection',
#  'Johnny 100 Pesos Collection',
#  'Johnny English Collection',
#  'Joséphine - Saga',
#  'Journey Collection',
#  'Journey to the West Collection',
#  'Joy Ride Collection',
#  'Ju-on Collection',
#  'Judwaa Collection',
#  'Julemandens Datter (Samling)',
#  'Jumanji Collection',
#  'Jump Street Collection',
#  'Jungle Cruise Collection',
#  'Jungle Jack Collection',
#  'Jurassic Park Collection',
#  'Jurassic Shark Collection',
#  'Justice League (DC Universe Animated) Collection',
#  'K-9 Adventures Collection',
#  'K.G.F Collection',
#  'KAIJI Collection',
#  'Kaguya-sama: Love is War - Collection',
#  'Kahaani Collection',
#  'Kaithi Collection',
#  'Kakegurui: The Movie',
#  'Kamen Rider (1971) Collection',
#  'Kamen Rider Agito Collection',
#  'Kamen Rider Amazons Collection',
#  'Kamen Rider Decade Collection',
#  'Kamen Rider OOO Collection',
#  'Kamen Rider The First Collection',
#  'Kamen Rider W Collection',
#  'Kandasamys Collection',
#  'Kangaroo Jack Collection',
#  'Karla Collection',
#  'Kartoffelsalat Filmreihe',
#  'Kazuo Umezus Horror Theater Collection',
#  'Keinohrhasen Filmreihe',
#  'Kekko Kamen Collection',
#  'Keluarga Cemara Collection',
#  'Kibakichi Collection',
#  'Kick-Ass Collection',
#  'Kickboxer (Reboot) Collection',
#  'Kids Return',
#  'Kidulthood Collection',
#  'Kill Bill Collection',
#  'Kill Buljo Collection',
#  'Killer Shrews Collection',
#  'Killing Cabos Collection',
#  'Killjoy Collection',
#  'Kindergarten Cop Collection',
#  'King Naresuan Collection',
#  'King of Guns Collection',
#  'Kingsman Collection',
#  'Kirikou Collection',
#  'Kizumonogatari',
#  'Klovn (filmene)',
#  'Knerten Collection',
#  'Knights of the Damned Collection',
#  'Knives Out Collection',
#  'Knocked Up Collection',
#  'Knutsen & Ludvigsen Collection',
#  'Kocan Kadar Konuş [Seri]',
#  'Koko Collection',
#  'Kolah Ghermezi',
#  'Krampus Collection',
#  'Krrish Collection',
#  'Kung Fu Masters Collection',
#  'Kung Fu Panda Collection',
#  'Kung Fu Traveler Collection',
#  'Kuntilanak Collection',
#  'Kuroko no Basket: Winter Cup Soushuuhen Collection',
#  'Kuroshithuji Collection',
#  'Kutsal Damacana [Seri]',
#  'Kvartet I Collection',
#  'Köstebekgiller [Seri]',
#  'L.O.R.D Collection',
#  'LEGO DC Comics Super Heroes Collection',
#  'LEGO DC Super Hero Girls Collection',
#  'LEGO: Hero Factory - Saga',
#  'LUPIN THE IIIRD Collection',
#  'La Abuela Collection',
#  'La Soga Collection',
#  'La befana vien di notte',
#  'La niña de tus ojos - Colección',
#  'Lady Ninja Kasumi Series',
#  'Laid To Rest Collection',
#  'Lake Fear Collection',
#  'Lan Kwai Fong Collection',
#  'Lapland Odyssey Collection',
#  'Largo Winch Collection',
#  'Las Leyendas Collection',
#  'LasseMajas Detektivbyrå (samling)',
#  'Laughing Gor（系列）',
#  'Lauras Stern',
#  'Lazer Team Collection',
#  'League of Gods',
#  'Leap collection',
#  'Left Behind Collection',
#  'Legally Blonde Collection',
#  'Legend of a Rabbit Collection',
#  'Lemon Popsicle Collection',
#  'Leprechaun Collection',
#  'Les Crevettes pailletées - Saga',
#  'Les Petits Mouchoirs - Saga',
#  'Lesní trilogie (kolekce)',
#  'Lesson of the Evil Collection',
#  'Let Him Be a Basketball Player Collection',
#  'Lethal Kittens Collection',
#  'Letters to Santa Collection',
#  'Lezioni di Cioccolato Collection',
#  'Liar Game Collection',
#  'Library Wars Collection',
#  'Lights Out Collection',
#  'Like Mike Collection',
#  'Like a Dragon Collection',
#  'Lilly the Witch Collection',
#  'Lilo & Stitch Collection',
#  'Line Walker Collection',
#  'Little Bear',
#  'Little Book of Love Collection',
#  'Little Forest Collection',
#  'Little Nicholas Trilogy',
#  'Little Witch Academia Collection',
#  'Live. Die. Repeat Collection',
#  'Living Dead Collection',
#  'Long Long Time Ago',
#  'Loro Collection',
#  'Los crímenes del sur',
#  'Lost Collection',
#  'Lotte Collection',
#  'Louis & Luca Collection',
#  'Love Comes Softly Collection',
#  'Love For Sale Collection',
#  'Love Stories 2 Series',
#  'Love Stories Series',
#  'Love Undercover Collection',
#  'Love in a... Collection',
#  'Love in the City Collection',
#  'Lovey-Dovey Collection',
#  'Lucifer Collection',
#  'Lucy Collection',
#  'L♥DK',
#  'MVP',
#  'Maari Collection',
#  'Machete Collection',
#  'Machine Girl Collection',
#  'Macross Frontier Collection',
#  'Mad Max Collection',
#  'Madagascar Collection',
#  'Made in Abyss Collection',
#  'Madea - Collection',
#  'Magic Carpet Ride Collection',
#  'Magic Mike Collection',
#  'Magic Silver Collection',
#  'Magical Girl Lyrical Nanoha Collection',
#  'Major Korenev Trilogy',
#  'Major Mahadevan Collection',
#  'Make Me Shudder',
#  'Maleficent Collection',
#  'Malevolence Collection',
#  'Malibu Rescue Collection',
#  'Mall Cop Collection',
#  'Mamma Mia! Collection',
#  'Man and a Baby Collection',
#  'Man of Steel Collection',
#  'Mandie Movies Collection',
#  'Mang Kepweng Collection',
#  'Mann Filmreihe',
#  'Manos Collection',
#  'Manual of Love Collection',
#  'Manyeo The Witch Collection',
#  'Mapado Collection',
#  'March Comes in Like a Lion Collection',
#  'Mardaani Collection',
#  'Mardock Scramble Collection',
#  'Marfa Girl Collection',
#  'Maria, ihm schmeckts nicht! Filmreihe',
#  'Mariachi Collection',
#  'Marley & Me Collection',
#  'Marrying the Mafia Collection',
#  'Mary Poppins Collection',
#  'Maskeli Beşler [Seri]',
#  'Masquerade Hotel Collection',
#  'Masti Collection',
#  'Mata Batin Collection',
#  'Max Collection',
#  'Max Havoc Collection',
#  'Max Pinlig Collection',
#  'May the Devil Take You',
#  'Maya the Bee Collection',
#  'McDull Collection',
#  'Mean Girls Collection',
#  'Meat pie collection',
#  'Meatball Machine Collection',
#  'Mechanic Collection',
#  'Meet the Blacks Collection',
#  'Meet the In-Laws',
#  'Meet the Parents Collection',
#  'Mega Shark Collection',
#  'Megalodon Collection',
#  'Mektoub is Mektoub',
#  'Memoirs of a Lady Ninja Series',
#  'Men & Women Dilogy',
#  'Men In Black Collection',
#  'Men Suddenly in Black Collections',
#  'Men in the City Collection',
#  'Methagu Collection',
#  'Mexico Barbaro Filmreihe',
#  'Mi Nismo Anđeli Collection',
#  'Midnight Diner Collection',
#  'Mince Alors ! - Saga',
#  'Minions Collection',
#  'Minuscule Collection',
#  'Mirror Mirror Collection',
#  'Mirrors Collection',
#  'Mischievous Kiss The Movie',
#  'Miss Congeniality Collection',
#  'Miss Modern Collection',
#  'Mission: Impossible Collection',
#  'Mister Twister Collection',
#  'Mobile Suit Gundam Thunderbolt Collection',
#  'Mobile Suit Gundam: The Origin Collection',
#  'Mobile Suit Zeta Gundam A New Translation',
#  'Mojin Collection',
#  'Molly Hartley Collection',
#  'Monica and Friends',
#  'Monster Family Collection',
#  'Monster High Collection',
#  'Monster Hunt Collection',
#  'Monsters Collection',
#  'Monsters, Inc. Collection',
#  'Moontrap Collection',
#  'Mortadelo y Filemón - Colección',
#  'Mortal Kombat Collection',
#  'Mortal Kombat Legends Collection',
#  'Moschettieri del Re - Collezione',
#  'Mountain Collection',
#  'Mr. Bean Collection',
#  'Mr. Bones Collection',
#  'Mr. Ripley Collection',
#  'Mucize [Seri]',
#  'Mummys Kiss Collection',
#  'Munafik Trilogy',
#  'Muni Collection',
#  'Munna Bhai Collection',
#  'Murder Collection',
#  'Murder Mystery Collection',
#  'Mushishi Collection',
#  'My Alien Girlfriend Collection',
#  'My Big Fat Greek Wedding Collection',
#  'My Boss, My Collection',
#  'My Brother Series',
#  'My Friends Sister Series',
#  'My Hero Academia Collection',
#  'My Little Pony: Equestria Girls Collection',
#  'My Mom is a Character Collection',
#  'My Sassy Girl Collection',
#  'My Sisters Kids (Remake) Collection',
#  'My Stupid Boss',
#  'My Thoughts Are Silent Collection',
#  'My Wife Is Collection',
#  'My Wife is a Gangster Collection',
#  'Mystery Road Collection',
#  'Mythica Collection',
#  'N.T.R Collection',
#  'NASU Collection',
#  'NKCTHI Collection',
#  'Naked Collection',
#  'Naked Fear Collection',
#  'Naked Poison Collection',
#  'Namastey London Collection',
#  'Nana Collection',
#  'Nanny McPhee Collection',
#  'Naruto Collection',
#  'National Lampoons Van Wilder Collection',
#  'National Treasure Collection',
#  'Nativity Collection',
#  'Necromancer',
#  'Neighbors Collection',
#  'Nemesis Collection',
#  'Neuilly sa mère ! - Saga',
#  'Never Back Down Collection',
#  'Never Died Collection',
#  'New Gods Collection',
#  'New Initial D Collection',
#  'New Kids Collection',
#  'New Money Collection',
#  'New Queer Visions Collection',
#  'New World Order Collection',
#  'Nice Sister-In-Law Series',
#  'Night at the Museum Collection',
#  'Night of the Demons Collection',
#  'Night of the Living Dead 3D - Collection',
#  'Nightmare Collections',
#  'Niko Collection',
#  'Nims Island Collection',
#  'Ninja Collection',
#  ...]

# %%
#make a mapper dictionary
collection_ints = range(len(unique_collection))
collection_map = dict(zip(unique_collection, collection_ints))
collection_map
# Out:
# {'#TemanTapiMenikah': 0,
#  '... Cameras Collection': 1,
#  '.hack Collection': 2,
#  '10 giorni... - Collezione': 3,
#  '100 Girls Collection': 4,
#  '100% Coco Collection': 5,
#  '101 Dalmatians (Live-Action) Collection': 6,
#  '12 Dogs of Christmas Collection': 7,
#  '12 Rounds Collection': 8,
#  '12 Westerns in 12 Months Collection': 9,
#  '14+ (Коллекция)': 10,
#  '1920 Collection': 11,
#  '1981 Collection': 12,
#  '2 Days In... Collection': 13,
#  '2001 Maniacs Collection': 14,
#  '20th Century Boys Collection': 15,
#  '28 Days/Weeks Later Collection': 16,
#  '3 A.M. Collection': 17,
#  '3 Braves Universe': 18,
#  '3 Little Pigs collection': 19,
#  '30 Days of Night Collection': 20,
#  '300 Collection': 21,
#  '365 Days Collection': 22,
#  '47 Meters Down Collection': 23,
#  '47 Ronin Collection': 24,
#  '64 Collection': 25,
#  '666 Collection': 26,
#  '8 свиданий (Коллекция)': 27,
#  'A California Christmas Collection': 28,
#  'A Chinese Odyssey Collection': 29,
#  'A Christmas Prince Collection': 30,
#  'A Doggone Collection': 31,
#  'A Dogs Purpose Collection': 32,
#  'A Few Best Men Collection': 33,
#  'A Frozen Christmas Collection': 34,
#  'A Haunted House Collection': 35,
#  'A Man and a Woman Collection': 36,
#  'A Menina que Matou os Pais': 37,
#  'A Meowy Collection': 38,
#  'A Monkeys Tale': 39,
#  'A Quiet Place Collection': 40,
#  'A Second Chance Collection': 41,
#  'A Very Special Love Collection': 42,
#  'ABCD Collection': 43,
#  'AMV Hell': 44,
#  'ARCHIE Collection': 45,
#  'AVP Collection': 46,
#  'Aadu Collection': 47,
#  'Aashiqui Collection': 48,
#  'Ab Tak Chhappan Collection': 49,
#  'About Love Collection': 50,
#  'Accident Man Collection': 51,
#  'Achtung, fertig Filmreihe': 52,
#  'Ada Apa Dengan Cinta? Collection': 53,
#  'Admiral Yi': 54,
#  'Adventures of Bailey Collection': 55,
#  'After Collection': 56,
#  'Against the Wild Collection': 57,
#  'Agent Cody Banks Collection': 58,
#  'Ah Boys to Men Collection': 59,
#  'Aileen Wuornos Collection': 60,
#  'Ajin Collection': 61,
#  'Akihabara Trilogy': 62,
#  'Aladdin (Live-Action) Collection': 63,
#  'Aldo Giovanni e Giacomo Collection': 64,
#  'Alex Cross Collection': 65,
#  'Algjör Sveppi': 66,
#  'Alice in Wonderland Collection': 67,
#  'Alien Factor Collection': 68,
#  'Alien Sex Files': 69,
#  'Aliens Ate My Homework Collection': 70,
#  'All Hallows Eve Collection': 71,
#  'All for ...': 72,
#  'Alligator Ladies Collection': 73,
#  'Alls Well, Ends Well': 74,
#  'Almighty Collection': 75,
#  'Alone in the Dark Collection': 76,
#  'Along Came the Devil Collection': 77,
#  'Along with the Gods Collection': 78,
#  'Alpha and Omega Collection': 79,
#  'Alvin and the Chipmunks Collection': 80,
#  'Always: Sunset on Third Street Collection': 81,
#  'Amateur Porn Star Killer Collection': 82,
#  'Ambra Collection': 83,
#  'American Civil War Collection': 84,
#  'American Guinea Pig Collection': 85,
#  'American Pie Collection': 86,
#  'American Poltergeist': 87,
#  'American Psycho Collection': 88,
#  'Amityville Scarecrow Collection': 89,
#  'An American Girl Collection': 90,
#  'Anaconda Collection': 91,
#  'Analyze Collection': 92,
#  'Anatomy Collection': 93,
#  'Anatomy of an Antihero Collection': 94,
#  'Anchorman Collection': 95,
#  'Android Kunjappan Collection': 96,
#  'Anděl Páně (kolekce)': 97,
#  'Ang Tanging Ina Collection': 98,
#  'Angelas Christmas Collection': 99,
#  'Animal Collection': 100,
#  'Anja & Viktor Collection': 101,
#  'Annabelle Collection': 102,
#  'Annika Bengtzon Collection': 103,
#  'Annika Bengtzon Collection (Helena Bergström)': 104,
#  'Another Gay Movie Collection': 105,
#  'Ant-Man Collection': 106,
#  'Antboy Collection': 107,
#  'Antelope Valley Collection': 108,
#  'Antisocial Collection': 109,
#  'Ants in the Pants Collection': 110,
#  'Apocalypse Collection': 111,
#  'Appleseed Collection': 112,
#  'Aqua Teen Hunger Force Colon Movie Film for Theaters Collection': 113,
#  'Aquaman Collection': 114,
#  'Arabian Nights Collection': 115,
#  'Aranmanai Collection': 116,
#  'Ardaas Collection': 117,
#  'Argo Collection': 118,
#  'Armored Trooper VOTOMS Collection': 119,
#  'Armour of God Collection': 120,
#  'Army of the Dead Collection': 121,
#  'Arn Collection': 122,
#  'Arpeggio of blue steel': 123,
#  'Art of the Devil Collection': 124,
#  'Arthur and the Invisibles Collection': 125,
#  'Ash Lad Collection': 126,
#  'Ashens Collection': 127,
#  'Ask Me Anything Collection': 128,
#  'Assassination Classroom Collection': 129,
#  'Asterix & Obelix Collection': 130,
#  'Asterix and Obelix (Animation) Collection': 131,
#  'Atlantic Rim Collection': 132,
#  'Atlantis Collection': 133,
#  'Atlas Shrugged Collection': 134,
#  'Atomic Blonde Collection': 135,
#  'Attack on Titan (Anime) Collection': 136,
#  'Attack on Titan Collection': 137,
#  'Attack the Block Collection': 138,
#  'Attack the Gas Station Collection': 139,
#  'Attraction Collection': 140,
#  'Austin Powers Collection': 141,
#  'Avatar Collection': 142,
#  'Avenger Dogs': 143,
#  'Avengers Grimm Collection': 144,
#  'Avunu Collection': 145,
#  'Aşk Tesadüfleri Sever [Seri]': 146,
#  'Baaghi Collection': 147,
#  'Baahubali Collection': 148,
#  'Baby Driver Collection': 149,
#  'Baby Geniuses Collection': 150,
#  'Babysitting Collection': 151,
#  'Bad Ass Collection': 152,
#  'Bad Ben Collection': 153,
#  'Bad Boys Collection': 154,
#  'Bad Kids Collection': 155,
#  'Bad Moms Collection': 156,
#  'Bad Santa Collection': 157,
#  'Balala the Fairies series': 158,
#  'Bamse Collection': 159,
#  'BanG Dream! Episode of Roselia Collection': 160,
#  'Bang Rajan Collection': 161,
#  'Barbershop Collection': 162,
#  'Barbie & Kendra Collection': 163,
#  'Barbie Mariposa Collection': 164,
#  'Basic Instinct Collection': 165,
#  'Batman (DC Universe Animated) Collection': 166,
#  'Batman Animation Collection (Adam West)': 167,
#  'Batman: The Long Halloween Collection': 168,
#  'Battle Royale Collection': 169,
#  'Battle of the Brides': 170,
#  'Bayside Shakedown Collection': 171,
#  'Baztan Trilogy': 172,
#  'Be My Slave Collection': 173,
#  'Bearcity Collection': 174,
#  'Before... Collection': 175,
#  'Behind Enemy Lines Collection': 176,
#  'Belle & Sebastian': 177,
#  'Benvenuti al... Collection': 178,
#  'Benvenuto Presidente - Collezione': 179,
#  'Benyamin The Troublemaker': 180,
#  'Bernie the Dolphin Collection': 181,
#  'Berserk: Golden Age Arc Collection': 182,
#  'Best Exotic Marigold Hotel Collection': 183,
#  'Best F(r)iends Collection': 184,
#  'Beverly Hills Chihuahua Collection': 185,
#  'Bhai - Vyakti ki Valli': 186,
#  'Bheja Fry Collection': 187,
#  'Bhoothnath Collection': 188,
#  'Bibi & Tina Collection': 189,
#  'Bibi Blocksberg Collection': 190,
#  'Big Brother Collection': 191,
#  'Big Fat Liar Collection': 192,
#  'Big Mommas House Collection': 193,
#  'Bigfoot Collection': 194,
#  'Bill & Teds Most Excellent Collection': 195,
#  'Bird Box Collection': 196,
#  'Birdemic Collection': 197,
#  'Black & White Collection': 198,
#  'Black Panther Collection': 199,
#  'Black Water Collection': 200,
#  'Blade Collection': 201,
#  'Blade Runner Collection': 202,
#  'Blair Witch Collection': 203,
#  'Bleach Collection': 204,
#  'Blood Feast Collection': 205,
#  'BloodRayne Collection': 206,
#  'Bloodbath at Pinky High Collection': 207,
#  'Bloodshot Collection': 208,
#  'Bloody Chainsaw Girl Collection': 209,
#  'Blue Crush Collection': 210,
#  'BoBoiBoy Collection': 211,
#  'Bob The Cat Collection': 212,
#  'Bon Bini Holland Collectie': 213,
#  'Bon Cop Bad Cop Collection': 214,
#  'Bonded by Blood Collection': 215,
#  'Boon Collection': 216,
#  'Boonie Bears Collection': 217,
#  'Borat Moviefilms Collection': 218,
#  'Borgríki Collection': 219,
#  'Boule & Bill': 220,
#  'Bound Heat': 221,
#  'Boys Life (Collection)': 222,
#  'Bratz Collection': 223,
#  'Brice Collection': 224,
#  'Bridget Jones Collection': 225,
#  'Brigada Z Collection': 226,
#  'Bright Collection': 227,
#  'Bring It On Collection': 228,
#  'Broken Blade Collection': 229,
#  'Brother Bear Collection': 230,
#  'Brother Collection': 231,
#  'Brotherhood of Blades Collection': 232,
#  'Bulletproof Collection': 233,
#  'Bunker of Blood Collection': 234,
#  'Bunnyman Collection': 235,
#  'Bunty Aur Babli': 236,
#  'Buppah Ratree Collection': 237,
#  'Burg Schreckenstein Filmreihe': 238,
#  'Burnout Collection': 239,
#  'Burnt by the Sun Trilogy': 240,
#  'Cabin Fever Collection': 241,
#  'Caesar and Otto Collection': 242,
#  'Cal Collection': 243,
#  'Camp Blood Collection': 244,
#  'Camping Collection': 245,
#  'Candyman Collection': 246,
#  'Captain America Collection': 247,
#  'Captain Marvel Collection': 248,
#  'Captain Underpants Collection': 249,
#  'Cardcaptor Sakura Collection': 250,
#  'Carmina - Colección': 251,
#  'CarousHELL Collection': 252,
#  'Carpenter Andersen Collection': 253,
#  'Cars Collection': 254,
#  'Carters Collection': 255,
#  'Carved Collection': 256,
#  'Casper and Emma Collection': 257,
#  'Cat Run Collection': 258,
#  'Cats & Dogs Collection': 259,
#  'Cattle Hill Collection': 260,
#  'Cementerio General Collection': 261,
#  'Center Stage Collection': 262,
#  'Charlies Angels Collection': 263,
#  'Charter Trips': 264,
#  'Chasing The Dragon Collection': 265,
#  'Che Collection': 266,
#  'Cheaper by the Dozen (2003) Collection': 267,
#  'Cheech & Chong Collection': 268,
#  'Cherry Blossoms': 269,
#  'Chhakka Panja Collection': 270,
#  'Chicken Run Collection': 271,
#  'Chief Daddy Collection': 272,
#  'Chihayafuru Collection': 273,
#  'Children of the Corn Collection': 274,
#  'Childs Play Collection': 275,
#  'Chili Palmer Collection': 276,
#  'Chocolate City Collection': 277,
#  'Christmas Thieves (Collection)': 278,
#  'Christmas with a Prince Collection': 279,
#  'Chronicle Collection': 280,
#  'Cinderella Story Collection': 281,
#  'Cities of Love Collection': 282,
#  'Clash of the Titans Collection': 283,
#  'Class Reunion Collection': 284,
#  'Clerks Collection': 285,
#  'Clint Eastwoods Iwo Jima Collection': 286,
#  'Cloudy with a Chance of Meatballs Collection': 287,
#  'Clubhouse Detectives Collection': 288,
#  'Coconut The Little Dragon Collection': 289,
#  'Code Geass: Akito the Exiled': 290,
#  'Code Geass: Lelouch of the Rebellion Recap Film Trilogy': 291,
#  'Cold Prey Collection': 292,
#  'Cold Pursuit Collection': 293,
#  'Cold War Collection': 294,
#  'Coletânea Nada a Perder': 295,
#  'Come un gatto in tangenziale - Collezione': 296,
#  'Coming to America Collection': 297,
#  'Commander Kellie & the Superkids Collection': 298,
#  'Commando Collection': 299,
#  'Confession Executive Committee (Series)': 300,
#  'Confidential Assignment': 301,
#  'Contracted Collection': 302,
#  'Corky St. Clair Collection': 303,
#  'Corpse Party Collection': 304,
#  'Corpse Prison Collection': 305,
#  'Corto Maltese Collection': 306,
#  'Cowboy Filmreihe': 307,
#  'Crackerjack Collection': 308,
#  'Crank Collection': 309,
#  'Crayon Shin-chan Collection': 310,
#  'Crazy Rich Asians Collection': 311,
#  'Crazy Wedding Collection': 312,
#  'Creed Collection': 313,
#  'Creep Collection': 314,
#  'Crimes of Passion: The Maria Lang Collection': 315,
#  'Crocodile Collection': 316,
#  'Crocodile Dundee Collection': 317,
#  'Cross Collection': 318,
#  'Crouching Tiger, Hidden Dragon Collection': 319,
#  'Crows Collection': 320,
#  'Cruella Collection': 321,
#  'Cube Collection': 322,
#  'Cuccioli - Collezione': 323,
#  'Curious George Collection': 324,
#  'Cyborg 009 Collection': 325,
#  'DAU Cinema': 326,
#  'Dabangg Collection': 327,
#  'Dabbe [Seri]': 328,
#  'Daddy Day Camp Collection': 329,
#  'Daddys Home Collection': 330,
#  'Danur Collection': 331,
#  'Dark Planet Collection': 332,
#  'Dark Woods Collection': 333,
#  'Dark World Collection': 334,
#  'Darko Collection': 335,
#  'Darling Collection': 336,
#  'Darna Hai Collection': 337,
#  'Dawn of the Dragonslayer Collection': 338,
#  'De Club van Sinterklaas': 339,
#  'De Pernas Pro Ar - Coleção': 340,
#  'De forbandede år (samling)': 341,
#  'Dead Rising Collection': 342,
#  'Dead River Collection': 343,
#  'Dead Snow Collection': 344,
#  'Dead or Alive Collection': 345,
#  'Deadlands Collection': 346,
#  'Deadly Prey Collection': 347,
#  'Deadpool Collection': 348,
#  'Deadtime Stories': 349,
#  'Dear God No!': 350,
#  'Death Bell Collection': 351,
#  'Death Forest Collection': 352,
#  'Death Note Collection': 353,
#  'Death Race Collection': 354,
#  'Deco Truck Gal Nami': 355,
#  'Decoys Collection': 356,
#  'Deep Blue Sea Collection': 357,
#  'Deep Sea Monster Raiga Collection': 358,
#  'Demon Slayer': 359,
#  'Den of Thieves Collection': 360,
#  'Den som dræber': 361,
#  'Department Q Collection': 362,
#  'Der kleine Rabe Socke Filmreihe': 363,
#  'Despicable Me Collection': 364,
#  'Detective Chinatown Collection': 365,
#  'Detective Conan Collection': 366,
#  'Detective Dee Collection': 367,
#  'Detective K Collection': 368,
#  'Detective bureau nr. 2': 369,
#  'Detective in the Bar': 370,
#  'Deuce Bigalow Collection': 371,
#  'Devi Collection': 372,
#  'Devil in the Flesh': 373,
#  'Dhamaal Collection': 374,
#  'Dhoom Collection': 375,
#  'Diabolik - Collezione': 376,
#  'Diary of a Wimpy Kid (Animated) Collection': 377,
#  'Diary of a Wimpy Kid Collection': 378,
#  'Die Hard Collection': 379,
#  'Die Vampirschwestern Collection': 380,
#  'Digimon Adventure tri. Collection': 381,
#  'Digimon Collection': 382,
#  'Dilan': 383,
#  'Diplomat Kosaku Kuroda': 384,
#  'Dirty Dancing Collection': 385,
#  'District 13 Collection': 386,
#  'Divergent Collection': 387,
#  'Divã: Coleção': 388,
#  'Doctor Strange Collection': 389,
#  'Dolemite Collection': 390,
#  'Dolphin Tale Collection': 391,
#  'Don Collection': 392,
#  'Doom Collection': 393,
#  'Doraemon Collection': 394,
#  'Dorm Daze Collection': 395,
#  'Dostana Collection': 396,
#  'Downton Abbey Collection': 397,
#  'Dr. Dolittle Collection': 398,
#  'Dracula 2000 Collection': 399,
#  'Dragon Ball Super Collection': 400,
#  'Dragon Inn': 401,
#  'Dragon Loaded Collection': 402,
#  'Dragon Nest Collection': 403,
#  'DragonHeart Collection': 404,
#  'Drishya Collection': 405,
#  'Drishyam Collection': 406,
#  'Drumline - Collection': 407,
#  'Drushyam Collection': 408,
#  'Ducobu Collection': 409,
#  'Dulhania Collection': 410,
#  'Dumb and Dumber Collection': 411,
#  'Dummie the Mummy Collection': 412,
#  'Dune Collection': 413,
#  'Dungeons & Dragons Collection': 414,
#  'Dynamic Pro Super Robot Collection': 415,
#  'Eagle Talon Collection': 416,
#  'Easy Money Collection': 417,
#  'Easy Rider Collection': 418,
#  'Eating Out Collection': 419,
#  'Eberhofer': 420,
#  'Eden of the East Collection': 421,
#  'Eight Ranger Collection': 422,
#  'El Bosque Animado': 423,
#  'El Crack Collection': 424,
#  'El Gezira Collection': 425,
#  'Election Collection': 426,
#  'Elektra Luxx Collection': 427,
#  'Elias the Little Rescue Boat Collection': 428,
#  'Elite Squad Collection': 429,
#  'Elizabeth Collection': 430,
#  'Ella and Friends Collection': 431,
#  'Ellembi Series': 432,
#  'Elling Collection': 433,
#  'Elvira Collection': 434,
#  'Emmanuelle Through Time Collection': 435,
#  'Enchanted Collection': 436,
#  'Enola Holmes Collection': 437,
#  'Erkan & Stefan Collection': 438,
#  'Escape Plan Collection': 439,
#  'Escape Room Collection': 440,
#  'Essex Boys': 441,
#  'Eureka Seven Hi-Evolution Collection': 442,
#  'Euthanizer Collection': 443,
#  'Evil Bong Collection': 444,
#  'Evil Dead Collection': 445,
#  'Ex Collection': 446,
#  'Ex-Files': 447,
#  'Extraction Collection': 448,
#  'Eye of the Dolphin Collection': 449,
#  'F*ck You, Goethe Collection': 450,
#  'Faces of Dying Collection': 451,
#  'Fairy Tail Collection': 452,
#  'Fallen': 453,
#  'Familien Jul (Samling)': 454,
#  'Famous Five Collection': 455,
#  'Fantastic Beasts Collection': 456,
#  'Fantastic Four Collection': 457,
#  'Fantastic Journey To Oz': 458,
#  'Fat Pizza Collection': 459,
#  'Fate/Stay Night: Heavens Feel Collection': 460,
#  'Father and Guns Collection': 461,
#  'Father of Four Collection': 462,
#  'Fear PHarm Collection': 463,
#  'Fear Street Collection': 464,
#  'Feast Collection': 465,
#  'Felix the Rabbit Collection': 466,
#  'Feluda Collection': 467,
#  'Female Ninjas Magic Chronicles Collection': 468,
#  'Femalien Collection': 469,
#  'Fifty Shades Collection': 470,
#  'Filthy McNasty Collection': 471,
#  'Fimfárum': 472,
#  'Final Destination Collection': 473,
#  'Final Fantasy VII Collection': 474,
#  'Finding Jesus Collection': 475,
#  'Finding Mr. Right Collection': 476,
#  'Finding Nemo Collection': 477,
#  'Firefly Collection': 478,
#  'First Lady Collection': 479,
#  'Fishermans Friends Collection': 480,
#  'Fishtales Collection': 481,
#  'Fist of the North Star: The Legends of the True Savior': 482,
#  'Flicka Collection': 483,
#  'Flower and Snake (Remake) Collection': 484,
#  'Fool for Love': 485,
#  'Forbidden Fruit Collection': 486,
#  'Force Collection': 487,
#  'Fortress Collection': 488,
#  'Four Sisters and a Wedding Collection': 489,
#  'Four Taxidrivers and a Dog Collection': 490,
#  'Franklin Collection': 491,
#  'Free Guy Collection': 492,
#  'Free!': 493,
#  'Freedom Trilogy': 494,
#  'Freier Fall Collection': 495,
#  'French Fried Vacation': 496,
#  'Friday Collection': 497,
#  'Friday the 13th Collection': 498,
#  'Friend Collection': 499,
#  'Fright Night (Reboot) Collection': 500,
#  'From Vegas to Macau Collection': 501,
#  'Frozen Collection': 502,
#  'Fubar Collection': 503,
#  'Fuerzas Especiales Collection': 504,
#  'Fuga de cerebros - Collection': 505,
#  'Fukrey Collection': 506,
#  'Full Out Collection': 507,
#  'Fullmetal Alchemist Collection': 508,
#  'G.I. Joe (Live-Action) Collection': 509,
#  'G.O.R.A. Collection': 510,
#  'GALILEO collection': 511,
#  'Gabriels Inferno Collection': 512,
#  'Gamera (Heisei) Collection': 513,
#  'Gang of Roses Collection': 514,
#  'Gangs of Wasseypur Collection': 515,
#  'Gantz Collection': 516,
#  'Garfield Collection': 517,
#  'Gatao Collection': 518,
#  'Gautas Iškvietimas Collection': 519,
#  'Gen-X Cops Collections': 520,
#  'Geniş Aile [Seri]': 521,
#  'Gett Collection': 522,
#  'Ghayal Collection': 523,
#  'Ghost In The Shell: Arise Collection': 524,
#  'Ghost Rider Collection': 525,
#  'Ghost Shark Collection': 526,
#  'Ghost in the Shell (Animated) Collection': 527,
#  'Ghostbusters Collection': 528,
#  'Ginger Snaps Collection': 529,
#  'Gintama Collection': 530,
#  'Gintama Movie Collection': 531,
#  'Girls & Panzer Filmreihe': 532,
#  'Girls on Top Collection': 533,
#  'Glass Tiger collection': 534,
#  'Gloria Duque - Colección': 535,
#  'Gnomeo & Juliet Collection': 536,
#  'Go For Broke Collection': 537,
#  'Go Goa Gone Collection': 538,
#  'Go Lala Go Collection': 539,
#  'Go! Go! Cory Carson Collection': 540,
#  'Goal! Collection': 541,
#  'Goat Story Collection': 542,
#  'God of Gamblers Collection': 543,
#  'Gods Not Dead Collection': 544,
#  'Godzilla (Millennium) Collection': 545,
#  'Godzilla Anime Trilogy': 546,
#  'Godzilla Collection': 547,
#  'Goenda Shabor Collection': 548,
#  'Gogol Collection': 549,
#  'Golden Chicken Collection': 550,
#  'Golden Winter Collection': 551,
#  'Golmaal Collection': 552,
#  'Gomez & Tavarès Collection': 553,
#  'Gonin Collection': 554,
#  'Good Take Collection': 555,
#  'Gooische Vrouwen Collection': 556,
#  'Goon Collection': 557,
#  'Goosebumps Collection': 558,
#  'Grave Encounters Collection': 559,
#  'Green Street Hooligans Collection': 560,
#  'Greenland Collection': 561,
#  'Grindsploitation Collection': 562,
#  'Grizzly Collection': 563,
#  'Groundhog Dave Collection': 564,
#  'Grown Ups Collection': 565,
#  'Guardians of the Galaxy Collection': 566,
#  'Gukga daepyo Collection': 567,
#  'Gumball 3000 Collection': 568,
#  'Gundala': 569,
#  'Gundam Reconguista in G Collection': 570,
#  'Gunpowder Milkshake Collection': 571,
#  'Gwendolyn Shepherd Collection': 572,
#  'HIT: Cases Collection': 573,
#  'Hababam Sınıfı [Seri]': 574,
#  'Habibie & Ainun Collection': 575,
#  'Haikyu!! - Movie Collection': 576,
#  'Hakuouki Movie Collection': 577,
#  'Half Past Dead Collection': 578,
#  'Halloween (Rob Zombie Series) Collection': 579,
#  'Halloween Collection': 580,
#  'Hamilton Collection': 581,
#  'Hana and Alice Collection': 582,
#  'Hana-Dama Collection': 583,
#  'Hanni & Nanni Filmreihe': 584,
#  'Happiness Collection': 585,
#  'Happy Bhag Jayegi Collection': 586,
#  'Happy Death Day Collection': 587,
#  'Happy Feet Collection': 588,
#  'Harihar Nagar  Collection': 589,
#  'Harold & Kumar Collection': 590,
#  'Harry Potter Collection': 591,
#  'Has Fallen Collection': 592,
#  'Hatchet Collection': 593,
#  'Hate Story Collection': 594,
#  'Haunted Road Collection': 595,
#  'Haunted School Collection': 596,
#  'Haunted Transylvania Collection': 597,
#  'Havoc Collection': 598,
#  'Hayflower and Quiltshoe Collection': 599,
#  'Hayride Collection': 600,
#  'He Who Dares Collection': 601,
#  'Head Cases': 602,
#  'Headless Hero Collection': 603,
#  'Healed by Grace Collection': 604,
#  'Heaven, Hell and Purgatory Collection': 605,
#  'Heavens Lost Property': 606,
#  'Heavy Metal Collection': 607,
#  'Hell House LLC Collection': 608,
#  'Hellboy Collection': 609,
#  'Hellcats Revenge Collection': 610,
#  'Hellraiser Collection': 611,
#  'Help, I Shrunk My...': 612,
#  'Henry Fool Collection': 613,
#  'Hentai Kamen Collection': 614,
#  'Hera Pheri Collection': 615,
#  'Herbie Collection': 616,
#  'Hercule Poirot Collection': 617,
#  'Herr Lehmann Filmreihe': 618,
#  'Hey Arnold Movie Collection': 619,
#  'Hideshi Hinos Theater of Horror': 620,
#  'High School Musical Collection': 621,
#  'High Strung Collection': 622,
#  'High&Low The Movie Collection': 623,
#  'Highlander Collection': 624,
#  'Hitman Collection': 625,
#  'Hobbs & Shaw Collection': 626,
#  'Hollow Man Collection': 627,
#  'Home Alone Collection': 628,
#  'Honest Candidate Collection': 629,
#  'Honey Collection': 630,
#  'Hoodwinked! Collection': 631,
#  'Hooked Collection': 632,
#  'Horrible Bosses Collection': 633,
#  'Horror Stories Collection': 634,
#  'Hostel Collection': 635,
#  'Hot Tub Time Machine Collection': 636,
#  'Hotel Inferno Collection': 637,
#  'Hotel Transylvania Collection': 638,
#  'House of the Dead Collection': 639,
#  'Housefull Collection': 640,
#  'How High Collection': 641,
#  'How to Train Your Dragon Collection': 642,
#  'Howard Lovecraft Collection': 643,
#  'Howling Village': 644,
#  'Huevos - Collection': 645,
#  'Hunter x Hunter Collection': 646,
#  'Hurricane Bianca Collection': 647,
#  'I Am Legend Collection': 648,
#  'I Am Vengeance Collection': 649,
#  'I Can Quit Whenever I Want Collection': 650,
#  'I Give You My Word Collection': 651,
#  'I Got Five on It Collection': 652,
#  'I Got the Hook Up Collection': 653,
#  'I Love Hong Kong Collection': 654,
#  'I Spit on Your Grave (Original) Collection': 655,
#  'I Spit on Your Grave Collection': 656,
#  'Ice Age Collection': 657,
#  'Ice Collection': 658,
#  'Iceman Collection': 659,
#  'If You Are the One (Collection)': 660,
#  'Il peggio della mia vita': 661,
#  'Immaturi Collection': 662,
#  'Impy Collection': 663,
#  'In the Name of the King Collection': 664,
#  'Inadequate People Collection': 665,
#  'Independence Day Collection': 666,
#  'Indian Gangster Trilogy': 667,
#  'Indiana Jones Collection': 668,
#  'Infernal Affairs Collection': 669,
#  'Initial D': 670,
#  'Inmu': 671,
#  'Inside Man Collection': 672,
#  'Insidious Collection': 673,
#  'Into the Blue Collection': 674,
#  'Inuyasha Collection': 675,
#  'Ip Man Collection': 676,
#  'Iqbal (Samling)': 677,
#  'Iris Collection': 678,
#  'Iron Girl Collection': 679,
#  'Iron Man Collection': 680,
#  'Iron Sky Collection': 681,
#  'Ironclad Collection': 682,
#  'It Collection': 683,
#  'Ivan Tsarevich & the Grey Wolf Collection': 684,
#  'Jack Reacher Collection': 685,
#  'Jack in the Box Collection': 686,
#  'Jack vs. Collection': 687,
#  'Jacqueline Mazerin Collection': 688,
#  'James Bond Collection': 689,
#  'Jan Dara': 690,
#  'Jannat Collection': 691,
#  'Jarhead Collection': 692,
#  'Jarle Klepp-trilogien': 693,
#  'Jay and Silent Bob Collection': 694,
#  'Jeepers Creepers Collection': 695,
#  'Jet Set - Saga': 696,
#  'Jiivi Collection': 697,
#  'Jim Button Collection': 698,
#  'Jism Collection': 699,
#  'Joan of Arc Collection': 700,
#  'Jodorowskys film autobiography': 701,
#  'Joe Dirt Collection': 702,
#  'John Wick Collection': 703,
#  'Johnny 100 Pesos Collection': 704,
#  'Johnny English Collection': 705,
#  'Joséphine - Saga': 706,
#  'Journey Collection': 707,
#  'Journey to the West Collection': 708,
#  'Joy Ride Collection': 709,
#  'Ju-on Collection': 710,
#  'Judwaa Collection': 711,
#  'Julemandens Datter (Samling)': 712,
#  'Jumanji Collection': 713,
#  'Jump Street Collection': 714,
#  'Jungle Cruise Collection': 715,
#  'Jungle Jack Collection': 716,
#  'Jurassic Park Collection': 717,
#  'Jurassic Shark Collection': 718,
#  'Justice League (DC Universe Animated) Collection': 719,
#  'K-9 Adventures Collection': 720,
#  'K.G.F Collection': 721,
#  'KAIJI Collection': 722,
#  'Kaguya-sama: Love is War - Collection': 723,
#  'Kahaani Collection': 724,
#  'Kaithi Collection': 725,
#  'Kakegurui: The Movie': 726,
#  'Kamen Rider (1971) Collection': 727,
#  'Kamen Rider Agito Collection': 728,
#  'Kamen Rider Amazons Collection': 729,
#  'Kamen Rider Decade Collection': 730,
#  'Kamen Rider OOO Collection': 731,
#  'Kamen Rider The First Collection': 732,
#  'Kamen Rider W Collection': 733,
#  'Kandasamys Collection': 734,
#  'Kangaroo Jack Collection': 735,
#  'Karla Collection': 736,
#  'Kartoffelsalat Filmreihe': 737,
#  'Kazuo Umezus Horror Theater Collection': 738,
#  'Keinohrhasen Filmreihe': 739,
#  'Kekko Kamen Collection': 740,
#  'Keluarga Cemara Collection': 741,
#  'Kibakichi Collection': 742,
#  'Kick-Ass Collection': 743,
#  'Kickboxer (Reboot) Collection': 744,
#  'Kids Return': 745,
#  'Kidulthood Collection': 746,
#  'Kill Bill Collection': 747,
#  'Kill Buljo Collection': 748,
#  'Killer Shrews Collection': 749,
#  'Killing Cabos Collection': 750,
#  'Killjoy Collection': 751,
#  'Kindergarten Cop Collection': 752,
#  'King Naresuan Collection': 753,
#  'King of Guns Collection': 754,
#  'Kingsman Collection': 755,
#  'Kirikou Collection': 756,
#  'Kizumonogatari': 757,
#  'Klovn (filmene)': 758,
#  'Knerten Collection': 759,
#  'Knights of the Damned Collection': 760,
#  'Knives Out Collection': 761,
#  'Knocked Up Collection': 762,
#  'Knutsen & Ludvigsen Collection': 763,
#  'Kocan Kadar Konuş [Seri]': 764,
#  'Koko Collection': 765,
#  'Kolah Ghermezi': 766,
#  'Krampus Collection': 767,
#  'Krrish Collection': 768,
#  'Kung Fu Masters Collection': 769,
#  'Kung Fu Panda Collection': 770,
#  'Kung Fu Traveler Collection': 771,
#  'Kuntilanak Collection': 772,
#  'Kuroko no Basket: Winter Cup Soushuuhen Collection': 773,
#  'Kuroshithuji Collection': 774,
#  'Kutsal Damacana [Seri]': 775,
#  'Kvartet I Collection': 776,
#  'Köstebekgiller [Seri]': 777,
#  'L.O.R.D Collection': 778,
#  'LEGO DC Comics Super Heroes Collection': 779,
#  'LEGO DC Super Hero Girls Collection': 780,
#  'LEGO: Hero Factory - Saga': 781,
#  'LUPIN THE IIIRD Collection': 782,
#  'La Abuela Collection': 783,
#  'La Soga Collection': 784,
#  'La befana vien di notte': 785,
#  'La niña de tus ojos - Colección': 786,
#  'Lady Ninja Kasumi Series': 787,
#  'Laid To Rest Collection': 788,
#  'Lake Fear Collection': 789,
#  'Lan Kwai Fong Collection': 790,
#  'Lapland Odyssey Collection': 791,
#  'Largo Winch Collection': 792,
#  'Las Leyendas Collection': 793,
#  'LasseMajas Detektivbyrå (samling)': 794,
#  'Laughing Gor（系列）': 795,
#  'Lauras Stern': 796,
#  'Lazer Team Collection': 797,
#  'League of Gods': 798,
#  'Leap collection': 799,
#  'Left Behind Collection': 800,
#  'Legally Blonde Collection': 801,
#  'Legend of a Rabbit Collection': 802,
#  'Lemon Popsicle Collection': 803,
#  'Leprechaun Collection': 804,
#  'Les Crevettes pailletées - Saga': 805,
#  'Les Petits Mouchoirs - Saga': 806,
#  'Lesní trilogie (kolekce)': 807,
#  'Lesson of the Evil Collection': 808,
#  'Let Him Be a Basketball Player Collection': 809,
#  'Lethal Kittens Collection': 810,
#  'Letters to Santa Collection': 811,
#  'Lezioni di Cioccolato Collection': 812,
#  'Liar Game Collection': 813,
#  'Library Wars Collection': 814,
#  'Lights Out Collection': 815,
#  'Like Mike Collection': 816,
#  'Like a Dragon Collection': 817,
#  'Lilly the Witch Collection': 818,
#  'Lilo & Stitch Collection': 819,
#  'Line Walker Collection': 820,
#  'Little Bear': 821,
#  'Little Book of Love Collection': 822,
#  'Little Forest Collection': 823,
#  'Little Nicholas Trilogy': 824,
#  'Little Witch Academia Collection': 825,
#  'Live. Die. Repeat Collection': 826,
#  'Living Dead Collection': 827,
#  'Long Long Time Ago': 828,
#  'Loro Collection': 829,
#  'Los crímenes del sur': 830,
#  'Lost Collection': 831,
#  'Lotte Collection': 832,
#  'Louis & Luca Collection': 833,
#  'Love Comes Softly Collection': 834,
#  'Love For Sale Collection': 835,
#  'Love Stories 2 Series': 836,
#  'Love Stories Series': 837,
#  'Love Undercover Collection': 838,
#  'Love in a... Collection': 839,
#  'Love in the City Collection': 840,
#  'Lovey-Dovey Collection': 841,
#  'Lucifer Collection': 842,
#  'Lucy Collection': 843,
#  'L♥DK': 844,
#  'MVP': 845,
#  'Maari Collection': 846,
#  'Machete Collection': 847,
#  'Machine Girl Collection': 848,
#  'Macross Frontier Collection': 849,
#  'Mad Max Collection': 850,
#  'Madagascar Collection': 851,
#  'Made in Abyss Collection': 852,
#  'Madea - Collection': 853,
#  'Magic Carpet Ride Collection': 854,
#  'Magic Mike Collection': 855,
#  'Magic Silver Collection': 856,
#  'Magical Girl Lyrical Nanoha Collection': 857,
#  'Major Korenev Trilogy': 858,
#  'Major Mahadevan Collection': 859,
#  'Make Me Shudder': 860,
#  'Maleficent Collection': 861,
#  'Malevolence Collection': 862,
#  'Malibu Rescue Collection': 863,
#  'Mall Cop Collection': 864,
#  'Mamma Mia! Collection': 865,
#  'Man and a Baby Collection': 866,
#  'Man of Steel Collection': 867,
#  'Mandie Movies Collection': 868,
#  'Mang Kepweng Collection': 869,
#  'Mann Filmreihe': 870,
#  'Manos Collection': 871,
#  'Manual of Love Collection': 872,
#  'Manyeo The Witch Collection': 873,
#  'Mapado Collection': 874,
#  'March Comes in Like a Lion Collection': 875,
#  'Mardaani Collection': 876,
#  'Mardock Scramble Collection': 877,
#  'Marfa Girl Collection': 878,
#  'Maria, ihm schmeckts nicht! Filmreihe': 879,
#  'Mariachi Collection': 880,
#  'Marley & Me Collection': 881,
#  'Marrying the Mafia Collection': 882,
#  'Mary Poppins Collection': 883,
#  'Maskeli Beşler [Seri]': 884,
#  'Masquerade Hotel Collection': 885,
#  'Masti Collection': 886,
#  'Mata Batin Collection': 887,
#  'Max Collection': 888,
#  'Max Havoc Collection': 889,
#  'Max Pinlig Collection': 890,
#  'May the Devil Take You': 891,
#  'Maya the Bee Collection': 892,
#  'McDull Collection': 893,
#  'Mean Girls Collection': 894,
#  'Meat pie collection': 895,
#  'Meatball Machine Collection': 896,
#  'Mechanic Collection': 897,
#  'Meet the Blacks Collection': 898,
#  'Meet the In-Laws': 899,
#  'Meet the Parents Collection': 900,
#  'Mega Shark Collection': 901,
#  'Megalodon Collection': 902,
#  'Mektoub is Mektoub': 903,
#  'Memoirs of a Lady Ninja Series': 904,
#  'Men & Women Dilogy': 905,
#  'Men In Black Collection': 906,
#  'Men Suddenly in Black Collections': 907,
#  'Men in the City Collection': 908,
#  'Methagu Collection': 909,
#  'Mexico Barbaro Filmreihe': 910,
#  'Mi Nismo Anđeli Collection': 911,
#  'Midnight Diner Collection': 912,
#  'Mince Alors ! - Saga': 913,
#  'Minions Collection': 914,
#  'Minuscule Collection': 915,
#  'Mirror Mirror Collection': 916,
#  'Mirrors Collection': 917,
#  'Mischievous Kiss The Movie': 918,
#  'Miss Congeniality Collection': 919,
#  'Miss Modern Collection': 920,
#  'Mission: Impossible Collection': 921,
#  'Mister Twister Collection': 922,
#  'Mobile Suit Gundam Thunderbolt Collection': 923,
#  'Mobile Suit Gundam: The Origin Collection': 924,
#  'Mobile Suit Zeta Gundam A New Translation': 925,
#  'Mojin Collection': 926,
#  'Molly Hartley Collection': 927,
#  'Monica and Friends': 928,
#  'Monster Family Collection': 929,
#  'Monster High Collection': 930,
#  'Monster Hunt Collection': 931,
#  'Monsters Collection': 932,
#  'Monsters, Inc. Collection': 933,
#  'Moontrap Collection': 934,
#  'Mortadelo y Filemón - Colección': 935,
#  'Mortal Kombat Collection': 936,
#  'Mortal Kombat Legends Collection': 937,
#  'Moschettieri del Re - Collezione': 938,
#  'Mountain Collection': 939,
#  'Mr. Bean Collection': 940,
#  'Mr. Bones Collection': 941,
#  'Mr. Ripley Collection': 942,
#  'Mucize [Seri]': 943,
#  'Mummys Kiss Collection': 944,
#  'Munafik Trilogy': 945,
#  'Muni Collection': 946,
#  'Munna Bhai Collection': 947,
#  'Murder Collection': 948,
#  'Murder Mystery Collection': 949,
#  'Mushishi Collection': 950,
#  'My Alien Girlfriend Collection': 951,
#  'My Big Fat Greek Wedding Collection': 952,
#  'My Boss, My Collection': 953,
#  'My Brother Series': 954,
#  'My Friends Sister Series': 955,
#  'My Hero Academia Collection': 956,
#  'My Little Pony: Equestria Girls Collection': 957,
#  'My Mom is a Character Collection': 958,
#  'My Sassy Girl Collection': 959,
#  'My Sisters Kids (Remake) Collection': 960,
#  'My Stupid Boss': 961,
#  'My Thoughts Are Silent Collection': 962,
#  'My Wife Is Collection': 963,
#  'My Wife is a Gangster Collection': 964,
#  'Mystery Road Collection': 965,
#  'Mythica Collection': 966,
#  'N.T.R Collection': 967,
#  'NASU Collection': 968,
#  'NKCTHI Collection': 969,
#  'Naked Collection': 970,
#  'Naked Fear Collection': 971,
#  'Naked Poison Collection': 972,
#  'Namastey London Collection': 973,
#  'Nana Collection': 974,
#  'Nanny McPhee Collection': 975,
#  'Naruto Collection': 976,
#  'National Lampoons Van Wilder Collection': 977,
#  'National Treasure Collection': 978,
#  'Nativity Collection': 979,
#  'Necromancer': 980,
#  'Neighbors Collection': 981,
#  'Nemesis Collection': 982,
#  'Neuilly sa mère ! - Saga': 983,
#  'Never Back Down Collection': 984,
#  'Never Died Collection': 985,
#  'New Gods Collection': 986,
#  'New Initial D Collection': 987,
#  'New Kids Collection': 988,
#  'New Money Collection': 989,
#  'New Queer Visions Collection': 990,
#  'New World Order Collection': 991,
#  'Nice Sister-In-Law Series': 992,
#  'Night at the Museum Collection': 993,
#  'Night of the Demons Collection': 994,
#  'Night of the Living Dead 3D - Collection': 995,
#  'Nightmare Collections': 996,
#  'Niko Collection': 997,
#  'Nims Island Collection': 998,
#  'Ninja Collection': 999,
#  ...}

# %%
#extract the necessary columns
df_collections = tmdb_df[['imdb_id', 'collection']]
df_collections
# Out:
#          imdb_id collection
# 0      tt0113026       None
# 1      tt0113092       None
# 2      tt0116391       None
# 3      tt0118694       None
# 4      tt0118852       None
# ...          ...        ...
# 61326  tt9895024       None
# 61327  tt9896876       None
# 61328  tt9898844       None
# 61329  tt9900940       None
# 61330  tt9907782       None
#
# [61331 rows x 2 columns]

# %%
#drop null values
df_collections = df_collections.dropna()
df_collections.isna().sum()
# Out:
# imdb_id       0
# collection    0
# dtype: int64

# %%
#make new integer collection_id column
df_collections['collection_id'] = df_collections['collection'].map(collection_map)
df_collections
# Out:
# /var/folders/tc/tt7jrftn7g510vxnf1thdhl80000gn/T/ipykernel_11905/3438514306.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_collections['collection_id'] = df_collections['collection'].map(collection_map)
#          imdb_id                           collection  collection_id
# 5      tt0119273               Heavy Metal Collection            607
# 12     tt0120630               Chicken Run Collection            271
# 16     tt0120755       Mission: Impossible Collection            921
# 17     tt0120903                     X-Men Collection           1781
# 19     tt0120917   The Emperors New Groove Collection           1452
# ...          ...                                  ...            ...
# 61274  tt9701942               Fear Street Collection            464
# 61294  tt9777666          The Tomorrow War Collection           1609
# 61306  tt9819258  12 Westerns in 12 Months Collection              9
# 61309  tt9844522               Escape Room Collection            440
# 61316  tt9857850  12 Westerns in 12 Months Collection              9
#
# [3791 rows x 3 columns]

# %%
#manually make dataframe with named columns from .keyd and .values
collection_lookup = pd.DataFrame({'collection_id':collection_map.values(), 
                              'collection_name':collection_map.keys()})
collection_lookup
# Out:
#       collection_id            collection_name
# 0                 0          #TemanTapiMenikah
# 1                 1     ... Cameras Collection
# 2                 2           .hack Collection
# 3                 3  10 giorni... - Collezione
# 4                 4       100 Girls Collection
# ...             ...                        ...
# 1841           1841                     青鬼（系列）
# 1842           1842                    달마야 시리즈
# 1843           1843                     독전 시리즈
# 1844           1844              동갑내기 과외하기 시리즈
# 1845           1845                     식객 시리즈
#
# [1846 rows x 2 columns]

# %% [markdown]
# #### Production Companies

# %%
#examine a single value from the production companies column
production = tmdb_df.iloc[0]['production_companies']
production
# Out:
# "[{'id': 51207, 'logo_path': None, 'name': 'Sullivan Street Productions', 'origin_country': ''}, {'id': 51208, 'logo_path': None, 'name': 'Michael Ritchie Productions', 'origin_country': ''}, {'id': 51209, 'logo_path': None, 'name': 'Radmin Company, The', 'origin_country': ''}, {'id': 60, 'logo_path': '/oJXpAs4I3W46e4dkaOEzCa4yBko.png', 'name': 'United Artists', 'origin_country': 'US'}]"

# %%
#the production companies seem to be a list of dictionaries
#there are plenty of things to fix here, a function might be helpful
def productionFix(data):
    try:
        data = data.replace('None', '"None"')
        data = data.replace('\\', '')
        data = data.replace("'s", 's')
        for quotes in ['id','logo_path','name','origin_country']:
            data = data.replace(f"'{quotes}'",f'"{quotes}"')
        data = data.replace("'", '"')
        data = json.loads(data)
        companies = []
        for company in data:
            companies.append(company['name'])
        return companies
    except:
        print(data)

# %%
#try out the function on our single value
productionFix(production)
# Out:
# ['Sullivan Street Productions',
#  'Michael Ritchie Productions',
#  'Radmin Company, The',
#  'United Artists']

# %%
#since the function was successfull, lets apply this to the entire column
tmdb_df['production_companies_list'] = tmdb_df['production_companies'].apply(productionFix)
# Out:
# [{"id": 19551, "logo_path": "/2WpWp9b108hizjHKdA107hFmvQ5.png", "name": "Marvel Enterprises", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 9168, "logo_path": "/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png", "name": "Bad Hat Harry Productions", "origin_country": "US"}, {"id": 22969, "logo_path": "None", "name": "Springwood Productions", "origin_country": ""}, {"id": 22970, "logo_path": "None", "name": "Genetics Productions", "origin_country": ""}, {"id": 25, "logo_path": "/qZCc1lty5FzX30aOCVRBLzaVmcp.png", "name": "20th Century Fox", "origin_country": "US"}]
# [{"id": 18710, "logo_path": "None", "name": "Zed Filmes", "origin_country": "PT"}, {"id": 8492, "logo_path": "/wYhNCpXIThYDXevad6n90vsMXZ2.png", "name": "RTP", "origin_country": "PT"}, {"id": 19673, "logo_path": "None", "name": "Hochschule für Film und Fernsehen "Konrad Wolf"", "origin_country": ""}, {"id": 31052, "logo_path": "/pJgQoO1PyJdhOP1UOrVsDeolYw7.png", "name": "Deutsche Film- und Fernsehakademie Berlin (DFFB)", "origin_country": "DE"}]
# [{"id": 121673, "logo_path": "None", "name": "Bring"em Back Alive Productions", "origin_country": ""}, {"id": 121674, "logo_path": "None", "name": "Down Home Productions", "origin_country": ""}, {"id": 121675, "logo_path": "None", "name": "Neversaydie Productions", "origin_country": ""}]
# [{"id": 65403, "logo_path": "None", "name": "IMF Internationale Medien und Film GmbH & Co. Produktions KG", "origin_country": ""}, {"id": 37, "logo_path": "/nlG4JEjJ7SAFDehgIVvHFBPW23y.png", "name": "Gramercy Pictures", "origin_country": "US"}, {"id": 278, "logo_path": "None", "name": "Propaganda Films", "origin_country": ""}, {"id": 98386, "logo_path": "None", "name": "ab"-strakt Pictures", "origin_country": ""}, {"id": 33, "logo_path": "/8lvHyhjr8oUKOOy2dKXoALWKdp0.png", "name": "Universal Pictures", "origin_country": "US"}]
# [{"id": 40544, "logo_path": "None", "name": "Giv"en Films", "origin_country": ""}, {"id": 22289, "logo_path": "None", "name": "Moonstone Entertainment", "origin_country": ""}]
# [{"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 157982, "logo_path": "None", "name": "CNC", "origin_country": "FR"}, {"id": 53824, "logo_path": "None", "name": "Co-Productiefonds Binnenlandse Omroep", "origin_country": ""}, {"id": 11402, "logo_path": "None", "name": "Conseil Régional de Franche-Comté", "origin_country": ""}, {"id": 46596, "logo_path": "None", "name": "Euripide Productions", "origin_country": ""}, {"id": 160195, "logo_path": "None", "name": "Harlekijn Holland BV", "origin_country": ""}, {"id": 33149, "logo_path": "None", "name": "Havas Images", "origin_country": ""}, {"id": 8541, "logo_path": "/gKy5OSpgtSZIcXX9yYeJcFgPuaD.png", "name": "Katholieke Radio Omroep (KRO)", "origin_country": "NL"}, {"id": 161578, "logo_path": "None", "name": "Les Voleurs d"Ombres", "origin_country": ""}, {"id": 161579, "logo_path": "None", "name": "Accolade Productions", "origin_country": ""}]
# [{"id": 36339, "logo_path": "None", "name": "Tokyo Theatres K.K.", "origin_country": "JP"}, {"id": 2752, "logo_path": "None", "name": "DENTSU Music And Entertainment", "origin_country": "JP"}, {"id": 2256, "logo_path": "None", "name": "Les Films de L"Observatoire", "origin_country": ""}, {"id": 23481, "logo_path": "None", "name": "Suncent CinemaWorks", "origin_country": ""}, {"id": 13412, "logo_path": "/jLBwPLrniN24UV46WMtNTCTyd8c.png", "name": "Imagica Lab.", "origin_country": "JP"}]
# [{"id": 1164, "logo_path": "None", "name": "City Heat Productions", "origin_country": ""}, {"id": 25433, "logo_path": "None", "name": "DEJ Productions", "origin_country": ""}, {"id": 11787, "logo_path": "None", "name": "Po" Boy Productions", "origin_country": ""}]
# [{"id": 7984, "logo_path": "None", "name": "Zespól Filmowy "Tor"", "origin_country": ""}, {"id": 84133, "logo_path": "None", "name": "Jacques Le Glou Audiovisuel", "origin_country": ""}, {"id": 250, "logo_path": "None", "name": "Canal+ Polska", "origin_country": "PL"}, {"id": 6480, "logo_path": "/qJUUNzFYXNUDaisssBTV3Zdki9R.png", "name": "TVP", "origin_country": "PL"}]
# [{"id": 28190, "logo_path": "/owxjMUpB2uvfF0sdGrT6gQo2GY4.png", "name": "13 Productions", "origin_country": "FR"}, {"id": 11332, "logo_path": "None", "name": "La Sept-Arte", "origin_country": "FR"}, {"id": 2381, "logo_path": "/hmzO0vmTZjfGoMoS5pykenpmHWH.png", "name": "Musée d"Orsay", "origin_country": "FR"}]
# [{"id": 27099, "logo_path": "None", "name": "Ministry of Culture and Tourism", "origin_country": ""}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 86690, "logo_path": "None", "name": "Youth Studio", "origin_country": ""}, {"id": 86691, "logo_path": "None", "name": "Studio de la Jeunesse", "origin_country": ""}, {"id": 86692, "logo_path": "None", "name": "Vietnam Cinema Office", "origin_country": ""}]
# [{"id": 884, "logo_path": "None", "name": "TPS Cinéma", "origin_country": ""}, {"id": 7799, "logo_path": "None", "name": "TF1 International", "origin_country": "FR"}, {"id": 11704, "logo_path": "None", "name": "2M", "origin_country": ""}, {"id": 58725, "logo_path": "None", "name": "Ali"n Productions", "origin_country": "MA"}, {"id": 70587, "logo_path": "None", "name": "Gimages 3", "origin_country": ""}, {"id": 73273, "logo_path": "None", "name": "Alexis Films", "origin_country": ""}, {"id": 89405, "logo_path": "None", "name": "Ace Editing", "origin_country": ""}, {"id": 89407, "logo_path": "None", "name": "Remstar Films", "origin_country": ""}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 20881, "logo_path": "None", "name": "Playtime", "origin_country": "FR"}, {"id": 36252, "logo_path": "/xHIIkI4AXFHrz8jiUzcQtd6dt6W.png", "name": "Centre Cinématographique Marocain (CCM)", "origin_country": "MA"}]
# [{"id": 75663, "logo_path": "None", "name": "Montage", "origin_country": ""}, {"id": 93417, "logo_path": "None", "name": "Sean Aloysius O"Fearna & Sons", "origin_country": ""}]
# [{"id": 89629, "logo_path": "None", "name": "Say It Isn"t So Productions", "origin_country": ""}, {"id": 1156, "logo_path": "None", "name": "Conundrum Entertainment", "origin_country": ""}, {"id": 25, "logo_path": "/qZCc1lty5FzX30aOCVRBLzaVmcp.png", "name": "20th Century Fox", "origin_country": "US"}]
# [{"id": 23446, "logo_path": "None", "name": "Sofica Sofinergie 5", "origin_country": ""}, {"id": 83, "logo_path": "/9OQ0rm55xtlgX7KcAKMUePJSrQc.png", "name": "France 2 Cinéma", "origin_country": "FR"}, {"id": 97762, "logo_path": "None", "name": "Le Clown et l"Enfant", "origin_country": ""}, {"id": 2951, "logo_path": "/eKuMbpKtI0T8T4LmPsldgNbCaIE.png", "name": "Les Films du Kiosque", "origin_country": "FR"}, {"id": 1168, "logo_path": "None", "name": "Novo Arturo Films", "origin_country": ""}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 109756, "logo_path": "/sudlIoNIIrKmVWaYD2ZVo9HGogW.png", "name": "Auvergne-Rhône-Alpes Cinéma", "origin_country": "FR"}]
# [{"id": 4077, "logo_path": "None", "name": "Crystal Sky Worldwide", "origin_country": ""}, {"id": 10828, "logo_path": "None", "name": "MDP Worldwide", "origin_country": ""}, {"id": 16850, "logo_path": "None", "name": "ApolloMedia", "origin_country": "DE"}, {"id": 23770, "logo_path": "/t1Dc5SaJLBfRxtl0ttLGdaYICQ2.png", "name": "Signature Entertainment", "origin_country": "US"}, {"id": 53010, "logo_path": "None", "name": "D"Artagnan Productions Limited", "origin_country": ""}, {"id": 53011, "logo_path": "None", "name": "Q&Q Medien GmbH", "origin_country": ""}, {"id": 8900, "logo_path": "None", "name": "The Carousel Picture Company", "origin_country": "LU"}, {"id": 11776, "logo_path": "/33JMuTtwY5UhPwkmCEyH1YaCD23.png", "name": "Film Fund Luxembourg", "origin_country": "LU"}]
# [{"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 158, "logo_path": "/6SHlNIype9zmyEMRsBtoueUtLsq.png", "name": "Spyglass Entertainment", "origin_country": "US"}, {"id": 9195, "logo_path": "/ou5BUbtulr6tIt699q6xJiEQTR9.png", "name": "Touchstone Pictures", "origin_country": "US"}, {"id": 1171, "logo_path": "None", "name": "Epsilon Motion Pictures", "origin_country": "CH"}]
# [{"id": 5756, "logo_path": "None", "name": "Vif Babelsberger Filmproduktion GmbH & Co. Dritte KG", "origin_country": ""}, {"id": 5757, "logo_path": "None", "name": "P"Artisan Filmproduktion GmbH", "origin_country": ""}, {"id": 5758, "logo_path": "None", "name": "Daybreak Pictures Ltd.", "origin_country": ""}]
# [{"id": 4528, "logo_path": "None", "name": "Picture Me Rollin" Productions", "origin_country": ""}]
# [{"id": 1839, "logo_path": "None", "name": "Chronos Film", "origin_country": ""}, {"id": 3268, "logo_path": "/tuomPhY2UtuPTqqFnKMVHvSb724.png", "name": "HBO", "origin_country": "US"}, {"id": 73861, "logo_path": "None", "name": "Kredyt Bank PBI S.A.", "origin_country": ""}, {"id": 1829, "logo_path": "None", "name": "Zespól Filmowy "Kadr"", "origin_country": "PL"}, {"id": 6480, "logo_path": "/qJUUNzFYXNUDaisssBTV3Zdki9R.png", "name": "TVP", "origin_country": "PL"}]
# [{"id": 85739, "logo_path": "None", "name": "Foundation Montecinema Verità", "origin_country": ""}, {"id": 2442, "logo_path": "None", "name": "Counihan Villiers Productions", "origin_country": ""}, {"id": 23433, "logo_path": "/z2CJKzHBgM1tHtBgHj0iFQDY1uX.png", "name": "Noé Productions", "origin_country": "FR"}, {"id": 54378, "logo_path": "None", "name": "Fabrica", "origin_country": ""}, {"id": 1016, "logo_path": "None", "name": "Mans Films", "origin_country": ""}, {"id": 49181, "logo_path": "None", "name": "Studio Maj", "origin_country": "SI"}, {"id": 85740, "logo_path": "None", "name": "The Centre du Cinema et de l"Audiovisuel de la Communauté Française de Belgique", "origin_country": ""}, {"id": 12024, "logo_path": "None", "name": "Télédistributeurs Wallons", "origin_country": ""}, {"id": 85741, "logo_path": "None", "name": "Slovenian Film Fund", "origin_country": "SI"}, {"id": 850, "logo_path": "/aF7qajGJGtMpdrtvssM9g90YanX.png", "name": "Eurimages", "origin_country": "FR"}, {"id": 25159, "logo_path": "None", "name": "British Screen Finance Ltd", "origin_country": ""}, {"id": 884, "logo_path": "None", "name": "TPS Cinéma", "origin_country": ""}, {"id": 85742, "logo_path": "None", "name": "Multivision", "origin_country": "FR"}, {"id": 85743, "logo_path": "None", "name": "Canal + Belgique", "origin_country": ""}, {"id": 85744, "logo_path": "None", "name": "Fondazione MonteCinemaVerità Locarno", "origin_country": ""}, {"id": 85745, "logo_path": "None", "name": "Direction du Développement et de la Coopération (DDC), Département Fédéral des Affaires Etrangères", "origin_country": ""}, {"id": 85746, "logo_path": "None", "name": "The European Co-Production Fund Limited", "origin_country": ""}, {"id": 792, "logo_path": "/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png", "name": "RTBF", "origin_country": "BE"}, {"id": 18973, "logo_path": "/lM081nCPhuKIPc2lJWstsQAlIaJ.png", "name": "01 Distribution", "origin_country": "IT"}, {"id": 1583, "logo_path": "/gKP4egMJOi5rksdnplfPV1wa0sd.png", "name": "RAI", "origin_country": "IT"}]
# [{"id": 73113, "logo_path": "None", "name": "Filmakademie Wien", "origin_country": "AT"}, {"id": 19673, "logo_path": "None", "name": "Hochschule für Film und Fernsehen "Konrad Wolf"", "origin_country": ""}]
# [{"id": 40544, "logo_path": "None", "name": "Giv"en Films", "origin_country": ""}, {"id": 35, "logo_path": "/wxrHa3nZ1K4zo65p56991INkGo6.png", "name": "Lions Gate Films", "origin_country": "US"}]
# [{"id": 8177, "logo_path": "None", "name": "Rothkirch Cartoon Film", "origin_country": ""}, {"id": 134438, "logo_path": "None", "name": "Buena Vista Negative Cutting", "origin_country": ""}, {"id": 134439, "logo_path": "None", "name": "Buena Vista Sound Studios", "origin_country": ""}, {"id": 134440, "logo_path": "None", "name": "O"Henry Sound Studios", "origin_country": ""}, {"id": 134441, "logo_path": "None", "name": "Pacific Title", "origin_country": ""}, {"id": 103464, "logo_path": "None", "name": "Technicolor", "origin_country": ""}, {"id": 174, "logo_path": "/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png", "name": "Warner Bros. Pictures", "origin_country": "US"}]
# [{"id": 23496, "logo_path": "None", "name": "Les Films de l"Ange", "origin_country": ""}]
# [{"id": 89629, "logo_path": "None", "name": "Say It Isn"t So Productions", "origin_country": ""}, {"id": 1156, "logo_path": "None", "name": "Conundrum Entertainment", "origin_country": ""}, {"id": 25, "logo_path": "/qZCc1lty5FzX30aOCVRBLzaVmcp.png", "name": "20th Century Fox", "origin_country": "US"}]
# [{"id": 23446, "logo_path": "None", "name": "Sofica Sofinergie 5", "origin_country": ""}, {"id": 83, "logo_path": "/9OQ0rm55xtlgX7KcAKMUePJSrQc.png", "name": "France 2 Cinéma", "origin_country": "FR"}, {"id": 97762, "logo_path": "None", "name": "Le Clown et l"Enfant", "origin_country": ""}, {"id": 2951, "logo_path": "/eKuMbpKtI0T8T4LmPsldgNbCaIE.png", "name": "Les Films du Kiosque", "origin_country": "FR"}, {"id": 1168, "logo_path": "None", "name": "Novo Arturo Films", "origin_country": ""}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 109756, "logo_path": "/sudlIoNIIrKmVWaYD2ZVo9HGogW.png", "name": "Auvergne-Rhône-Alpes Cinéma", "origin_country": "FR"}]
# [{"id": 4077, "logo_path": "None", "name": "Crystal Sky Worldwide", "origin_country": ""}, {"id": 10828, "logo_path": "None", "name": "MDP Worldwide", "origin_country": ""}, {"id": 16850, "logo_path": "None", "name": "ApolloMedia", "origin_country": "DE"}, {"id": 23770, "logo_path": "/t1Dc5SaJLBfRxtl0ttLGdaYICQ2.png", "name": "Signature Entertainment", "origin_country": "US"}, {"id": 53010, "logo_path": "None", "name": "D"Artagnan Productions Limited", "origin_country": ""}, {"id": 53011, "logo_path": "None", "name": "Q&Q Medien GmbH", "origin_country": ""}, {"id": 8900, "logo_path": "None", "name": "The Carousel Picture Company", "origin_country": "LU"}, {"id": 11776, "logo_path": "/33JMuTtwY5UhPwkmCEyH1YaCD23.png", "name": "Film Fund Luxembourg", "origin_country": "LU"}]
# [{"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 158, "logo_path": "/6SHlNIype9zmyEMRsBtoueUtLsq.png", "name": "Spyglass Entertainment", "origin_country": "US"}, {"id": 9195, "logo_path": "/ou5BUbtulr6tIt699q6xJiEQTR9.png", "name": "Touchstone Pictures", "origin_country": "US"}, {"id": 1171, "logo_path": "None", "name": "Epsilon Motion Pictures", "origin_country": "CH"}]
# [{"id": 5756, "logo_path": "None", "name": "Vif Babelsberger Filmproduktion GmbH & Co. Dritte KG", "origin_country": ""}, {"id": 5757, "logo_path": "None", "name": "P"Artisan Filmproduktion GmbH", "origin_country": ""}, {"id": 5758, "logo_path": "None", "name": "Daybreak Pictures Ltd.", "origin_country": ""}]
# [{"id": 4528, "logo_path": "None", "name": "Picture Me Rollin" Productions", "origin_country": ""}]
# [{"id": 1839, "logo_path": "None", "name": "Chronos Film", "origin_country": ""}, {"id": 3268, "logo_path": "/tuomPhY2UtuPTqqFnKMVHvSb724.png", "name": "HBO", "origin_country": "US"}, {"id": 73861, "logo_path": "None", "name": "Kredyt Bank PBI S.A.", "origin_country": ""}, {"id": 1829, "logo_path": "None", "name": "Zespól Filmowy "Kadr"", "origin_country": "PL"}, {"id": 6480, "logo_path": "/qJUUNzFYXNUDaisssBTV3Zdki9R.png", "name": "TVP", "origin_country": "PL"}]
# [{"id": 85739, "logo_path": "None", "name": "Foundation Montecinema Verità", "origin_country": ""}, {"id": 2442, "logo_path": "None", "name": "Counihan Villiers Productions", "origin_country": ""}, {"id": 23433, "logo_path": "/z2CJKzHBgM1tHtBgHj0iFQDY1uX.png", "name": "Noé Productions", "origin_country": "FR"}, {"id": 54378, "logo_path": "None", "name": "Fabrica", "origin_country": ""}, {"id": 1016, "logo_path": "None", "name": "Mans Films", "origin_country": ""}, {"id": 49181, "logo_path": "None", "name": "Studio Maj", "origin_country": "SI"}, {"id": 85740, "logo_path": "None", "name": "The Centre du Cinema et de l"Audiovisuel de la Communauté Française de Belgique", "origin_country": ""}, {"id": 12024, "logo_path": "None", "name": "Télédistributeurs Wallons", "origin_country": ""}, {"id": 85741, "logo_path": "None", "name": "Slovenian Film Fund", "origin_country": "SI"}, {"id": 850, "logo_path": "/aF7qajGJGtMpdrtvssM9g90YanX.png", "name": "Eurimages", "origin_country": "FR"}, {"id": 25159, "logo_path": "None", "name": "British Screen Finance Ltd", "origin_country": ""}, {"id": 884, "logo_path": "None", "name": "TPS Cinéma", "origin_country": ""}, {"id": 85742, "logo_path": "None", "name": "Multivision", "origin_country": "FR"}, {"id": 85743, "logo_path": "None", "name": "Canal + Belgique", "origin_country": ""}, {"id": 85744, "logo_path": "None", "name": "Fondazione MonteCinemaVerità Locarno", "origin_country": ""}, {"id": 85745, "logo_path": "None", "name": "Direction du Développement et de la Coopération (DDC), Département Fédéral des Affaires Etrangères", "origin_country": ""}, {"id": 85746, "logo_path": "None", "name": "The European Co-Production Fund Limited", "origin_country": ""}, {"id": 792, "logo_path": "/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png", "name": "RTBF", "origin_country": "BE"}, {"id": 18973, "logo_path": "/lM081nCPhuKIPc2lJWstsQAlIaJ.png", "name": "01 Distribution", "origin_country": "IT"}, {"id": 1583, "logo_path": "/gKP4egMJOi5rksdnplfPV1wa0sd.png", "name": "RAI", "origin_country": "IT"}]
# [{"id": 73113, "logo_path": "None", "name": "Filmakademie Wien", "origin_country": "AT"}, {"id": 19673, "logo_path": "None", "name": "Hochschule für Film und Fernsehen "Konrad Wolf"", "origin_country": ""}]
# [{"id": 40544, "logo_path": "None", "name": "Giv"en Films", "origin_country": ""}, {"id": 35, "logo_path": "/wxrHa3nZ1K4zo65p56991INkGo6.png", "name": "Lions Gate Films", "origin_country": "US"}]
# [{"id": 8177, "logo_path": "None", "name": "Rothkirch Cartoon Film", "origin_country": ""}, {"id": 134438, "logo_path": "None", "name": "Buena Vista Negative Cutting", "origin_country": ""}, {"id": 134439, "logo_path": "None", "name": "Buena Vista Sound Studios", "origin_country": ""}, {"id": 134440, "logo_path": "None", "name": "O"Henry Sound Studios", "origin_country": ""}, {"id": 134441, "logo_path": "None", "name": "Pacific Title", "origin_country": ""}, {"id": 103464, "logo_path": "None", "name": "Technicolor", "origin_country": ""}, {"id": 174, "logo_path": "/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png", "name": "Warner Bros. Pictures", "origin_country": "US"}]
# [{"id": 23496, "logo_path": "None", "name": "Les Films de l"Ange", "origin_country": ""}]
# [{"id": 13693, "logo_path": "None", "name": "Swingin" Productions", "origin_country": ""}, {"id": 38617, "logo_path": "None", "name": "Quantum Entertainment", "origin_country": ""}, {"id": 75896, "logo_path": "None", "name": "Ushakiron Movies International", "origin_country": ""}]
# [{"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 635, "logo_path": "None", "name": "Les Films Alain Sarde", "origin_country": "FR"}, {"id": 168443, "logo_path": "None", "name": "Sofica Studio Images 8", "origin_country": ""}, {"id": 356, "logo_path": "/9tW5wZEGotn1Ei5pErA88m47XiD.png", "name": "TF1 Films Production", "origin_country": "FR"}, {"id": 67543, "logo_path": "None", "name": "Tentative d"Evasion", "origin_country": ""}]
# [{"id": 25224, "logo_path": "None", "name": "Les Aventuriers de l"Image", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 25206, "logo_path": "None", "name": "La Sorcière Rouge", "origin_country": ""}]
# [{"id": 98428, "logo_path": "None", "name": scythe productions", "origin_country": ""}]
# [{"id": 2901, "logo_path": "None", "name": "ADR Productions", "origin_country": ""}, {"id": 13728, "logo_path": "/bpsUvoLS3Xms2xXOPQFq5nLZI5J.png", "name": "Nomadis Images", "origin_country": "TN"}, {"id": 75449, "logo_path": "None", "name": "A.N.P.A. (Agence Nationale de Promotion de l"Audiovisuel)", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}]
# [{"id": 11517, "logo_path": "/7tT0PqNjEalEwE1GkjxU32SlOW6.png", "name": "Buffalo Gal Pictures", "origin_country": "CA"}, {"id": 20255, "logo_path": "None", "name": "Les Films de l"Isle", "origin_country": ""}, {"id": 22321, "logo_path": "None", "name": "Transmar Films", "origin_country": ""}]
# [{"id": 16450, "logo_path": "None", "name": "Filmes do Tejo", "origin_country": "PT"}, {"id": 6669, "logo_path": "None", "name": "Les Films de l"Après-Midi", "origin_country": "FR"}]
# [{"id": 16791, "logo_path": "None", "name": "Newman/Tooley Films", "origin_country": ""}, {"id": 37103, "logo_path": "None", "name": ""DIA" Productions GmbH & Co. KG", "origin_country": ""}, {"id": 21975, "logo_path": "None", "name": "Joseph Nittolo Entertainment", "origin_country": ""}, {"id": 12, "logo_path": "/iaYpEp3LQmb8AfAtmTvpqd4149c.png", "name": "New Line Cinema", "origin_country": "US"}]
# [{"id": 19551, "logo_path": "/2WpWp9b108hizjHKdA107hFmvQ5.png", "name": "Marvel Enterprises", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 9168, "logo_path": "/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png", "name": "Bad Hat Harry Productions", "origin_country": "US"}, {"id": 79027, "logo_path": "None", "name": "XF2 Canada Productions", "origin_country": ""}, {"id": 25, "logo_path": "/qZCc1lty5FzX30aOCVRBLzaVmcp.png", "name": "20th Century Fox", "origin_country": "US"}]
# [{"id": 4, "logo_path": "/gz66EfNoYPqHTYI4q9UEN4CbHRc.png", "name": "Paramount", "origin_country": "US"}, {"id": 762, "logo_path": "None", "name": "Mutual Film Company", "origin_country": ""}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 18619, "logo_path": "None", "name": "Cobalt Media Group", "origin_country": ""}, {"id": 18620, "logo_path": "None", "name": "Artists Production Group (APG)", "origin_country": ""}]
# [{"id": 7943, "logo_path": "None", "name": "Mascaret Films", "origin_country": ""}, {"id": 1523, "logo_path": "None", "name": "Ciné Valse", "origin_country": ""}, {"id": 5757, "logo_path": "None", "name": "P"Artisan Filmproduktion GmbH", "origin_country": ""}, {"id": 260, "logo_path": "None", "name": "Heritage Films", "origin_country": "PL"}]
# [{"id": 79751, "logo_path": "None", "name": "Sidecar Films & TV", "origin_country": ""}, {"id": 97958, "logo_path": "None", "name": "L"Ottava", "origin_country": ""}]
# [{"id": 61370, "logo_path": "None", "name": "Grupong Sinehan", "origin_country": ""}, {"id": 131854, "logo_path": "None", "name": "Up Cineastes" Studio", "origin_country": ""}]
# [{"id": 50458, "logo_path": "/kJr7qaViqRAKVWqgHuGSq8Bgc8p.png", "name": "Pink"O", "origin_country": "IT"}]
# [{"id": 96523, "logo_path": "None", "name": "Dirt Road Films", "origin_country": ""}, {"id": 53569, "logo_path": "None", "name": soap factory GmbH", "origin_country": "CH"}]
# [{"id": 177, "logo_path": "None", "name": "Columbia TriStar", "origin_country": ""}, {"id": 85999, "logo_path": "None", "name": "absolutely productions", "origin_country": ""}, {"id": 86000, "logo_path": "None", "name": stella street ltd.", "origin_country": ""}]
# [{"id": 74682, "logo_path": "None", "name": "Kinokompaniya "Tsar"", "origin_country": ""}]
# [{"id": 12030, "logo_path": "None", "name": "Ateliers de Baere", "origin_country": ""}, {"id": 107357, "logo_path": "None", "name": "Bluelight l"Ecole", "origin_country": "GB"}, {"id": 207, "logo_path": "/uskenzq65wJe0cT0D8StQI3hJnO.png", "name": "Agat Films & Cie / Ex Nihilo", "origin_country": "FR"}]
# [{"id": 98428, "logo_path": "None", "name": scythe productions", "origin_country": ""}, {"id": 35518, "logo_path": "None", "name": "Film Harvest", "origin_country": ""}]
# [{"id": 72701, "logo_path": "None", "name": "Non Stop Film Service", "origin_country": "PL"}, {"id": 7984, "logo_path": "None", "name": "Zespól Filmowy "Tor"", "origin_country": ""}, {"id": 266, "logo_path": "None", "name": "Agencja Produkcji Filmowej", "origin_country": "PL"}]
# [{"id": 2387, "logo_path": "None", "name": sabotage film GmbH", "origin_country": ""}, {"id": 4606, "logo_path": "/otZHbf1HmzLRQsZFSqJXkf8EHz7.png", "name": "ZDF", "origin_country": "DE"}]
# [{"id": 79, "logo_path": "/tpFpsqbleCzEE2p5EgvUq6ozfCA.png", "name": "Village Roadshow Pictures", "origin_country": "US"}, {"id": 429, "logo_path": "/2Tc1P3Ac8M479naPp1kYT3izLS5.png", "name": "DC Comics", "origin_country": "US"}, {"id": 430, "logo_path": "None", "name": "Lonely Film Productions GmbH & Co. KG.", "origin_country": ""}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 432, "logo_path": "None", "name": "Branded Entertainment/Batfilm Productions", "origin_country": ""}, {"id": 433, "logo_path": "None", "name": "Weed Road Pictures", "origin_country": "US"}, {"id": 434, "logo_path": "None", "name": "3 Art Entertainment", "origin_country": ""}, {"id": 435, "logo_path": "/AjzK0s2w1GtLfR4hqCjVSYi0Sr8.png", "name": "Di Bonaventura Pictures", "origin_country": "US"}, {"id": 174, "logo_path": "/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png", "name": "Warner Bros. Pictures", "origin_country": "US"}]
# [{"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 836, "logo_path": "/93zzVd8ijSExx6DhVI4Xqj8WmOJ.png", "name": "Elzévir Films", "origin_country": "FR"}, {"id": 837, "logo_path": "None", "name": "Oï  Oï  Oï Productions", "origin_country": ""}, {"id": 10102, "logo_path": "/b0g4aEM39p0PwbIiaU1Cg3ZZUAq.png", "name": "Cattleya", "origin_country": "IT"}, {"id": 2210, "logo_path": "None", "name": "K2 SA", "origin_country": ""}, {"id": 26629, "logo_path": "None", "name": "Transfax Film Productions", "origin_country": "IL"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 6246, "logo_path": "None", "name": "Medusa Film", "origin_country": "IT"}, {"id": 2250, "logo_path": "None", "name": "SCOPE Invest", "origin_country": ""}, {"id": 6301, "logo_path": "/jma8ZaHq1KAzlXW3v0RswVOWSdn.png", "name": "CinéCinéma", "origin_country": "FR"}, {"id": 95446, "logo_path": "None", "name": "Kiosque", "origin_country": ""}, {"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 11921, "logo_path": "/gqvfasbanyk8hIKDM2EVT6Sn2AO.png", "name": "Le Tax Shelter du Gouvernement Fédéral de Belgique", "origin_country": "BE"}, {"id": 851, "logo_path": "None", "name": "MEDIA Programme of the European Union", "origin_country": ""}, {"id": 11199, "logo_path": "/ursSXLOZaDxiZ84sEgfXbiFnYaa.png", "name": "SCOPE Pictures", "origin_country": "BE"}]
# [{"id": 5, "logo_path": "/71BqEFAF4V3qjjMPCpLuyJFB9A.png", "name": "Columbia Pictures", "origin_country": "US"}, {"id": 7, "logo_path": "/vru2SssLX3FPhnKZGtYw00pVIS9.png", "name": "DreamWorks Pictures", "origin_country": "US"}, {"id": 158, "logo_path": "/6SHlNIype9zmyEMRsBtoueUtLsq.png", "name": "Spyglass Entertainment", "origin_country": "US"}, {"id": 56, "logo_path": "/cEaxANEisCqeEoRvODv2dO1I0iI.png", "name": "Amblin Entertainment", "origin_country": "US"}, {"id": 14440, "logo_path": "None", "name": "Red Wagon Entertainment", "origin_country": "US"}, {"id": 14870, "logo_path": "None", "name": "United Performers" Studio", "origin_country": ""}, {"id": 14, "logo_path": "/m6AHu84oZQxvq7n1rsvMNJIAsMu.png", "name": "Miramax", "origin_country": "US"}, {"id": 113521, "logo_path": "/fF4xLqMQ0C6Laql7HpzRnvn8hfi.png", "name": "StudioCanal", "origin_country": "GB"}]
# [{"id": 7799, "logo_path": "None", "name": "TF1 International", "origin_country": "FR"}, {"id": 23087, "logo_path": "None", "name": "L"Arbre et la Colombe", "origin_country": ""}, {"id": 6586, "logo_path": "None", "name": "TPS Star", "origin_country": "FR"}, {"id": 4888, "logo_path": "None", "name": "M6 Studio", "origin_country": "FR"}, {"id": 2756, "logo_path": "None", "name": "Vertigo Productions", "origin_country": "FR"}]
# [{"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 11687, "logo_path": "None", "name": "Le Fresnoy", "origin_country": "FR"}, {"id": 15530, "logo_path": "None", "name": "Les Films Hatari", "origin_country": "FR"}, {"id": 57614, "logo_path": "None", "name": "Unlimited", "origin_country": ""}, {"id": 88412, "logo_path": "None", "name": "Les Films de L"Etranger", "origin_country": "FR"}, {"id": 95253, "logo_path": "None", "name": "Digimage", "origin_country": ""}, {"id": 95254, "logo_path": "None", "name": "Film Council Productions", "origin_country": ""}, {"id": 95255, "logo_path": "None", "name": "Les Filmsoir", "origin_country": ""}, {"id": 95256, "logo_path": "None", "name": "Onoma", "origin_country": ""}, {"id": 95257, "logo_path": "None", "name": "Poly-Son", "origin_country": ""}]
# [{"id": 108537, "logo_path": "None", "name": sony", "origin_country": ""}]
# [{"id": 850, "logo_path": "/aF7qajGJGtMpdrtvssM9g90YanX.png", "name": "Eurimages", "origin_country": "FR"}, {"id": 1926, "logo_path": "/sORCydQs61kwWqRIIzPiBpgVVag.png", "name": "Les Films du Fleuve", "origin_country": "BE"}, {"id": 2250, "logo_path": "None", "name": "SCOPE Invest", "origin_country": ""}, {"id": 11199, "logo_path": "/ursSXLOZaDxiZ84sEgfXbiFnYaa.png", "name": "SCOPE Pictures", "origin_country": "BE"}, {"id": 11932, "logo_path": "None", "name": "Centre du Cinéma et de l"Audiovisuel de la Communauté Française de Belgique", "origin_country": "BE"}, {"id": 12352, "logo_path": "/fkIacb6MddD6trIWamr33SIcUAn.png", "name": "Wallimage", "origin_country": "BE"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 792, "logo_path": "/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png", "name": "RTBF", "origin_country": "BE"}, {"id": 2695, "logo_path": "None", "name": "Archipel 33>35", "origin_country": "FR"}]
# [{"id": 8117, "logo_path": "/eVsVPEZRK63zsQMxxSHf5Cv017g.png", "name": "Max Films", "origin_country": "CA"}, {"id": 11578, "logo_path": "/us1W5CytIttX4F526bRJmrS36dJ.png", "name": "Super Écran", "origin_country": "CA"}, {"id": 94223, "logo_path": "None", "name": "Crédit d"Impôt pour la Production Cinématographique ou Magnétoscopique Canadienne", "origin_country": ""}, {"id": 57579, "logo_path": "/grILVkf42n5aNwGR6bjYRR9WUVx.png", "name": "ICI Radio-Canada Télé", "origin_country": "CA"}, {"id": 174443, "logo_path": "None", "name": "Québec Crédit d"Impôt Cinéma et Télévison", "origin_country": ""}, {"id": 9116, "logo_path": "/vYeYdFxDWoqBzFgYz2Tf9d2ZseE.png", "name": "SODEC", "origin_country": "CA"}, {"id": 806, "logo_path": "/kcNh09qqR2Pkw1JAzRW4CommrW4.png", "name": "Téléfilm Canada", "origin_country": "CA"}]
# [{"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 444, "logo_path": "/42UPdZl6B2cFXgNUASR8hSt9mpS.png", "name": "Dune Entertainment", "origin_country": "US"}, {"id": 445, "logo_path": "None", "name": "Major Studio Partners", "origin_country": "US"}, {"id": 9168, "logo_path": "/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png", "name": "Bad Hat Harry Productions", "origin_country": "US"}, {"id": 79028, "logo_path": "None", "name": "X3 Canada Productions", "origin_country": ""}, {"id": 79029, "logo_path": "None", "name": "X3US Productions", "origin_country": ""}, {"id": 79030, "logo_path": "None", "name": "XM3 Service", "origin_country": ""}, {"id": 25, "logo_path": "/qZCc1lty5FzX30aOCVRBLzaVmcp.png", "name": "20th Century Fox", "origin_country": "US"}, {"id": 446, "logo_path": "/d9EQKqrGy25s61Bsh10nO0BfzPF.png", "name": "thinkfilm", "origin_country": "US"}, {"id": 7505, "logo_path": "/837VMM4wOkODc1idNxGT0KQJlej.png", "name": "Marvel Entertainment", "origin_country": "US"}, {"id": 290, "logo_path": "/Q8mw2AOQQc8Qg0uNwLWq86DVZv.png", "name": "Ingenious Media", "origin_country": "GB"}]
# [{"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 122638, "logo_path": "None", "name": "République de Côte d"Ivoire", "origin_country": ""}, {"id": 13542, "logo_path": "/sJ0R9LDMGR5ildYS4GMhQcbKJVD.png", "name": "CNRS Images", "origin_country": "FR"}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 2326, "logo_path": "None", "name": "Autonomous", "origin_country": ""}, {"id": 122639, "logo_path": "None", "name": "Éliane de Latour Production", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 1249, "logo_path": "None", "name": "Les Films du Lendemain", "origin_country": "FR"}, {"id": 122640, "logo_path": "None", "name": "Cognition", "origin_country": ""}, {"id": 122641, "logo_path": "None", "name": "Ice Breaker", "origin_country": ""}, {"id": 122642, "logo_path": "None", "name": "Kings Road Picture Company", "origin_country": ""}]
# [{"id": 83, "logo_path": "/9OQ0rm55xtlgX7KcAKMUePJSrQc.png", "name": "France 2 Cinéma", "origin_country": "FR"}, {"id": 4045, "logo_path": "None", "name": "Cinegram", "origin_country": "GR"}, {"id": 23495, "logo_path": "None", "name": "Titania Produzioni", "origin_country": "IT"}, {"id": 98757, "logo_path": "None", "name": "Les films de l"instant", "origin_country": ""}, {"id": 98758, "logo_path": "None", "name": "Films 18", "origin_country": ""}, {"id": 98759, "logo_path": "None", "name": "CG Studios", "origin_country": ""}]
# [{"id": 1088, "logo_path": "/9WOE5AQUXbOtLU6GTwfjS8OMF0v.png", "name": "Alcon Entertainment", "origin_country": "US"}, {"id": 10405, "logo_path": "None", "name": "EFO Films", "origin_country": "US"}, {"id": 890, "logo_path": "None", "name": "Cheyenne Enterprises", "origin_country": ""}, {"id": 10885, "logo_path": "None", "name": "Equity Pictures Medienfonds GmbH & Co. KG III", "origin_country": ""}, {"id": 10886, "logo_path": "None", "name": "16 Block Productions", "origin_country": ""}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 1020, "logo_path": "/kuUIHNwMec4dwOLghDhhZJzHZTd.png", "name": "Millennium Films", "origin_country": "US"}, {"id": 925, "logo_path": "/dIb9hjXNOkgxu4kBWdIdK8nM4w.png", "name": "Nu Image", "origin_country": "US"}, {"id": 1420, "logo_path": "None", "name": "ContentFilm", "origin_country": ""}]
# [{"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 113973, "logo_path": "None", "name": "Ciné Cinéma", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 2318, "logo_path": "None", "name": "Région Provence Côte d"Azur", "origin_country": "FR"}, {"id": 2700, "logo_path": "/jqmxhA0HVNPiRD80MbBPLSNaIzA.png", "name": "Rectangle Productions", "origin_country": "FR"}, {"id": 694, "logo_path": "/5LEHONGkZBIoWvp1ygHOF8iyi1M.png", "name": "StudioCanal", "origin_country": "FR"}, {"id": 6844, "logo_path": "/yilspcMjH7xgb0AdTg1cFUowUj3.png", "name": "Thelma Films", "origin_country": "FR"}, {"id": 69459, "logo_path": "None", "name": "Uni Etoile 3", "origin_country": "FR"}]
# [{"id": 95594, "logo_path": "None", "name": "Train A Comin" Productions Inc.", "origin_country": ""}, {"id": 2274, "logo_path": "None", "name": "Element Films", "origin_country": "BG"}]
# [{"id": 83, "logo_path": "/9OQ0rm55xtlgX7KcAKMUePJSrQc.png", "name": "France 2 Cinéma", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 136842, "logo_path": "None", "name": "Atlan Films", "origin_country": ""}, {"id": 157982, "logo_path": "None", "name": "CNC", "origin_country": "FR"}, {"id": 11798, "logo_path": "None", "name": "Région Provence-Alpes-Côte d"Azur", "origin_country": ""}, {"id": 856, "logo_path": "/3tfzS2CrX6Ntbu927XzHXEPDA6y.png", "name": "Wild Bunch", "origin_country": "FR"}, {"id": 6586, "logo_path": "None", "name": "TPS Star", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 3373, "logo_path": "None", "name": "KS2 Productions", "origin_country": ""}, {"id": 28401, "logo_path": "None", "name": "Tovo Films", "origin_country": ""}, {"id": 12389, "logo_path": "/6yilbEvoHtPcTb4LwAueAq091iT.png", "name": "Les Films Pelléas", "origin_country": "FR"}]
# [{"id": 2318, "logo_path": "None", "name": "Région Provence Côte d"Azur", "origin_country": "FR"}, {"id": 2673, "logo_path": "/kgqoT0BfqE1vWEXuliWoAsglH.png", "name": "La Fabrique de Films", "origin_country": "FR"}, {"id": 9011, "logo_path": "None", "name": "Toloda", "origin_country": ""}, {"id": 21083, "logo_path": "None", "name": "Soficinéma 2", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}]
# [{"id": 174, "logo_path": "/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png", "name": "Warner Bros. Pictures", "origin_country": "US"}, {"id": 79, "logo_path": "/tpFpsqbleCzEE2p5EgvUq6ozfCA.png", "name": "Village Roadshow Pictures", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}]
# [{"id": 4740, "logo_path": "/20IuOPEwlHRXnn0MTOsEmw0wcql.png", "name": "Gary Sanchez Productions", "origin_country": "US"}, {"id": 746, "logo_path": "/kc7bdIVTBkJYy9aDK1QDDTAL463.png", "name": "MTV Films", "origin_country": "US"}, {"id": 164585, "logo_path": "None", "name": "You Know I Can"t Kiss You", "origin_country": ""}]
# [{"id": 20971, "logo_path": "None", "name": "BL Production", "origin_country": ""}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 13728, "logo_path": "/bpsUvoLS3Xms2xXOPQFq5nLZI5J.png", "name": "Nomadis Images", "origin_country": "TN"}]
# [{"id": 23596, "logo_path": "None", "name": "Paul Schiff Productions", "origin_country": "US"}, {"id": 9039, "logo_path": "None", "name": "Stick "N" Stone Productions", "origin_country": "US"}, {"id": 23597, "logo_path": "None", "name": "Island Bound Productions", "origin_country": ""}]
# [{"id": 84593, "logo_path": "None", "name": "Société des Producteurs de L"Angoa", "origin_country": ""}, {"id": 58, "logo_path": "/voYCwlBHJQANtjvm5MNIkCF1dDH.png", "name": "Sony Pictures Classics", "origin_country": "US"}, {"id": 311, "logo_path": "/TNGvZ8zOklntjPP3EcsHtrR8Rc.png", "name": "PROCIREP", "origin_country": "FR"}, {"id": 312, "logo_path": "None", "name": "Soficinéma", "origin_country": ""}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 744, "logo_path": "/iPQvLZPw7e3T3No0akup0F9o8nV.png", "name": "Diaphana Films", "origin_country": "FR"}, {"id": 854, "logo_path": "None", "name": "Sofica EuropaCorp", "origin_country": ""}, {"id": 860, "logo_path": "/aWrTeKCGu9jjsiiVSDsALC3vxu4.png", "name": "Celluloid Dreams", "origin_country": "FR"}, {"id": 862, "logo_path": "/udTjbqPmcTbfrihMuLtLcizDEM1.png", "name": "The Kennedy/Marshall Company", "origin_country": "US"}, {"id": 11246, "logo_path": "/4YZ5CQZkJa2FIKGtjLLoKhNOAIw.png", "name": "Région Ile-de-France", "origin_country": "FR"}, {"id": 23677, "logo_path": "None", "name": "Fondation GAN pour le Cinéma", "origin_country": ""}, {"id": 62546, "logo_path": "None", "name": "2.4.7. Films", "origin_country": "FR"}, {"id": 84592, "logo_path": "None", "name": "French Connection Animations", "origin_country": "FR"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}]
# [{"id": 30995, "logo_path": "None", "name": "3H Productions", "origin_country": ""}, {"id": 2670, "logo_path": "None", "name": "Margo Films", "origin_country": "FR"}, {"id": 1249, "logo_path": "None", "name": "Les Films du Lendemain", "origin_country": "FR"}, {"id": 6301, "logo_path": "/jma8ZaHq1KAzlXW3v0RswVOWSdn.png", "name": "CinéCinéma", "origin_country": "FR"}, {"id": 79022, "logo_path": "None", "name": "Sofica Poste Image", "origin_country": ""}, {"id": 11246, "logo_path": "/4YZ5CQZkJa2FIKGtjLLoKhNOAIw.png", "name": "Région Ile-de-France", "origin_country": "FR"}, {"id": 25205, "logo_path": "None", "name": "Soficinéma 3", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 2381, "logo_path": "/hmzO0vmTZjfGoMoS5pykenpmHWH.png", "name": "Musée d"Orsay", "origin_country": "FR"}]
# [{"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 6246, "logo_path": "None", "name": "Medusa Film", "origin_country": "IT"}, {"id": 5030, "logo_path": "None", "name": "Offside", "origin_country": ""}, {"id": 19079, "logo_path": "None", "name": "Sky", "origin_country": ""}]
# [{"id": 2317, "logo_path": "None", "name": "Cofinova 3", "origin_country": "FR"}, {"id": 2318, "logo_path": "None", "name": "Région Provence Côte d"Azur", "origin_country": "FR"}]
# [{"id": 6670, "logo_path": "None", "name": "Filmes do Tejo II", "origin_country": "PT"}, {"id": 6669, "logo_path": "None", "name": "Les Films de l"Après-Midi", "origin_country": "FR"}, {"id": 81547, "logo_path": "None", "name": "Ministério da Cultura", "origin_country": ""}]
# [{"id": 22139, "logo_path": "None", "name": "Art"Mell", "origin_country": "FR"}, {"id": 47413, "logo_path": "/tWgdrvRArGnERk9lmr4IkqoiMoZ.png", "name": "CAPA", "origin_country": "FR"}, {"id": 56802, "logo_path": "None", "name": "Fantascope", "origin_country": ""}, {"id": 26065, "logo_path": "None", "name": "Piste Rouge", "origin_country": ""}, {"id": 53030, "logo_path": "None", "name": "Starfield Productions", "origin_country": ""}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 58669, "logo_path": "None", "name": "Rhamsa Productions", "origin_country": ""}]
# [{"id": 29036, "logo_path": "None", "name": "Fog"n"Desire Films", "origin_country": "CZ"}, {"id": 3837, "logo_path": "None", "name": "Bioscop", "origin_country": "CZ"}]
# [{"id": 50458, "logo_path": "/kJr7qaViqRAKVWqgHuGSq8Bgc8p.png", "name": "Pink"O", "origin_country": "IT"}]
# [{"id": 2387, "logo_path": "None", "name": sabotage film GmbH", "origin_country": ""}, {"id": 1251, "logo_path": "/ucgmv8vBIA3Tr2VbqQ1NKYgkTsN.png", "name": "ARD", "origin_country": "DE"}]
# [{"id": 6332, "logo_path": "/42UPdZl6B2cFXgNUASR8hSt9mpS.png", "name": "Dune Entertainment III", "origin_country": "US"}, {"id": 43, "logo_path": "/4RgIPr55kBakgupWkzdDxqXJEqr.png", "name": "Fox Searchlight Pictures", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 907, "logo_path": "/ca5SWI5uvU985f8Kbb4xc8AmVWH.png", "name": "Overbrook Entertainment", "origin_country": "US"}]
# [{"id": 26772, "logo_path": "None", "name": "J&J JAKUBISKO FILM EUROPE Production s.r.o.", "origin_country": "SK"}, {"id": 16016, "logo_path": "None", "name": "Eurofilm Stúdió", "origin_country": "HU"}, {"id": 26773, "logo_path": "None", "name": "J&J Jakubisko Film", "origin_country": "CZ"}, {"id": 2568, "logo_path": "None", "name": "Lunar Films", "origin_country": "GB"}, {"id": 26774, "logo_path": "None", "name": "Concorde Film Trust", "origin_country": "HU"}, {"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 26775, "logo_path": "None", "name": "Ministry of Culture of the Slovak Republic", "origin_country": "SK"}, {"id": 6062, "logo_path": "None", "name": "Státní fond ČR pro podporu a rozvoj české kinematografie", "origin_country": "CZ"}]
# [{"id": 12, "logo_path": "/iaYpEp3LQmb8AfAtmTvpqd4149c.png", "name": "New Line Cinema", "origin_country": "US"}, {"id": 1001, "logo_path": "None", "name": "Solaris Film", "origin_country": ""}, {"id": 12066, "logo_path": "None", "name": "O"Connor Brothers", "origin_country": ""}, {"id": 1565, "logo_path": "None", "name": "Avery Pix", "origin_country": "US"}, {"id": 12067, "logo_path": "None", "name": "Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 1 KG", "origin_country": ""}]
# [{"id": 2381, "logo_path": "/hmzO0vmTZjfGoMoS5pykenpmHWH.png", "name": "Musée d"Orsay", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 6586, "logo_path": "None", "name": "TPS Star", "origin_country": "FR"}]
# [{"id": 12, "logo_path": "/iaYpEp3LQmb8AfAtmTvpqd4149c.png", "name": "New Line Cinema", "origin_country": "US"}, {"id": 748, "logo_path": "None", "name": "Mosaic Media Group", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 2648, "logo_path": "None", "name": "Road Rebel", "origin_country": ""}]
# ...
# [{"id": 60656, "logo_path": "None", "name": "Souvenir Films", "origin_country": ""}, {"id": 69987, "logo_path": "None", "name": "Uncork"d Entertainment", "origin_country": ""}]
# [{"id": 84532, "logo_path": "None", "name": "Mita"i Films", "origin_country": ""}]
# [{"id": 122393, "logo_path": "None", "name": "Bronwyn Cornelius Productions", "origin_country": ""}, {"id": 10745, "logo_path": "None", "name": spectrum studios", "origin_country": ""}, {"id": 38230, "logo_path": "None", "name": "Anarchy Post", "origin_country": ""}]
# [{"id": 85212, "logo_path": "/qIxFahRmNORWPLd7EbSYq3GXi42.png", "name": seriousFilm", "origin_country": "NL"}, {"id": 173045, "logo_path": "None", "name": "Absent Without Leave", "origin_country": ""}]
# [{"id": 121124, "logo_path": "None", "name": "Diversion", "origin_country": "TH"}, {"id": 89842, "logo_path": "None", "name": "DAMNED FILMS", "origin_country": ""}, {"id": 54589, "logo_path": "None", "name": "Sluizer Films", "origin_country": ""}, {"id": 155788, "logo_path": "None", "name": "M"GO Films", "origin_country": ""}, {"id": 126451, "logo_path": "None", "name": "Mit Out Sound Films", "origin_country": ""}]
# [{"id": 152668, "logo_path": "None", "name": "Place of Power", "origin_country": "RU"}, {"id": 69021, "logo_path": "None", "name": "Look-Film", "origin_country": "RU"}, {"id": 103580, "logo_path": "None", "name": "KinoVista", "origin_country": "FR"}, {"id": 6144, "logo_path": "None", "name": "Homeless Bob Production", "origin_country": "EE"}, {"id": 15755, "logo_path": "/cZDbkvJPOnzHlmu2CDx05DcEnaf.png", "name": "Ministry of Culture of the Russian Federation", "origin_country": "RU"}, {"id": 125613, "logo_path": "/llbR8dccO5UlzJ3x1gzdQWmOuuS.png", "name": "Kinoprime Foundation", "origin_country": "RU"}, {"id": 850, "logo_path": "/aF7qajGJGtMpdrtvssM9g90YanX.png", "name": "Eurimages", "origin_country": "FR"}, {"id": 72596, "logo_path": "None", "name": "L"Aide aux Cinémas du Monde", "origin_country": ""}]
# [{"id": 87032, "logo_path": "/71mp8rPAXpFdEOrcCUetcui3WUC.png", "name": "Kidam", "origin_country": "FR"}, {"id": 53509, "logo_path": "/xmJMAss7BDsQPvODjYkDQKiNhUX.png", "name": "Wrong Men North", "origin_country": "BE"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 162201, "logo_path": "None", "name": "Région de Bruxelles-Capitale", "origin_country": ""}, {"id": 157982, "logo_path": "None", "name": "CNC", "origin_country": "FR"}, {"id": 11997, "logo_path": "None", "name": "BNP Paribas Fortis", "origin_country": "BE"}, {"id": 792, "logo_path": "/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png", "name": "RTBF", "origin_country": "BE"}, {"id": 92187, "logo_path": "/yrAyYme1zlZtHuhlWS3DlFAj762.png", "name": "Proximus", "origin_country": "BE"}, {"id": 11797, "logo_path": "/oeBCBsLLlIj2UNQBZZkhlPdDOJG.png", "name": "VOO", "origin_country": "BE"}, {"id": 24430, "logo_path": "/7ZIwXTA5QVD6feybiITOL6OYJPJ.png", "name": "BeTV", "origin_country": "BE"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 167235, "logo_path": "None", "name": "Indéfilms 9", "origin_country": ""}, {"id": 170358, "logo_path": "None", "name": "Cinéventure 5", "origin_country": ""}, {"id": 174106, "logo_path": "None", "name": "Cinéventure 6", "origin_country": ""}, {"id": 114955, "logo_path": "None", "name": "Tax Shelter du Gouvernement Fédéral Belge", "origin_country": "BE"}, {"id": 12350, "logo_path": "None", "name": "Société des Auteurs et Compositeurs Dramatiques (SACD)", "origin_country": ""}, {"id": 161909, "logo_path": "None", "name": "Département de la Seine-Saint-Denis", "origin_country": ""}, {"id": 102874, "logo_path": "/3oHMY8bVdqo8c9KSQw1ehMc0o3V.png", "name": "Charades", "origin_country": "FR"}, {"id": 96606, "logo_path": "None", "name": "Condor", "origin_country": ""}]
# [{"id": 89839, "logo_path": "None", "name": "Pili Films", "origin_country": ""}, {"id": 54781, "logo_path": "None", "name": "Göi-Göi Productions", "origin_country": "TD"}, {"id": 92062, "logo_path": "None", "name": "Made In Germany Filmproduktion", "origin_country": "DE"}, {"id": 104419, "logo_path": "None", "name": "Beluga Tree", "origin_country": ""}, {"id": 92187, "logo_path": "/yrAyYme1zlZtHuhlWS3DlFAj762.png", "name": "Proximus", "origin_country": "BE"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 7455, "logo_path": "/lfOa1bldiwL3WFty4IGiviIKNRU.png", "name": "Cinémage 4", "origin_country": "FR"}, {"id": 157318, "logo_path": "None", "name": "Indéfilms 8", "origin_country": ""}, {"id": 22627, "logo_path": "/mZsZ3IYzoheUPTPN3WeFwOYxAkP.png", "name": "Film- und Medienstiftung NRW", "origin_country": "DE"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 122329, "logo_path": "None", "name": "Canal+ International", "origin_country": "FR"}, {"id": 20662, "logo_path": "/rxfxm2P7zJdUsXB9d5Zrg9DOXfd.png", "name": "TV5 Monde", "origin_country": "FR"}, {"id": 172978, "logo_path": "None", "name": "CNC/FFA Mini-Traite", "origin_country": ""}, {"id": 172979, "logo_path": "None", "name": "Coopération Belge au Développement", "origin_country": ""}]
# [{"id": 44632, "logo_path": "/neCKH4sJCBhZ1B4QocTM4VXCQOR.png", "name": "Gravitas Ventures", "origin_country": "US"}, {"id": 139211, "logo_path": "None", "name": "Pitch White Entertainment", "origin_country": ""}, {"id": 148421, "logo_path": "None", "name": "Brothers" Ink Productions", "origin_country": ""}]
# [{"id": 4667, "logo_path": "/o6hvcQKfrSYkKipKi9dIAWl1qIS.png", "name": "Bitters End", "origin_country": "JP"}, {"id": 10764, "logo_path": "None", "name": "C & I entertainment", "origin_country": "JP"}, {"id": 116589, "logo_path": "None", "name": "Culture Entertainment", "origin_country": "JP"}, {"id": 68374, "logo_path": "None", "name": "Agency for Cultural Affairs", "origin_country": "JP"}, {"id": 159465, "logo_path": "None", "name": "J-LOD", "origin_country": "JP"}, {"id": 159466, "logo_path": "None", "name": "nekojarashi", "origin_country": "JP"}, {"id": 22715, "logo_path": "/c4d6GLfUXbp44dbWWJqWCh7YrnO.png", "name": "Quaras", "origin_country": "JP"}, {"id": 101877, "logo_path": "None", "name": "Bungeishunju", "origin_country": ""}, {"id": 99254, "logo_path": "None", "name": "L"espace Vision", "origin_country": "JP"}, {"id": 57977, "logo_path": "/2JcgVKZ1gEY5RsLJU1CGj1MaKFj.png", "name": "The Asahi Shimbun", "origin_country": "JP"}, {"id": 3032, "logo_path": "None", "name": "Nippan Group Holdings", "origin_country": "JP"}]
# [{"id": 6669, "logo_path": "None", "name": "Les Films de l"Après-Midi", "origin_country": "FR"}]
# [{"id": 157118, "logo_path": "None", "name": "Ali n" Productions", "origin_country": ""}, {"id": 20219, "logo_path": "None", "name": "Les Films du Nouveau Monde", "origin_country": "FR"}, {"id": 72352, "logo_path": "None", "name": "Unité de Production", "origin_country": "FR"}]
# [{"id": 126286, "logo_path": "None", "name": "Heure d"Eté Productions", "origin_country": ""}]
# [{"id": 121251, "logo_path": "None", "name": "Les Films d"Argile", "origin_country": "FR"}, {"id": 16691, "logo_path": "None", "name": "Shellac Films", "origin_country": "FR"}]
# [{"id": 121268, "logo_path": "/vPtiQxlA2S3Z77eduT6TFqBG9NE.png", "name": "The Othrs", "origin_country": "US"}, {"id": 149332, "logo_path": "/AqVHovrBoc7uVlsM6aVWALeewVs.png", "name": "Vice Studios", "origin_country": "US"}, {"id": 73068, "logo_path": "/m669bsYloJvsocBzYlgAftIgVsE.png", "name": "RYOT Films", "origin_country": "US"}, {"id": 158157, "logo_path": "None", "name": "D"Artagnan", "origin_country": "FR"}, {"id": 124473, "logo_path": "/smOjK8hF9ySe2OfePFNtJqsgG5S.png", "name": "Level Forward", "origin_country": "US"}, {"id": 159048, "logo_path": "None", "name": "Hameda’s Stories", "origin_country": ""}, {"id": 153886, "logo_path": "/wcOgb8591a6a506L1bUqxEiRv1B.png", "name": "Foothill Productions", "origin_country": "US"}, {"id": 169390, "logo_path": "None", "name": "Quiet", "origin_country": "US"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 152983, "logo_path": "/AdtLOWCkTUAJkRC7FIuYmyF7Lhg.png", "name": "Willa Productions", "origin_country": "US"}]
# [{"id": 69987, "logo_path": "None", "name": "Uncork"d Entertainment", "origin_country": ""}, {"id": 164252, "logo_path": "None", "name": "TrapDark", "origin_country": ""}]
# [{"id": 8997, "logo_path": "None", "name": "SBS Productions", "origin_country": ""}, {"id": 24845, "logo_path": "/eRT3fMGdAaQaFyOYXMEIt8GCe6I.png", "name": "Topkapi Films", "origin_country": "NL"}, {"id": 7981, "logo_path": "/6Yv1gIAuGkHS5Vis4UjnqHhCPWV.png", "name": "Pathé", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 78300, "logo_path": "/cFR4kN2bUJo4jo5aIgn7gmU6ur0.png", "name": "Belga Films Fund", "origin_country": "BE"}, {"id": 83, "logo_path": "/9OQ0rm55xtlgX7KcAKMUePJSrQc.png", "name": "France 2 Cinéma", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 78298, "logo_path": "/9U7x4fLDn8EVEZTc4usYeJV1uHF.png", "name": "Belga Productions", "origin_country": "BE"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 122285, "logo_path": "None", "name": "Cinémage 13", "origin_country": ""}, {"id": 133529, "logo_path": "None", "name": "Cofimage 30", "origin_country": ""}, {"id": 122284, "logo_path": "None", "name": "Cofinova 15", "origin_country": ""}, {"id": 7131, "logo_path": "/eLvjHPYZ12GR58lrDgg6MXZp2a3.png", "name": "France Télévisions", "origin_country": "FR"}, {"id": 122283, "logo_path": "None", "name": "Indéfilms 7", "origin_country": ""}, {"id": 22628, "logo_path": "None", "name": "Netherland Filmfund", "origin_country": ""}, {"id": 122282, "logo_path": "None", "name": "Palatine Etoile 16", "origin_country": ""}, {"id": 11798, "logo_path": "None", "name": "Région Provence-Alpes-Côte d"Azur", "origin_country": ""}]
# [{"id": 134143, "logo_path": "None", "name": "StudioBauhaus", "origin_country": ""}, {"id": 157614, "logo_path": "None", "name": "Utopie Films (FR)", "origin_country": ""}, {"id": 80504, "logo_path": "None", "name": ""None"theless Productions", "origin_country": ""}]
# [{"id": 61201, "logo_path": "None", "name": "Anna Sanders Films", "origin_country": "FR"}, {"id": 16889, "logo_path": "/iqTRJp4dVJifIFMTw08sf1Zv5W2.png", "name": "Burning Blue", "origin_country": "CO"}, {"id": 24372, "logo_path": "/5GC9vLJ27fPCCA5bIj7IJ5GXQS0.png", "name": "Illuminations Films", "origin_country": "GB"}, {"id": 59665, "logo_path": "None", "name": "Kick the Machine", "origin_country": "TH"}, {"id": 19771, "logo_path": "/anRmhRCSY9fXOIygcjjVHL4bWL1.png", "name": "Piano", "origin_country": "MX"}, {"id": 7306, "logo_path": "/qeZiPsQpCq7r1MrQgM7op2BQcPZ.png", "name": "The Match Factory", "origin_country": "DE"}, {"id": 4606, "logo_path": "/otZHbf1HmzLRQsZFSqJXkf8EHz7.png", "name": "ZDF", "origin_country": "DE"}, {"id": 587, "logo_path": "/6UIpEURdjnmcJPwgTDRzVRuwADr.png", "name": "ARTE", "origin_country": "DE"}, {"id": 11237, "logo_path": "None", "name": "ZDF/Arte", "origin_country": "DE"}, {"id": 1079, "logo_path": "None", "name": "Xstream Pictures", "origin_country": "CN"}, {"id": 47416, "logo_path": "/1SGwPd5snC2OHk4vW8w3m6ET6jc.png", "name": "Sovereign Films", "origin_country": "GB"}, {"id": 104615, "logo_path": "None", "name": "Schortcut Films", "origin_country": ""}, {"id": 127914, "logo_path": "/xaPfwbAnv2ULcCil5x6dPFmFs8z.png", "name": "Rediance", "origin_country": "CN"}, {"id": 127915, "logo_path": "None", "name": "Purin Foundation", "origin_country": ""}, {"id": 71209, "logo_path": "None", "name": "Proimagenes Colombia", "origin_country": "CO"}, {"id": 72598, "logo_path": "None", "name": "Ministère des Affaires étrangères et du Développement International", "origin_country": "FR"}, {"id": 8469, "logo_path": "None", "name": "Louverture Films", "origin_country": "US"}, {"id": 58879, "logo_path": "/le0j7yzBOYcxGqC7YeuiFmgP5E3.png", "name": "Labo", "origin_country": "MX"}, {"id": 72596, "logo_path": "None", "name": "L"Aide aux Cinémas du Monde", "origin_country": ""}, {"id": 13413, "logo_path": "None", "name": "Hubert Bals Fund", "origin_country": "NL"}, {"id": 89127, "logo_path": "None", "name": "Eficine", "origin_country": ""}, {"id": 8152, "logo_path": "/shnLD1Pj9d1vB2TH93QHSNT5gzW.png", "name": "DFI", "origin_country": "QA"}, {"id": 7970, "logo_path": "/so1bsD7PbaSsFio7gVyW0M3qhsc.png", "name": "Bord Cadre Films", "origin_country": "CH"}, {"id": 127917, "logo_path": "None", "name": "Beijing Contemporary Art Foundation", "origin_country": ""}, {"id": 108142, "logo_path": "None", "name": "185 Films", "origin_country": "FR"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 451, "logo_path": "/g1GRk1SdwxNwg5J3aXtrqTaXo8k.png", "name": "Medienboard Berlin-Brandenburg", "origin_country": "DE"}, {"id": 71551, "logo_path": "/97Cvt9E0qIZGarpO0PP604zELCV.png", "name": "Field of Vision", "origin_country": "US"}, {"id": 90733, "logo_path": "/3K9wCZTyDgop3ITK1rDi6T2PckE.png", "name": "Neon", "origin_country": "US"}]
# [{"id": 42765, "logo_path": "/gFr0hFU857cktTimsiRDGtFe3Ld.png", "name": "Les Films de l"Arlequin", "origin_country": "FR"}, {"id": 79397, "logo_path": "None", "name": "Xbo films", "origin_country": "FR"}, {"id": 201, "logo_path": "/6UIpEURdjnmcJPwgTDRzVRuwADr.png", "name": "ARTE", "origin_country": "FR"}, {"id": 71406, "logo_path": "None", "name": "Balance Film", "origin_country": "DE"}, {"id": 6719, "logo_path": "None", "name": "MAUR film", "origin_country": "CZ"}, {"id": 587, "logo_path": "/6UIpEURdjnmcJPwgTDRzVRuwADr.png", "name": "ARTE", "origin_country": "DE"}, {"id": 487, "logo_path": "/x3BUIowxU2skXOpnOeOkl7kIYDo.png", "name": "Česká televize", "origin_country": "CZ"}]
# [{"id": 115963, "logo_path": "None", "name": "Wild Eye Releasing", "origin_country": ""}, {"id": 69987, "logo_path": "None", "name": "Uncork"d Entertainment", "origin_country": ""}]
# [{"id": 83960, "logo_path": "None", "name": "ChevalDeuxTrois", "origin_country": "FR"}, {"id": 53509, "logo_path": "/xmJMAss7BDsQPvODjYkDQKiNhUX.png", "name": "Wrong Men North", "origin_country": "BE"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 792, "logo_path": "/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png", "name": "RTBF", "origin_country": "BE"}, {"id": 92187, "logo_path": "/yrAyYme1zlZtHuhlWS3DlFAj762.png", "name": "Proximus", "origin_country": "BE"}, {"id": 11797, "logo_path": "/oeBCBsLLlIj2UNQBZZkhlPdDOJG.png", "name": "VOO", "origin_country": "BE"}, {"id": 24430, "logo_path": "/7ZIwXTA5QVD6feybiITOL6OYJPJ.png", "name": "BeTV", "origin_country": "BE"}, {"id": 105095, "logo_path": "/jk8qdzJEaQPeVc3dawOKVDk1Cz9.png", "name": "MUBI", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}]

# %%
#create a new list of production companies
companies_exploded = tmdb_df.explode('production_companies_list')
companies_exploded
# Out:
#          imdb_id  adult                     backdrop_path  \
# 0      tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 0      tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 0      tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 0      tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1      tt0113092    0.0                               NaN
# ...          ...    ...                               ...
# 61328  tt9898844    0.0  /q2KFBGyUSzHDhNqXEYv2LqTWVSz.jpg
# 61328  tt9898844    0.0  /q2KFBGyUSzHDhNqXEYv2LqTWVSz.jpg
# 61329  tt9900940    0.0  /3jjWLg5bevWqReyVroYqxwVrH0k.jpg
# 61330  tt9907782    0.0  /gRTYArznK1MLAq7opC1tYHnTwM3.jpg
# 61330  tt9907782    0.0  /gRTYArznK1MLAq7opC1tYHnTwM3.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN  10000000.0
# 0                       NaN  10000000.0
# 0                       NaN  10000000.0
# 0                       NaN  10000000.0
# 1                       NaN         0.0
# ...                     ...         ...
# 61328                   NaN         0.0
# 61328                   NaN         0.0
# 61329                   NaN         0.0
# 61330                   NaN         0.0
# 61330                   NaN         0.0
#
#                                                   genres homepage        id  \
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 1               [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977.0
# ...                                                  ...      ...       ...
# 61328                     [{'id': 27, 'name': 'Horror'}]      NaN  870671.0
# 61328                     [{'id': 27, 'name': 'Horror'}]      NaN  870671.0
# 61329  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN  861294.0
# 61330  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...      NaN  630392.0
# 61330  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...      NaN  630392.0
#
#       original_language   original_title  ...  \
# 0                    en  The Fantasticks  ...
# 0                    en  The Fantasticks  ...
# 0                    en  The Fantasticks  ...
# 0                    en  The Fantasticks  ...
# 1                    en    For the Cause  ...
# ...                 ...              ...  ...
# 61328                en      The Hunting  ...
# 61328                en      The Hunting  ...
# 61329                en     The Scrapper  ...
# 61330                en       The Cursed  ...
# 61330                en       The Cursed  ...
#
#                                         spoken_languages    status  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                  ...       ...
# 61328  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61328  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61329  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61330  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 61330  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline            title video  \
# 0      Try to remember the first time magic happened  The Fantasticks   0.0
# 0      Try to remember the first time magic happened  The Fantasticks   0.0
# 0      Try to remember the first time magic happened  The Fantasticks   0.0
# 0      Try to remember the first time magic happened  The Fantasticks   0.0
# 1       The ultimate showdown on a forbidden planet.    For the Cause   0.0
# ...                                              ...              ...   ...
# 61328                              Hunger runs deep.      The Hunting   0.0
# 61328                              Hunger runs deep.      The Hunting   0.0
# 61329                    You can't escape your past.     The Scrapper   0.0
# 61330                                            NaN       The Cursed   0.0
# 61330                                            NaN       The Cursed   0.0
#
#       vote_average  vote_count  certification collection  \
# 0              5.4        21.0            NaN       None
# 0              5.4        21.0            NaN       None
# 0              5.4        21.0            NaN       None
# 0              5.4        21.0            NaN       None
# 1              4.4         7.0            NaN       None
# ...            ...         ...            ...        ...
# 61328          4.9        20.0            NaN       None
# 61328          4.9        20.0            NaN       None
# 61329          6.0         2.0            NaN       None
# 61330          7.0        55.0              R       None
# 61330          7.0        55.0              R       None
#
#          production_companies_list
# 0      Sullivan Street Productions
# 0      Michael Ritchie Productions
# 0              Radmin Company, The
# 0                   United Artists
# 1                  Dimension Films
# ...                            ...
# 61328              Moonphase Media
# 61328          Bright Shiny Things
# 61329                 Lucky Movies
# 61330                  Piste Rouge
# 61330             LD Entertainment
#
# [115070 rows x 28 columns]

# %%
#save the unique genres
unique_companies = sorted(companies_exploded['production_companies_list'].dropna().unique())
unique_companies
# Out:
# ['# Andrea Sperling Productions',
#  '#Sinning Works',
#  '#littlesecretfilm',
#  '(주)라인필름',
#  '(주)유비컬쳐',
#  '(주)유비콘텐츠',
#  '+Magenta',
#  '.40 Caliber',
#  '.Mille et Une. Films.',
#  '.hack Conglomerate',
#  '0',
#  '01 Distribution',
#  '011 Productions',
#  '011Films',
#  '02 Filmes',
#  '0708 Films',
#  '1 Bullet in the Gun Productions',
#  '1 Media Productions',
#  '1 Production Film',
#  '1+1 Production',
#  '1-2-3 Production',
#  '1.85 Films',
#  '10 East Pictures',
#  '10 West Studios',
#  '10.80 Films',
#  '100',
#  '100 Bares',
#  '100 Feet Productions',
#  '100 Year Films',
#  '100 doo',
#  '100% Halal',
#  '1000 Volt',
#  '101 Films',
#  '101 Studios',
#  '1019 Entertainment',
#  '1019 Pictures',
#  '102 Distribution',
#  '1024 FILM',
#  '1031 Films',
#  '104 Films',
#  '1066 Pictures',
#  '108 Media',
#  '1091',
#  '1091 Media',
#  '1091 Pictures',
#  '10:15! Productions',
#  '10X Productions',
#  '10th Hole Productions',
#  '10th Street Entertainment',
#  '11 Marzo Film',
#  '1121 Productions',
#  '11:11 Entertainment',
#  '11:11 Mediaworks',
#  '12 A.M. Pictures',
#  '120 Films',
#  '120 Over 80',
#  '1201 Pictures',
#  '120E Films',
#  '120dB Films',
#  '1211 Woodlake Pictures presents',
#  '1212 Entertainment',
#  '1230 Manhattan',
#  '1244',
#  '127 Wall',
#  '12th Street Productions',
#  '13 All Stars LLC',
#  '13 Conejos',
#  '13 Entertainment',
#  '13 Films',
#  '13 Ghosts Productions Canada Inc.',
#  '13 Moons Productions LLC',
#  '13 Paces',
#  '13 Productions',
#  '13 TV',
#  '130K Frames',
#  '13th Studio, The',
#  '14 Pies',
#  '14 Reels Entertainment',
#  '14-18 NOW',
#  '1405 comunicaciones',
#  '141 Entertainment',
#  '1428 Films',
#  '1492 Pictures',
#  '14ème Art Production',
#  '15 in the Dark',
#  '1500 Entertainment',
#  '1518 Films',
#  '152 WEST Productions',
#  '1618 Action Limited',
#  '16:14 Entertainment',
#  '17 Road',
#  '17-28 Black Production',
#  '1718 Studio',
#  '18 Reels',
#  '180 Degrees',
#  '1812 Productions',
#  '1821 Pictures',
#  '185 Films',
#  '185 Trax',
#  '185º Equator',
#  '19 Entertainment',
#  '1922 Films',
#  '1976 Productions',
#  '1984 Pictures',
#  '1984 Private Defense Contractors',
#  '1991 Broadway Theatre Group',
#  '19th & Wilson',
#  '19th Floor Productions',
#  '1A Productions',
#  '1Tentertainment',
#  '1inMM Productions',
#  '1st Boll Kino Beteiligungs GmbH and Co. KG',
#  '1stAveMachine',
#  '2 A.M. Productions',
#  '2 Bridges Productions',
#  '2 Cities Productions',
#  '2 Crackers and a Lamp Productions',
#  '2 Die 4 Films',
#  '2 Entertain',
#  '2 Focus',
#  '2 Friends Media',
#  '2 Loop Films',
#  '2 Man Production',
#  '2 Minutes',
#  '2 Red Rabbit Films',
#  '2 Wolves Films',
#  '2 Wonder Full To Be',
#  '2-G Multi-Media',
#  '2-Team Productions',
#  '2.0 Entertainment',
#  '2.4.7. Films',
#  '20 Max Films',
#  '20 Steps Productions',
#  '20/20',
#  '20/20 Visions Entertainment Group',
#  '2000 Bilder',
#  '2003 Productions',
#  '2015 Project Love Live Movie',
#  '2076 Kolektib',
#  '2077883 Ontario',
#  '20ten Media',
#  '20th Century Animation',
#  '20th Century Fox',
#  '20th Century Fox Animation',
#  '20th Century Fox Argentina',
#  '20th Century Fox Brazil',
#  '20th Century Fox Home Entertainment',
#  '20th Century Fox Korea',
#  '20th Century Fox Russia',
#  '20th Century Studios',
#  '21 Century Shengkai Film',
#  '21 Laps Entertainment',
#  '211 Productions',
#  '212 Productions',
#  '21juin Cinema',
#  '21kin.com',
#  '21st Century',
#  '21st Century 3D',
#  '21st Century DreamQuest Films',
#  '21st Century Film Production',
#  '22 & Green',
#  '22 & Indiana Pictures',
#  '22 Hours Films',
#  '221 Films',
#  '222 Productions',
#  '224 Entertainment',
#  '2262730 Ontario',
#  '22DOGS',
#  '22h22',
#  '22six Productions',
#  '23 Feet',
#  '23 Hues Entertainment',
#  '23/5 Filmproduktion',
#  '235 Films',
#  '23rd Street Films',
#  '23ten',
#  '24 25 Films',
#  '24 Frames Factory',
#  '24 Mai Production',
#  '24/7 Films',
#  '24:25 Films',
#  '24AM Studios',
#  '24MEDIA',
#  '24TL Productions',
#  '24fs Chitra',
#  '25 Film',
#  '25-One Productions',
#  '2500 entertainment',
#  '25th Frame',
#  '26 Company',
#  '26 Films',
#  '26 Keys Productions',
#  '260 Degrees Entertainment',
#  '26DB Productions',
#  '27 Films Production',
#  '27 Productions',
#  '27 Ten Productions',
#  '28 Productions',
#  '282 Studios',
#  '29 Libran Films',
#  '2929 Entertainment',
#  '2929 Productions',
#  '29P Films',
#  '29th February Film Company',
#  '2:1 Film',
#  '2:59 Films',
#  '2B Films',
#  '2CFilm',
#  '2D Celluloid',
#  '2D Entertainment',
#  '2DS Productions',
#  '2DUX²',
#  '2Feet Entertainment',
#  '2Könige Filmproduktion',
#  '2L Productions',
#  '2Mr Films',
#  '2Pilots Filmproduction',
#  '2Plan2',
#  '2S Films',
#  '2afilm',
#  '2am Films',
#  '2d3D Animations',
#  '2mCine',
#  '2nd Nature Films',
#  '2|35',
#  '3 Arts Entertainment',
#  '3 Bean Productions',
#  '3 Daughters Films',
#  '3 Dogs & a Pony',
#  '3 Doubles Producciones',
#  '3 Legged Dog Films',
#  '3 Marys Entertainment',
#  '3 Men in a Tub Productions',
#  '3 Ng Film',
#  '3 Ring Circus Films',
#  '3 Spears Pty. Ltd.',
#  '3 Wall Productions',
#  '3 in the Box',
#  '3 minutes West',
#  '3, 4 Women Productions',
#  '3-Dimension Films',
#  '3-H Films',
#  '30 Bones Cinema',
#  '30 Pictures',
#  '30 Something Productions',
#  '300 & Co.',
#  '305 Media Group',
#  '308 Enterprises',
#  '30WEST',
#  '31 Juin Films',
#  '310 Studios',
#  '315 Films',
#  '316 Productions',
#  '321 Films',
#  '3210 Films',
#  '33 Degrees',
#  '33 Pictures',
#  '3311 Productions',
#  '333 Experience',
#  '3332472 Nova Scotia',
#  '33andOut Productions',
#  '34 Filmes',
#  '341 House Productions',
#  '344 Productions',
#  '34th Street Films',
#  '360 Film Group',
#  '360 Pictures',
#  '369 Productions',
#  '377 Films',
#  '388 Studios',
#  '39 Steps',
#  '39Films',
#  '3:00 am Productions',
#  '3:1 Cinema',
#  '3:16 Productions',
#  '3:41am',
#  '3:59',
#  '3B Productions',
#  '3B Studios',
#  '3BlackDot',
#  '3Brane Entertainment',
#  '3C Films Group',
#  '3D Animagics Entertainment',
#  '3D Produzioni',
#  '3D Safari LC',
#  '3D Video System',
#  '3F',
#  '3Foot7',
#  '3GI Industries',
#  '3L Filmproduktion GmbH',
#  '3L Filmverleih',
#  '3L Productions',
#  '3Mark Entertainment',
#  '3Pas Studios',
#  '3QU Media',
#  '3Roundburst Productions',
#  '3YFILM',
#  '3am Cinematic Escapes',
#  '3am Entertainment',
#  '3bros Film',
#  '3dar',
#  '3dot Productions',
#  '3leven',
#  '3rd Coast Digital Films',
#  '3rd Films',
#  '3rd Identity Films',
#  '3rd Monkey Productions',
#  '3rd Partner Productions',
#  '3rd Shift Media',
#  '3rd Vision Films',
#  '3sat',
#  '3x7 production',
#  '3xMedia',
#  '4 1/2',
#  '4 Cats Pictures',
#  '4 Film',
#  '4 Proof Film',
#  '4 Reel Productions',
#  '4 Rooms',
#  '4 à 4 Productions',
#  '40 Acres & A Mule Filmworks',
#  '40 Acres and a Mule Filmworks',
#  '40 Below Films',
#  '400 Filmes',
#  '403 Productions',
#  '408 Films',
#  '415 Project',
#  '419 Productions',
#  '42',
#  '42 Films',
#  '42 Km Film',
#  '42 Productions',
#  '424 Post',
#  '4248 Productions',
#  '42ND street films',
#  '42film',
#  '42nd Pictures',
#  '42nd Street Productions',
#  '430 Productions',
#  '435 Films',
#  '44 Toons',
#  '441 Films',
#  '454 Productions',
#  '47ème Parallèle',
#  '48 Days Film Project',
#  '480 Films',
#  '49 Film',
#  '49th Parallel Films',
#  '4:02 PRODUCTIONS',
#  '4AM Film Studios',
#  '4Cows',
#  '4DH Films',
#  '4Digital Media',
#  '4G Vision',
#  '4Go West Productions',
#  '4Horsemen Films',
#  '4Kids Entertainment',
#  '4L',
#  '4LAP Films',
#  '4M',
#  '4P Pictures',
#  '4PIX',
#  '4k Films',
#  '4th & Alameda Picture Company',
#  '4th Wall Entertainment',
#  '4½',
#  '5 Child Productions',
#  '5 London Films',
#  '5 Name Films',
#  '5 Nen D Gumi',
#  '5 Star Productions',
#  '5 States',
#  '5-Second Films',
#  '50/50 Films',
#  '50/50 Films DC',
#  '5000 Broadway Productions',
#  '501 Pictures',
#  '501st Joint Fighter Wing',
#  '51 Entertainment',
#  '51 Minds Entertainment',
#  '51/50 Films',
#  '5150 Action',
#  '5150 Productions',
#  '51MM Films',
#  '51k',
#  '531 Productions',
#  '5459 Films',
#  '5656 Films',
#  '58 Films Llc',
#  '58.5 Production',
#  '5858 Films',
#  '58Filme',
#  '59 Films',
#  '5AM Producciones',
#  '5B Productions',
#  '5J Media',
#  '5pb',
#  '5th Element',
#  '5th Tuesday Films',
#  '5à 7 Films',
#  '5ème Planète',
#  '5’7 Films',
#  '6 Foot Films',
#  '600 West Productions',
#  '606 Films',
#  '6140 Productions',
#  '624 Productions',
#  '625 Productions',
#  '64A Films',
#  '65 Wilding Films',
#  '666 Production',
#  '6th & Idaho',
#  '7 Arts',
#  '7 Bucks Entertainment',
#  '7 Continents Films',
#  '7 Eccles Street',
#  '7 Ponies Productions',
#  '7 Región de Murcia',
#  '7 Spencer Productions',
#  '7 Toes Productions',
#  '70 MM Entertainment',
#  '700 Pictures',
#  '700G Films',
#  '70mm Entertainments',
#  '71 Degrees North',
#  '7107 Entertainment',
#  '72 Productions',
#  '721 Productions',
#  '72nd Street Productions',
#  '73140323 Producciones Cinematográficas',
#  '74 Entertainment',
#  '74 Films',
#  '747 Hallway Productions',
#  '75 Films',
#  '75 Year Plan Productions',
#  '76 Pictures',
#  '77 Films',
#  '775 Media Corp',
#  '777 Films Corporation',
#  '7930 Entertainment',
#  '79th & Broadway Entertainment',
#  '7Cs Entertainment',
#  '7DM Studios',
#  '7Films7',
#  '7G Films',
#  '7Glab Entertainment',
#  '7Heaven Productions',
#  '7cuerdasfilms',
#  '7e Apache Film',
#  '7e Heart Productions',
#  '7th Sense Films',
#  '7th Street Productions',
#  '7ype',
#  '8 Ball Stunts of Hollywood',
#  '8 Street Films',
#  '8-Track Productions',
#  '80 Days Productions',
#  '800 Pound Gorilla Pictures',
#  '802 AD Productions',
#  '802 Films',
#  '808 Filmes Fora da Lata',
#  '81 Produce',
#  '8168 Productions Winter Star Productions',
#  '8180 Films',
#  '81st Street Films',
#  '821 Entertainment Group',
#  '8383 Productions',
#  '852 Films',
#  '856 Films',
#  '8750 Films',
#  '87Eleven',
#  '87North Productions',
#  '88 Art & Cinema',
#  '88 Miles',
#  '88 Rising',
#  '88 to 1 Productions',
#  '88mm Productions',
#  '8:38 Productions',
#  '8Heads Productions',
#  '8bit',
#  '8horses',
#  '8th In Line',
#  '8th Sense Productions',
#  '8th Wonder Entertainment',
#  '9 1/2 Comunicaciones',
#  '9 Light Entertainment',
#  '9.99 Films',
#  '9/02 Entertainment',
#  '90 Minutes Film Studio',
#  '90 Productions',
#  '900 Films',
#  '9000 Wolves',
#  '923 Films',
#  '95 Animation Studio',
#  '96 Film Co., Ltd.',
#  '98 MPH Productions',
#  '99 Ways Entertainment',
#  '9ers Entertainment',
#  'A & D Studios',
#  'A & P GROUPS',
#  'A + D Films',
#  'A Atalanta',
#  'A B Corp',
#  'A Bad Way Ltd',
#  'A Band Apart',
#  'A Baroque House',
#  'A Bellyful of Dreams Entertainment',
#  'A Bigger Boat',
#  'A Bird and a Bear Entertainment',
#  'A Bollywood Yorker Films',
#  'A Buck Short Productions',
#  'A Certain Film Productions',
#  'A Christmas Hero Productions',
#  'A Company Filmproduktionsgesellschaft',
#  'A Company Production',
#  'A Contracorriente Films',
#  'A Contraluz Films',
#  'A Corpse With No Name Productions',
#  'A Cut to the Chase Productions',
#  'A Day in the Life Films',
#  'A Dime And A Dream Pictures',
#  'A Exceção e a Regra',
#  'A Fabrica',
#  'A Farewell to Kings Entertainment Company',
#  'A Film Company',
#  'A Film Estonia',
#  'A Film Location Company',
#  'A Film Monkey Production',
#  'A Fire in the Lake',
#  'A Flying Woman Productions',
#  'A Free World Productions',
#  'A Gardeners Production',
#  'A Grand Elephant',
#  'A Grinning Tree Production',
#  'A Happy Place',
#  'A Hot Dog',
#  'A KIMCHI MOVIE PRODUCTION',
#  'A Loopy Production LLC',
#  'A Lucky Old Sun Production',
#  'A Mates Entertainment Release',
#  'A May Sky Picture Entertainment',
#  'A Monster Calls AIE',
#  'A Monster in the Attic',
#  'A Moving Image Productions',
#  'A Mutual Respect',
#  'A Named Viking',
#  'A No More Darkness Production',
#  'A Palm Springs Joint',
#  'A Perfect Circle Entertainment',
#  'A Pict Films',
#  'A Plus Entertainment',
#  'A Plus Image',
#  'A Plus Image 2',
#  'A Plus Image 3',
#  'A Plus Image 4',
#  'A Plus Image 5',
#  'A Plus Image 6',
#  'A Plus Image 7',
#  'A Prime Group',
#  'A Private View',
#  'A Product of Malitsky',
#  'A Really Good Home Pictures',
#  'A Really Happy Film',
#  'A Red Arrow Studios Company',
#  'A Russian Bear Production LLC',
#  'A Shadow in the Dark Productions',
#  'A Single Man Productions',
#  'A Skye Vision',
#  'A Small Production Company',
#  'A Space Between',
#  'A Spencer Media',
#  'A Stream In The Desert',
#  'A Street Productions',
#  'A Studios',
#  'A Team Productions',
#  'A Thousand Ships',
#  'A Tiny But Big Pictures',
#  'A Toda Madre Entertainment',
#  'A United Bros. Cinema Distribution',
#  'A Very Good Production',
#  'A Walk in the Parks Productions',
#  'A Walled Garden',
#  'A Wife Alone',
#  'A and A Produktion',
#  'A for Apple Production',
#  'A&A Advisors',
#  'A&A Pictures',
#  'A&D Pictures',
#  'A&E Television Networks',
#  'A&F Productions',
#  'A&G',
#  'A&M Sound Pictures',
#  'A&P Films',
#  'A+ Images 7',
#  'A+E Studios',
#  'A-1 Kino Video',
#  'A-1 Pictures',
#  'A-1 Productions',
#  'A-Film Distribution',
#  'A-Line Pictures',
#  'A-List Entertainment',
#  'A-Mark Entertainment',
#  'A-Motion',
#  'A-OK Media House',
#  'A-Po Films',
#  'A-Team',
#  'A-Yao Film',
#  'A-toys',
#  'A. Film Production',
#  'A.A.C. Productions',
#  'A.B. Seahorse Films',
#  'A.B.C. Pictures Pvt. Ltd.',
#  'A.E. Media Corporation',
#  'A.F. Cinema e Vídeo',
#  'A.G. Entertainment',
#  'A.G. Films',
#  'A.Gi.Di.',
#  'A.J. Digital Entertainment',
#  'A.J. Productions',
#  'A.J.O.Z. Films',
#  'A.Pictures Film & TV Production',
#  'A.R.Murugadoss Productions',
#  'A.S. Films',
#  'A.S. Prod',
#  'A.S. Productions',
#  'A.S.A.P',
#  'A.T.P.I.P. Producciones',
#  'A.V.A. Prodcutions',
#  'A1 Studios',
#  'A113',
#  'A2 Entertainment Group',
#  'A2 Film Corporation',
#  'A24',
#  'A2B Media',
#  'A2L Production Films',
#  'A2O',
#  'A71 Productions',
#  'A7SLE Films',
#  'AAA Entertainment',
#  'AAA Motion Pictures',
#  'AAA Pro Film',
#  'AAMPI Inc.',
#  'AAND',
#  'AAP Studios',
#  'AB Corp Ltd.',
#  'AB3',
#  'ABC Animation',
#  'ABC Family',
#  'ABC Signature',
#  'ABC3',
#  'ABHO Film',
#  'ABKCO Films',
#  'ABO Entertainment',
#  'ABP Entertainment',
#  'ABR Productions',
#  'ABS Film Company',
#  'ABS Production',
#  'AC Film',
#  'AC Transformative Media',
#  'ACE',
#  'ACE Entertainment',
#  'ACE Pictures Entertainment',
#  'ACE Productions',
#  'ACEDEUCE',
#  'ACH',
#  'ACI Films Inc.',
#  'ACK Animation Studios',
#  'ACM Films',
#  'ACME Film',
#  'ACPAV',
#  'ACSD ArtinMovimento',
#  'ACT Animation Films',
#  'ACT-PIC',
#  'AD406',
#  'ADCB Films',
#  'ADF Acquisitions',
#  'ADF Productions',
#  'ADF Studios',
#  'ADHM Films',
#  'ADIUVO Productions',
#  'ADL Film Fest Fund',
#  'ADR Productions',
#  'ADTDF Utah Productions',
#  'ADV Films',
#  'AE Electra Productions',
#  'AE Two Film Productions',
#  'AEC Studios',
#  'AEON ENTERTAINMENT CO.LTD',
#  'AFA Film Productions',
#  'AFAC',
#  'AFC',
#  'AFH Films',
#  'AFPI',
#  'AFS Film',
#  'AFTRS',
#  'AG Group',
#  'AG Studio',
#  'AG Studios',
#  'AGBO',
#  'AGC Studios',
#  'AGGK Films',
#  'AGM Factory',
#  'AGS Entertainment',
#  'AGS Productions',
#  'AGUNG INC.',
#  'AGe Industriesllc',
#  'AHTF Films',
#  'AI Film Entertainment',
#  'AI-Film',
#  'AIASPLUS',
#  'AIC Studios',
#  'AIMZ Media',
#  'AISI film',
#  'AITD Productions',
#  'AJ Entertainement Ltd.',
#  'AJB Productions',
#  'AJL Pictures',
#  'AK Entertainments',
#  'AK Worldwide',
#  'AK47 Presents',
#  'AKA Pictures',
#  'AKELA Films',
#  'AKN Productions',
#  'AKOM Production Company',
#  'AKOOLFILM COMPANY INC.',
#  'AKS Media & Entertainment',
#  'ALEF Film & Media Group',
#  'ALP Productions',
#  'ALT Entertainment',
#  'ALV Entertainment Network',
#  'ALV Films',
#  'AM Associates',
#  'AM Creative',
#  'AM Films',
#  'AM Pictures',
#  'AMA Media',
#  'AMBI',
#  'AMBI Group',
#  'AMC Networks International Iberia',
#  'AMC Pictures',
#  'AMCO Entertainment Group',
#  'AMG Entertainment',
#  'AMG Media',
#  'AMIB Productions',
#  'AMJ Productions',
#  'AMKO Productions Inc.',
#  'AMP',
#  'AMP Creative',
#  'AMP Filmworks',
#  'AMP International',
#  'AMP Media',
#  'AMPCO Films',
#  'AMUSE',
#  'AMUSIC FREEATER',
#  'AMV Production',
#  'AMVHell.com',
#  'AMedia',
#  'AMediaVision Productions',
#  'ANA Media',
#  'ANC Entertainment',
#  'ANCINE/Ministério da Cultura, Fundo Setorial do Audiovisual',
#  'ANDMARQ Studio',
#  'ANG Film',
#  'ANGGAR ANANDA',
#  'ANGOA',
#  'ANIMA',
#  'ANIMAL DE LUZ FILMS',
#  'ANOC Productions',
#  'ANS Prodüksiyon',
#  'ANTEC',
#  'ANTORCHA FILMS',
#  'ANVL Entertainment',
#  'AOA Productions Pty. Ltd.',
#  'AOE Media',
#  'AOI Pro.',
#  'AOPL Entertainment',
#  'APC',
#  'API Films',
#  'APM - Ana Pinhão Moura Produções',
#  'APPP Company',
#  'APS Films',
#  'APS Films LLC',
#  'APT Entertainment',
#  'APT Films',
#  'APT. 1B Productions',
#  'AR Content',
#  'AR Films',
#  'AR-TL',
#  'ARC FILMS',
#  'ARD',
#  'ARD/Degeto Film',
#  'ARGO PICTURES',
#  'ARK-Film',
#  'ARM Entertainment',
#  'ARM/Cinema 25 Pictures Inc.',
#  'ARO Entertainment',
#  'ARP Sélection',
#  'ARRAY Filmworks',
#  'ARRAY Releasing',
#  'ARRI Film & TV Services',
#  'ARRI Media',
#  'ARRI Media Productions',
#  'ARRI Productions',
#  'ARS Digital Studio',
#  'ARS Film Production',
#  'ARS Films',
#  'ART & BOB',
#  'ARTE',
#  'ARTE Cofinova',
#  'ARTE France Cinéma',
#  'ARTE GEIE',
#  'ARTFO',
#  'ARTISK, INC.',
#  'ARY Films',
#  'AS Entertainment',
#  'ASA Film Production',
#  'ASA Production & Enterprises',
#  'ASA Productions and Enterprises',
#  'ASAF',
#  'ASAP Entertainment',
#  'ASC Audiovisual',
#  'ASCII Media Works',
#  'ASF Productions LLC',
#  'ASFK',
#  'ASG Films',
#  'ASHA',
#  'ASIG Productions',
#  'ASLFilms',
#  'ASM Media',
#  'ASP GmbH',
#  'ASP S.A.',
#  'ASP White',
#  'AST Studios',
#  'AStory',
#  'AT Studio',
#  'AT&T',
#  'AT-X',
#  'ATAEC Studios',
#  'ATD Entertainment',
#  'ATG Productions',
#  'ATHANOR',
#  'ATKO Films',
#  'ATM Grupa',
#  'ATM Motionwide',
#  'ATO',
#  'ATO Pictures',
#  'ATR Films',
#  'AUM Creative',
#  'AUX BUNKER CONSTANTLY PRODUCTIONS DCS',
#  'AUX Entertainment',
#  'AV Club, The',
#  'AV Films',
#  'AV Patchbay',
#  'AV Pictures',
#  'AV Studio Production, L.L.C.',
#  'AV1 Productions',
#  'AVA Productions',
#  'AVE Publishing GmbH & Co. KG',
#  'AVG Global Entertainment',
#  'AVM Productions',
#  'AVRO',
#  'AVRO Television',
#  'AVROTROS',
#  'AW Canada Films',
#  'AWS Films',
#  'AX-ON',
#  'AXI Pictures',
#  'AXIOM 8',
#  'AXN',
#  'AYAYAY! Films',
#  'AZ Celtic Films',
#  'AZ Film Studios',
#  'AZ Films',
#  'AZ Works',
#  'AZA Films',
#  'AZL Productions KG',
#  'AZPEITIA CINE SRL',
#  'Aadi Productions',
#  'Aama Saraswoti Geeta Devi Films',
#  'Aamir Khan Productions',
#  'Aamu Film Company',
#  'Aan Mega Media',
#  'Aardman Animations',
#  'Aardwolf Entertainment',
#  'Aargauer Kuratorium',
#  'Aascar Film Pvt. Ltd',
#  'Aascar Films',
#  'Aashirvad Cinemas',
#  'Aatpat Production',
#  'Abaam Movies',
#  'Ababil Indie Movies',
#  'Abaca Films',
#  'Aban Productions',
#  'Abandon Entertainment',
#  'Abandon Pictures',
#  'Abattoir Fermé',
#  'Abba Movies Co. Ltd.',
#  'Abbas Kiarostami Productions',
#  'Abbolita Productions',
#  'AbbottVision',
#  'Abbout Productions',
#  'Abby Normal Pictures',
#  'Abduction Films',
#  'Abdulelah Alqurashi Films',
#  'Abe Shuji',
#  'Aberration Films',
#  'Abhishek Films',
#  'Abhishek Pictures',
#  'Abi & Abi Pictures',
#  'Abington Ridge Films',
#  'Abis Studio',
#  'Abismo Films',
#  'Abissia Productions',
#  'Ablaze Image',
#  'Able & Baker',
#  'Able 2 Film Entertainment',
#  'Abnormal Pictures',
#  'Abominable Pictures',
#  'Aboretum Productions',
#  'Abot Hameiri',
#  'About Us Productions',
#  'Above All Things Inc',
#  'Above the Clouds',
#  'Above the Clouds Media Group',
#  'Above the Line Productions',
#  'Above-The-Line Film Productions',
#  'Abovo Films',
#  'Abra Producciones',
#  'Abracadabra Films',
#  'Abraham Productions',
#  'Abrakadabra Films',
#  'Abrakan Estudio',
#  'Abramorama',
#  'Abraxas Film',
#  'Abrupt Films',
#  'Absinthe Films',
#  'Absinthe Productions',
#  'Abso Lutely Productions',
#  'Absolut Film Management',
#  'Absolut Media',
#  'Absolute Entertainment',
#  'Absolutely No1 Films',
#  'Absurd Productions Pictures',
#  'Absurda',
#  'Abu Dhabi Film Commission',
#  'Abundant House Films',
#  'Abundant Productions',
#  'Abundantia Entertainment',
#  'Abus Film',
#  'Abyssmal Entertainment',
#  'Acaba Produzioni',
#  'Acacia Filmed Entertainment',
#  'Academy Film',
#  'Academy Films',
#  'Academy Leader',
#  'Académie Franco-Russe du Cinéma',
#  'Acajams Production',
#  'Acajou Films',
#  'Acamedia Pictures',
#  'Accattone Films',
#  'Accelerated Entertainment',
#  'Accelerated Matter',
#  'Accelerator Films',
#  'Accent Entertainment Corporation',
#  'Accent Films',
#  'Accento Films',
#  'Accentus Music',
#  'Access Entertainment',
#  'Access Films',
#  'Access Industries',
#  'Access Motion Picture Group',
#  'Access Motion Pictures',
#  'Access Pictures',
#  'Accidental Films',
#  'Accio Cine',
#  'Accolade Films',
#  'Accomplice Films',
#  'Accord Productions',
#  'Accorde Filmes',
#  'Accusatory Productions Inc.,',
#  'Ace Deuce Entertainment',
#  'Ace Entertainment',
#  'Ace Entertainment Films',
#  'Ace Film Company',
#  'Ace Films',
#  'Ace Studios',
#  'Ace and Company',
#  'Ace in the Hole Productions',
#  'Acemaker Movieworks',
#  'Acere Produções',
#  'Acevedo Smith Productions',
#  'Achab Film',
#  'Achalchitra',
#  'Achaman Films AIE',
#  'Acheron Films',
#  'Achicha Cinemas',
#  'Achilles Entertainments',
#  'Achim Pictures',
#  'Achoos International',
#  'Acht Frankfurt',
#  ...]

# %%
#create integer Ids for the companies
company_ints = range(len(unique_companies))
company_map = dict(zip(unique_companies, company_ints))
company_map
# Out:
# {'# Andrea Sperling Productions': 0,
#  '#Sinning Works': 1,
#  '#littlesecretfilm': 2,
#  '(주)라인필름': 3,
#  '(주)유비컬쳐': 4,
#  '(주)유비콘텐츠': 5,
#  '+Magenta': 6,
#  '.40 Caliber': 7,
#  '.Mille et Une. Films.': 8,
#  '.hack Conglomerate': 9,
#  '0': 10,
#  '01 Distribution': 11,
#  '011 Productions': 12,
#  '011Films': 13,
#  '02 Filmes': 14,
#  '0708 Films': 15,
#  '1 Bullet in the Gun Productions': 16,
#  '1 Media Productions': 17,
#  '1 Production Film': 18,
#  '1+1 Production': 19,
#  '1-2-3 Production': 20,
#  '1.85 Films': 21,
#  '10 East Pictures': 22,
#  '10 West Studios': 23,
#  '10.80 Films': 24,
#  '100': 25,
#  '100 Bares': 26,
#  '100 Feet Productions': 27,
#  '100 Year Films': 28,
#  '100 doo': 29,
#  '100% Halal': 30,
#  '1000 Volt': 31,
#  '101 Films': 32,
#  '101 Studios': 33,
#  '1019 Entertainment': 34,
#  '1019 Pictures': 35,
#  '102 Distribution': 36,
#  '1024 FILM': 37,
#  '1031 Films': 38,
#  '104 Films': 39,
#  '1066 Pictures': 40,
#  '108 Media': 41,
#  '1091': 42,
#  '1091 Media': 43,
#  '1091 Pictures': 44,
#  '10:15! Productions': 45,
#  '10X Productions': 46,
#  '10th Hole Productions': 47,
#  '10th Street Entertainment': 48,
#  '11 Marzo Film': 49,
#  '1121 Productions': 50,
#  '11:11 Entertainment': 51,
#  '11:11 Mediaworks': 52,
#  '12 A.M. Pictures': 53,
#  '120 Films': 54,
#  '120 Over 80': 55,
#  '1201 Pictures': 56,
#  '120E Films': 57,
#  '120dB Films': 58,
#  '1211 Woodlake Pictures presents': 59,
#  '1212 Entertainment': 60,
#  '1230 Manhattan': 61,
#  '1244': 62,
#  '127 Wall': 63,
#  '12th Street Productions': 64,
#  '13 All Stars LLC': 65,
#  '13 Conejos': 66,
#  '13 Entertainment': 67,
#  '13 Films': 68,
#  '13 Ghosts Productions Canada Inc.': 69,
#  '13 Moons Productions LLC': 70,
#  '13 Paces': 71,
#  '13 Productions': 72,
#  '13 TV': 73,
#  '130K Frames': 74,
#  '13th Studio, The': 75,
#  '14 Pies': 76,
#  '14 Reels Entertainment': 77,
#  '14-18 NOW': 78,
#  '1405 comunicaciones': 79,
#  '141 Entertainment': 80,
#  '1428 Films': 81,
#  '1492 Pictures': 82,
#  '14ème Art Production': 83,
#  '15 in the Dark': 84,
#  '1500 Entertainment': 85,
#  '1518 Films': 86,
#  '152 WEST Productions': 87,
#  '1618 Action Limited': 88,
#  '16:14 Entertainment': 89,
#  '17 Road': 90,
#  '17-28 Black Production': 91,
#  '1718 Studio': 92,
#  '18 Reels': 93,
#  '180 Degrees': 94,
#  '1812 Productions': 95,
#  '1821 Pictures': 96,
#  '185 Films': 97,
#  '185 Trax': 98,
#  '185º Equator': 99,
#  '19 Entertainment': 100,
#  '1922 Films': 101,
#  '1976 Productions': 102,
#  '1984 Pictures': 103,
#  '1984 Private Defense Contractors': 104,
#  '1991 Broadway Theatre Group': 105,
#  '19th & Wilson': 106,
#  '19th Floor Productions': 107,
#  '1A Productions': 108,
#  '1Tentertainment': 109,
#  '1inMM Productions': 110,
#  '1st Boll Kino Beteiligungs GmbH and Co. KG': 111,
#  '1stAveMachine': 112,
#  '2 A.M. Productions': 113,
#  '2 Bridges Productions': 114,
#  '2 Cities Productions': 115,
#  '2 Crackers and a Lamp Productions': 116,
#  '2 Die 4 Films': 117,
#  '2 Entertain': 118,
#  '2 Focus': 119,
#  '2 Friends Media': 120,
#  '2 Loop Films': 121,
#  '2 Man Production': 122,
#  '2 Minutes': 123,
#  '2 Red Rabbit Films': 124,
#  '2 Wolves Films': 125,
#  '2 Wonder Full To Be': 126,
#  '2-G Multi-Media': 127,
#  '2-Team Productions': 128,
#  '2.0 Entertainment': 129,
#  '2.4.7. Films': 130,
#  '20 Max Films': 131,
#  '20 Steps Productions': 132,
#  '20/20': 133,
#  '20/20 Visions Entertainment Group': 134,
#  '2000 Bilder': 135,
#  '2003 Productions': 136,
#  '2015 Project Love Live Movie': 137,
#  '2076 Kolektib': 138,
#  '2077883 Ontario': 139,
#  '20ten Media': 140,
#  '20th Century Animation': 141,
#  '20th Century Fox': 142,
#  '20th Century Fox Animation': 143,
#  '20th Century Fox Argentina': 144,
#  '20th Century Fox Brazil': 145,
#  '20th Century Fox Home Entertainment': 146,
#  '20th Century Fox Korea': 147,
#  '20th Century Fox Russia': 148,
#  '20th Century Studios': 149,
#  '21 Century Shengkai Film': 150,
#  '21 Laps Entertainment': 151,
#  '211 Productions': 152,
#  '212 Productions': 153,
#  '21juin Cinema': 154,
#  '21kin.com': 155,
#  '21st Century': 156,
#  '21st Century 3D': 157,
#  '21st Century DreamQuest Films': 158,
#  '21st Century Film Production': 159,
#  '22 & Green': 160,
#  '22 & Indiana Pictures': 161,
#  '22 Hours Films': 162,
#  '221 Films': 163,
#  '222 Productions': 164,
#  '224 Entertainment': 165,
#  '2262730 Ontario': 166,
#  '22DOGS': 167,
#  '22h22': 168,
#  '22six Productions': 169,
#  '23 Feet': 170,
#  '23 Hues Entertainment': 171,
#  '23/5 Filmproduktion': 172,
#  '235 Films': 173,
#  '23rd Street Films': 174,
#  '23ten': 175,
#  '24 25 Films': 176,
#  '24 Frames Factory': 177,
#  '24 Mai Production': 178,
#  '24/7 Films': 179,
#  '24:25 Films': 180,
#  '24AM Studios': 181,
#  '24MEDIA': 182,
#  '24TL Productions': 183,
#  '24fs Chitra': 184,
#  '25 Film': 185,
#  '25-One Productions': 186,
#  '2500 entertainment': 187,
#  '25th Frame': 188,
#  '26 Company': 189,
#  '26 Films': 190,
#  '26 Keys Productions': 191,
#  '260 Degrees Entertainment': 192,
#  '26DB Productions': 193,
#  '27 Films Production': 194,
#  '27 Productions': 195,
#  '27 Ten Productions': 196,
#  '28 Productions': 197,
#  '282 Studios': 198,
#  '29 Libran Films': 199,
#  '2929 Entertainment': 200,
#  '2929 Productions': 201,
#  '29P Films': 202,
#  '29th February Film Company': 203,
#  '2:1 Film': 204,
#  '2:59 Films': 205,
#  '2B Films': 206,
#  '2CFilm': 207,
#  '2D Celluloid': 208,
#  '2D Entertainment': 209,
#  '2DS Productions': 210,
#  '2DUX²': 211,
#  '2Feet Entertainment': 212,
#  '2Könige Filmproduktion': 213,
#  '2L Productions': 214,
#  '2Mr Films': 215,
#  '2Pilots Filmproduction': 216,
#  '2Plan2': 217,
#  '2S Films': 218,
#  '2afilm': 219,
#  '2am Films': 220,
#  '2d3D Animations': 221,
#  '2mCine': 222,
#  '2nd Nature Films': 223,
#  '2|35': 224,
#  '3 Arts Entertainment': 225,
#  '3 Bean Productions': 226,
#  '3 Daughters Films': 227,
#  '3 Dogs & a Pony': 228,
#  '3 Doubles Producciones': 229,
#  '3 Legged Dog Films': 230,
#  '3 Marys Entertainment': 231,
#  '3 Men in a Tub Productions': 232,
#  '3 Ng Film': 233,
#  '3 Ring Circus Films': 234,
#  '3 Spears Pty. Ltd.': 235,
#  '3 Wall Productions': 236,
#  '3 in the Box': 237,
#  '3 minutes West': 238,
#  '3, 4 Women Productions': 239,
#  '3-Dimension Films': 240,
#  '3-H Films': 241,
#  '30 Bones Cinema': 242,
#  '30 Pictures': 243,
#  '30 Something Productions': 244,
#  '300 & Co.': 245,
#  '305 Media Group': 246,
#  '308 Enterprises': 247,
#  '30WEST': 248,
#  '31 Juin Films': 249,
#  '310 Studios': 250,
#  '315 Films': 251,
#  '316 Productions': 252,
#  '321 Films': 253,
#  '3210 Films': 254,
#  '33 Degrees': 255,
#  '33 Pictures': 256,
#  '3311 Productions': 257,
#  '333 Experience': 258,
#  '3332472 Nova Scotia': 259,
#  '33andOut Productions': 260,
#  '34 Filmes': 261,
#  '341 House Productions': 262,
#  '344 Productions': 263,
#  '34th Street Films': 264,
#  '360 Film Group': 265,
#  '360 Pictures': 266,
#  '369 Productions': 267,
#  '377 Films': 268,
#  '388 Studios': 269,
#  '39 Steps': 270,
#  '39Films': 271,
#  '3:00 am Productions': 272,
#  '3:1 Cinema': 273,
#  '3:16 Productions': 274,
#  '3:41am': 275,
#  '3:59': 276,
#  '3B Productions': 277,
#  '3B Studios': 278,
#  '3BlackDot': 279,
#  '3Brane Entertainment': 280,
#  '3C Films Group': 281,
#  '3D Animagics Entertainment': 282,
#  '3D Produzioni': 283,
#  '3D Safari LC': 284,
#  '3D Video System': 285,
#  '3F': 286,
#  '3Foot7': 287,
#  '3GI Industries': 288,
#  '3L Filmproduktion GmbH': 289,
#  '3L Filmverleih': 290,
#  '3L Productions': 291,
#  '3Mark Entertainment': 292,
#  '3Pas Studios': 293,
#  '3QU Media': 294,
#  '3Roundburst Productions': 295,
#  '3YFILM': 296,
#  '3am Cinematic Escapes': 297,
#  '3am Entertainment': 298,
#  '3bros Film': 299,
#  '3dar': 300,
#  '3dot Productions': 301,
#  '3leven': 302,
#  '3rd Coast Digital Films': 303,
#  '3rd Films': 304,
#  '3rd Identity Films': 305,
#  '3rd Monkey Productions': 306,
#  '3rd Partner Productions': 307,
#  '3rd Shift Media': 308,
#  '3rd Vision Films': 309,
#  '3sat': 310,
#  '3x7 production': 311,
#  '3xMedia': 312,
#  '4 1/2': 313,
#  '4 Cats Pictures': 314,
#  '4 Film': 315,
#  '4 Proof Film': 316,
#  '4 Reel Productions': 317,
#  '4 Rooms': 318,
#  '4 à 4 Productions': 319,
#  '40 Acres & A Mule Filmworks': 320,
#  '40 Acres and a Mule Filmworks': 321,
#  '40 Below Films': 322,
#  '400 Filmes': 323,
#  '403 Productions': 324,
#  '408 Films': 325,
#  '415 Project': 326,
#  '419 Productions': 327,
#  '42': 328,
#  '42 Films': 329,
#  '42 Km Film': 330,
#  '42 Productions': 331,
#  '424 Post': 332,
#  '4248 Productions': 333,
#  '42ND street films': 334,
#  '42film': 335,
#  '42nd Pictures': 336,
#  '42nd Street Productions': 337,
#  '430 Productions': 338,
#  '435 Films': 339,
#  '44 Toons': 340,
#  '441 Films': 341,
#  '454 Productions': 342,
#  '47ème Parallèle': 343,
#  '48 Days Film Project': 344,
#  '480 Films': 345,
#  '49 Film': 346,
#  '49th Parallel Films': 347,
#  '4:02 PRODUCTIONS': 348,
#  '4AM Film Studios': 349,
#  '4Cows': 350,
#  '4DH Films': 351,
#  '4Digital Media': 352,
#  '4G Vision': 353,
#  '4Go West Productions': 354,
#  '4Horsemen Films': 355,
#  '4Kids Entertainment': 356,
#  '4L': 357,
#  '4LAP Films': 358,
#  '4M': 359,
#  '4P Pictures': 360,
#  '4PIX': 361,
#  '4k Films': 362,
#  '4th & Alameda Picture Company': 363,
#  '4th Wall Entertainment': 364,
#  '4½': 365,
#  '5 Child Productions': 366,
#  '5 London Films': 367,
#  '5 Name Films': 368,
#  '5 Nen D Gumi': 369,
#  '5 Star Productions': 370,
#  '5 States': 371,
#  '5-Second Films': 372,
#  '50/50 Films': 373,
#  '50/50 Films DC': 374,
#  '5000 Broadway Productions': 375,
#  '501 Pictures': 376,
#  '501st Joint Fighter Wing': 377,
#  '51 Entertainment': 378,
#  '51 Minds Entertainment': 379,
#  '51/50 Films': 380,
#  '5150 Action': 381,
#  '5150 Productions': 382,
#  '51MM Films': 383,
#  '51k': 384,
#  '531 Productions': 385,
#  '5459 Films': 386,
#  '5656 Films': 387,
#  '58 Films Llc': 388,
#  '58.5 Production': 389,
#  '5858 Films': 390,
#  '58Filme': 391,
#  '59 Films': 392,
#  '5AM Producciones': 393,
#  '5B Productions': 394,
#  '5J Media': 395,
#  '5pb': 396,
#  '5th Element': 397,
#  '5th Tuesday Films': 398,
#  '5à 7 Films': 399,
#  '5ème Planète': 400,
#  '5’7 Films': 401,
#  '6 Foot Films': 402,
#  '600 West Productions': 403,
#  '606 Films': 404,
#  '6140 Productions': 405,
#  '624 Productions': 406,
#  '625 Productions': 407,
#  '64A Films': 408,
#  '65 Wilding Films': 409,
#  '666 Production': 410,
#  '6th & Idaho': 411,
#  '7 Arts': 412,
#  '7 Bucks Entertainment': 413,
#  '7 Continents Films': 414,
#  '7 Eccles Street': 415,
#  '7 Ponies Productions': 416,
#  '7 Región de Murcia': 417,
#  '7 Spencer Productions': 418,
#  '7 Toes Productions': 419,
#  '70 MM Entertainment': 420,
#  '700 Pictures': 421,
#  '700G Films': 422,
#  '70mm Entertainments': 423,
#  '71 Degrees North': 424,
#  '7107 Entertainment': 425,
#  '72 Productions': 426,
#  '721 Productions': 427,
#  '72nd Street Productions': 428,
#  '73140323 Producciones Cinematográficas': 429,
#  '74 Entertainment': 430,
#  '74 Films': 431,
#  '747 Hallway Productions': 432,
#  '75 Films': 433,
#  '75 Year Plan Productions': 434,
#  '76 Pictures': 435,
#  '77 Films': 436,
#  '775 Media Corp': 437,
#  '777 Films Corporation': 438,
#  '7930 Entertainment': 439,
#  '79th & Broadway Entertainment': 440,
#  '7Cs Entertainment': 441,
#  '7DM Studios': 442,
#  '7Films7': 443,
#  '7G Films': 444,
#  '7Glab Entertainment': 445,
#  '7Heaven Productions': 446,
#  '7cuerdasfilms': 447,
#  '7e Apache Film': 448,
#  '7e Heart Productions': 449,
#  '7th Sense Films': 450,
#  '7th Street Productions': 451,
#  '7ype': 452,
#  '8 Ball Stunts of Hollywood': 453,
#  '8 Street Films': 454,
#  '8-Track Productions': 455,
#  '80 Days Productions': 456,
#  '800 Pound Gorilla Pictures': 457,
#  '802 AD Productions': 458,
#  '802 Films': 459,
#  '808 Filmes Fora da Lata': 460,
#  '81 Produce': 461,
#  '8168 Productions Winter Star Productions': 462,
#  '8180 Films': 463,
#  '81st Street Films': 464,
#  '821 Entertainment Group': 465,
#  '8383 Productions': 466,
#  '852 Films': 467,
#  '856 Films': 468,
#  '8750 Films': 469,
#  '87Eleven': 470,
#  '87North Productions': 471,
#  '88 Art & Cinema': 472,
#  '88 Miles': 473,
#  '88 Rising': 474,
#  '88 to 1 Productions': 475,
#  '88mm Productions': 476,
#  '8:38 Productions': 477,
#  '8Heads Productions': 478,
#  '8bit': 479,
#  '8horses': 480,
#  '8th In Line': 481,
#  '8th Sense Productions': 482,
#  '8th Wonder Entertainment': 483,
#  '9 1/2 Comunicaciones': 484,
#  '9 Light Entertainment': 485,
#  '9.99 Films': 486,
#  '9/02 Entertainment': 487,
#  '90 Minutes Film Studio': 488,
#  '90 Productions': 489,
#  '900 Films': 490,
#  '9000 Wolves': 491,
#  '923 Films': 492,
#  '95 Animation Studio': 493,
#  '96 Film Co., Ltd.': 494,
#  '98 MPH Productions': 495,
#  '99 Ways Entertainment': 496,
#  '9ers Entertainment': 497,
#  'A & D Studios': 498,
#  'A & P GROUPS': 499,
#  'A + D Films': 500,
#  'A Atalanta': 501,
#  'A B Corp': 502,
#  'A Bad Way Ltd': 503,
#  'A Band Apart': 504,
#  'A Baroque House': 505,
#  'A Bellyful of Dreams Entertainment': 506,
#  'A Bigger Boat': 507,
#  'A Bird and a Bear Entertainment': 508,
#  'A Bollywood Yorker Films': 509,
#  'A Buck Short Productions': 510,
#  'A Certain Film Productions': 511,
#  'A Christmas Hero Productions': 512,
#  'A Company Filmproduktionsgesellschaft': 513,
#  'A Company Production': 514,
#  'A Contracorriente Films': 515,
#  'A Contraluz Films': 516,
#  'A Corpse With No Name Productions': 517,
#  'A Cut to the Chase Productions': 518,
#  'A Day in the Life Films': 519,
#  'A Dime And A Dream Pictures': 520,
#  'A Exceção e a Regra': 521,
#  'A Fabrica': 522,
#  'A Farewell to Kings Entertainment Company': 523,
#  'A Film Company': 524,
#  'A Film Estonia': 525,
#  'A Film Location Company': 526,
#  'A Film Monkey Production': 527,
#  'A Fire in the Lake': 528,
#  'A Flying Woman Productions': 529,
#  'A Free World Productions': 530,
#  'A Gardeners Production': 531,
#  'A Grand Elephant': 532,
#  'A Grinning Tree Production': 533,
#  'A Happy Place': 534,
#  'A Hot Dog': 535,
#  'A KIMCHI MOVIE PRODUCTION': 536,
#  'A Loopy Production LLC': 537,
#  'A Lucky Old Sun Production': 538,
#  'A Mates Entertainment Release': 539,
#  'A May Sky Picture Entertainment': 540,
#  'A Monster Calls AIE': 541,
#  'A Monster in the Attic': 542,
#  'A Moving Image Productions': 543,
#  'A Mutual Respect': 544,
#  'A Named Viking': 545,
#  'A No More Darkness Production': 546,
#  'A Palm Springs Joint': 547,
#  'A Perfect Circle Entertainment': 548,
#  'A Pict Films': 549,
#  'A Plus Entertainment': 550,
#  'A Plus Image': 551,
#  'A Plus Image 2': 552,
#  'A Plus Image 3': 553,
#  'A Plus Image 4': 554,
#  'A Plus Image 5': 555,
#  'A Plus Image 6': 556,
#  'A Plus Image 7': 557,
#  'A Prime Group': 558,
#  'A Private View': 559,
#  'A Product of Malitsky': 560,
#  'A Really Good Home Pictures': 561,
#  'A Really Happy Film': 562,
#  'A Red Arrow Studios Company': 563,
#  'A Russian Bear Production LLC': 564,
#  'A Shadow in the Dark Productions': 565,
#  'A Single Man Productions': 566,
#  'A Skye Vision': 567,
#  'A Small Production Company': 568,
#  'A Space Between': 569,
#  'A Spencer Media': 570,
#  'A Stream In The Desert': 571,
#  'A Street Productions': 572,
#  'A Studios': 573,
#  'A Team Productions': 574,
#  'A Thousand Ships': 575,
#  'A Tiny But Big Pictures': 576,
#  'A Toda Madre Entertainment': 577,
#  'A United Bros. Cinema Distribution': 578,
#  'A Very Good Production': 579,
#  'A Walk in the Parks Productions': 580,
#  'A Walled Garden': 581,
#  'A Wife Alone': 582,
#  'A and A Produktion': 583,
#  'A for Apple Production': 584,
#  'A&A Advisors': 585,
#  'A&A Pictures': 586,
#  'A&D Pictures': 587,
#  'A&E Television Networks': 588,
#  'A&F Productions': 589,
#  'A&G': 590,
#  'A&M Sound Pictures': 591,
#  'A&P Films': 592,
#  'A+ Images 7': 593,
#  'A+E Studios': 594,
#  'A-1 Kino Video': 595,
#  'A-1 Pictures': 596,
#  'A-1 Productions': 597,
#  'A-Film Distribution': 598,
#  'A-Line Pictures': 599,
#  'A-List Entertainment': 600,
#  'A-Mark Entertainment': 601,
#  'A-Motion': 602,
#  'A-OK Media House': 603,
#  'A-Po Films': 604,
#  'A-Team': 605,
#  'A-Yao Film': 606,
#  'A-toys': 607,
#  'A. Film Production': 608,
#  'A.A.C. Productions': 609,
#  'A.B. Seahorse Films': 610,
#  'A.B.C. Pictures Pvt. Ltd.': 611,
#  'A.E. Media Corporation': 612,
#  'A.F. Cinema e Vídeo': 613,
#  'A.G. Entertainment': 614,
#  'A.G. Films': 615,
#  'A.Gi.Di.': 616,
#  'A.J. Digital Entertainment': 617,
#  'A.J. Productions': 618,
#  'A.J.O.Z. Films': 619,
#  'A.Pictures Film & TV Production': 620,
#  'A.R.Murugadoss Productions': 621,
#  'A.S. Films': 622,
#  'A.S. Prod': 623,
#  'A.S. Productions': 624,
#  'A.S.A.P': 625,
#  'A.T.P.I.P. Producciones': 626,
#  'A.V.A. Prodcutions': 627,
#  'A1 Studios': 628,
#  'A113': 629,
#  'A2 Entertainment Group': 630,
#  'A2 Film Corporation': 631,
#  'A24': 632,
#  'A2B Media': 633,
#  'A2L Production Films': 634,
#  'A2O': 635,
#  'A71 Productions': 636,
#  'A7SLE Films': 637,
#  'AAA Entertainment': 638,
#  'AAA Motion Pictures': 639,
#  'AAA Pro Film': 640,
#  'AAMPI Inc.': 641,
#  'AAND': 642,
#  'AAP Studios': 643,
#  'AB Corp Ltd.': 644,
#  'AB3': 645,
#  'ABC Animation': 646,
#  'ABC Family': 647,
#  'ABC Signature': 648,
#  'ABC3': 649,
#  'ABHO Film': 650,
#  'ABKCO Films': 651,
#  'ABO Entertainment': 652,
#  'ABP Entertainment': 653,
#  'ABR Productions': 654,
#  'ABS Film Company': 655,
#  'ABS Production': 656,
#  'AC Film': 657,
#  'AC Transformative Media': 658,
#  'ACE': 659,
#  'ACE Entertainment': 660,
#  'ACE Pictures Entertainment': 661,
#  'ACE Productions': 662,
#  'ACEDEUCE': 663,
#  'ACH': 664,
#  'ACI Films Inc.': 665,
#  'ACK Animation Studios': 666,
#  'ACM Films': 667,
#  'ACME Film': 668,
#  'ACPAV': 669,
#  'ACSD ArtinMovimento': 670,
#  'ACT Animation Films': 671,
#  'ACT-PIC': 672,
#  'AD406': 673,
#  'ADCB Films': 674,
#  'ADF Acquisitions': 675,
#  'ADF Productions': 676,
#  'ADF Studios': 677,
#  'ADHM Films': 678,
#  'ADIUVO Productions': 679,
#  'ADL Film Fest Fund': 680,
#  'ADR Productions': 681,
#  'ADTDF Utah Productions': 682,
#  'ADV Films': 683,
#  'AE Electra Productions': 684,
#  'AE Two Film Productions': 685,
#  'AEC Studios': 686,
#  'AEON ENTERTAINMENT CO.LTD': 687,
#  'AFA Film Productions': 688,
#  'AFAC': 689,
#  'AFC': 690,
#  'AFH Films': 691,
#  'AFPI': 692,
#  'AFS Film': 693,
#  'AFTRS': 694,
#  'AG Group': 695,
#  'AG Studio': 696,
#  'AG Studios': 697,
#  'AGBO': 698,
#  'AGC Studios': 699,
#  'AGGK Films': 700,
#  'AGM Factory': 701,
#  'AGS Entertainment': 702,
#  'AGS Productions': 703,
#  'AGUNG INC.': 704,
#  'AGe Industriesllc': 705,
#  'AHTF Films': 706,
#  'AI Film Entertainment': 707,
#  'AI-Film': 708,
#  'AIASPLUS': 709,
#  'AIC Studios': 710,
#  'AIMZ Media': 711,
#  'AISI film': 712,
#  'AITD Productions': 713,
#  'AJ Entertainement Ltd.': 714,
#  'AJB Productions': 715,
#  'AJL Pictures': 716,
#  'AK Entertainments': 717,
#  'AK Worldwide': 718,
#  'AK47 Presents': 719,
#  'AKA Pictures': 720,
#  'AKELA Films': 721,
#  'AKN Productions': 722,
#  'AKOM Production Company': 723,
#  'AKOOLFILM COMPANY INC.': 724,
#  'AKS Media & Entertainment': 725,
#  'ALEF Film & Media Group': 726,
#  'ALP Productions': 727,
#  'ALT Entertainment': 728,
#  'ALV Entertainment Network': 729,
#  'ALV Films': 730,
#  'AM Associates': 731,
#  'AM Creative': 732,
#  'AM Films': 733,
#  'AM Pictures': 734,
#  'AMA Media': 735,
#  'AMBI': 736,
#  'AMBI Group': 737,
#  'AMC Networks International Iberia': 738,
#  'AMC Pictures': 739,
#  'AMCO Entertainment Group': 740,
#  'AMG Entertainment': 741,
#  'AMG Media': 742,
#  'AMIB Productions': 743,
#  'AMJ Productions': 744,
#  'AMKO Productions Inc.': 745,
#  'AMP': 746,
#  'AMP Creative': 747,
#  'AMP Filmworks': 748,
#  'AMP International': 749,
#  'AMP Media': 750,
#  'AMPCO Films': 751,
#  'AMUSE': 752,
#  'AMUSIC FREEATER': 753,
#  'AMV Production': 754,
#  'AMVHell.com': 755,
#  'AMedia': 756,
#  'AMediaVision Productions': 757,
#  'ANA Media': 758,
#  'ANC Entertainment': 759,
#  'ANCINE/Ministério da Cultura, Fundo Setorial do Audiovisual': 760,
#  'ANDMARQ Studio': 761,
#  'ANG Film': 762,
#  'ANGGAR ANANDA': 763,
#  'ANGOA': 764,
#  'ANIMA': 765,
#  'ANIMAL DE LUZ FILMS': 766,
#  'ANOC Productions': 767,
#  'ANS Prodüksiyon': 768,
#  'ANTEC': 769,
#  'ANTORCHA FILMS': 770,
#  'ANVL Entertainment': 771,
#  'AOA Productions Pty. Ltd.': 772,
#  'AOE Media': 773,
#  'AOI Pro.': 774,
#  'AOPL Entertainment': 775,
#  'APC': 776,
#  'API Films': 777,
#  'APM - Ana Pinhão Moura Produções': 778,
#  'APPP Company': 779,
#  'APS Films': 780,
#  'APS Films LLC': 781,
#  'APT Entertainment': 782,
#  'APT Films': 783,
#  'APT. 1B Productions': 784,
#  'AR Content': 785,
#  'AR Films': 786,
#  'AR-TL': 787,
#  'ARC FILMS': 788,
#  'ARD': 789,
#  'ARD/Degeto Film': 790,
#  'ARGO PICTURES': 791,
#  'ARK-Film': 792,
#  'ARM Entertainment': 793,
#  'ARM/Cinema 25 Pictures Inc.': 794,
#  'ARO Entertainment': 795,
#  'ARP Sélection': 796,
#  'ARRAY Filmworks': 797,
#  'ARRAY Releasing': 798,
#  'ARRI Film & TV Services': 799,
#  'ARRI Media': 800,
#  'ARRI Media Productions': 801,
#  'ARRI Productions': 802,
#  'ARS Digital Studio': 803,
#  'ARS Film Production': 804,
#  'ARS Films': 805,
#  'ART & BOB': 806,
#  'ARTE': 807,
#  'ARTE Cofinova': 808,
#  'ARTE France Cinéma': 809,
#  'ARTE GEIE': 810,
#  'ARTFO': 811,
#  'ARTISK, INC.': 812,
#  'ARY Films': 813,
#  'AS Entertainment': 814,
#  'ASA Film Production': 815,
#  'ASA Production & Enterprises': 816,
#  'ASA Productions and Enterprises': 817,
#  'ASAF': 818,
#  'ASAP Entertainment': 819,
#  'ASC Audiovisual': 820,
#  'ASCII Media Works': 821,
#  'ASF Productions LLC': 822,
#  'ASFK': 823,
#  'ASG Films': 824,
#  'ASHA': 825,
#  'ASIG Productions': 826,
#  'ASLFilms': 827,
#  'ASM Media': 828,
#  'ASP GmbH': 829,
#  'ASP S.A.': 830,
#  'ASP White': 831,
#  'AST Studios': 832,
#  'AStory': 833,
#  'AT Studio': 834,
#  'AT&T': 835,
#  'AT-X': 836,
#  'ATAEC Studios': 837,
#  'ATD Entertainment': 838,
#  'ATG Productions': 839,
#  'ATHANOR': 840,
#  'ATKO Films': 841,
#  'ATM Grupa': 842,
#  'ATM Motionwide': 843,
#  'ATO': 844,
#  'ATO Pictures': 845,
#  'ATR Films': 846,
#  'AUM Creative': 847,
#  'AUX BUNKER CONSTANTLY PRODUCTIONS DCS': 848,
#  'AUX Entertainment': 849,
#  'AV Club, The': 850,
#  'AV Films': 851,
#  'AV Patchbay': 852,
#  'AV Pictures': 853,
#  'AV Studio Production, L.L.C.': 854,
#  'AV1 Productions': 855,
#  'AVA Productions': 856,
#  'AVE Publishing GmbH & Co. KG': 857,
#  'AVG Global Entertainment': 858,
#  'AVM Productions': 859,
#  'AVRO': 860,
#  'AVRO Television': 861,
#  'AVROTROS': 862,
#  'AW Canada Films': 863,
#  'AWS Films': 864,
#  'AX-ON': 865,
#  'AXI Pictures': 866,
#  'AXIOM 8': 867,
#  'AXN': 868,
#  'AYAYAY! Films': 869,
#  'AZ Celtic Films': 870,
#  'AZ Film Studios': 871,
#  'AZ Films': 872,
#  'AZ Works': 873,
#  'AZA Films': 874,
#  'AZL Productions KG': 875,
#  'AZPEITIA CINE SRL': 876,
#  'Aadi Productions': 877,
#  'Aama Saraswoti Geeta Devi Films': 878,
#  'Aamir Khan Productions': 879,
#  'Aamu Film Company': 880,
#  'Aan Mega Media': 881,
#  'Aardman Animations': 882,
#  'Aardwolf Entertainment': 883,
#  'Aargauer Kuratorium': 884,
#  'Aascar Film Pvt. Ltd': 885,
#  'Aascar Films': 886,
#  'Aashirvad Cinemas': 887,
#  'Aatpat Production': 888,
#  'Abaam Movies': 889,
#  'Ababil Indie Movies': 890,
#  'Abaca Films': 891,
#  'Aban Productions': 892,
#  'Abandon Entertainment': 893,
#  'Abandon Pictures': 894,
#  'Abattoir Fermé': 895,
#  'Abba Movies Co. Ltd.': 896,
#  'Abbas Kiarostami Productions': 897,
#  'Abbolita Productions': 898,
#  'AbbottVision': 899,
#  'Abbout Productions': 900,
#  'Abby Normal Pictures': 901,
#  'Abduction Films': 902,
#  'Abdulelah Alqurashi Films': 903,
#  'Abe Shuji': 904,
#  'Aberration Films': 905,
#  'Abhishek Films': 906,
#  'Abhishek Pictures': 907,
#  'Abi & Abi Pictures': 908,
#  'Abington Ridge Films': 909,
#  'Abis Studio': 910,
#  'Abismo Films': 911,
#  'Abissia Productions': 912,
#  'Ablaze Image': 913,
#  'Able & Baker': 914,
#  'Able 2 Film Entertainment': 915,
#  'Abnormal Pictures': 916,
#  'Abominable Pictures': 917,
#  'Aboretum Productions': 918,
#  'Abot Hameiri': 919,
#  'About Us Productions': 920,
#  'Above All Things Inc': 921,
#  'Above the Clouds': 922,
#  'Above the Clouds Media Group': 923,
#  'Above the Line Productions': 924,
#  'Above-The-Line Film Productions': 925,
#  'Abovo Films': 926,
#  'Abra Producciones': 927,
#  'Abracadabra Films': 928,
#  'Abraham Productions': 929,
#  'Abrakadabra Films': 930,
#  'Abrakan Estudio': 931,
#  'Abramorama': 932,
#  'Abraxas Film': 933,
#  'Abrupt Films': 934,
#  'Absinthe Films': 935,
#  'Absinthe Productions': 936,
#  'Abso Lutely Productions': 937,
#  'Absolut Film Management': 938,
#  'Absolut Media': 939,
#  'Absolute Entertainment': 940,
#  'Absolutely No1 Films': 941,
#  'Absurd Productions Pictures': 942,
#  'Absurda': 943,
#  'Abu Dhabi Film Commission': 944,
#  'Abundant House Films': 945,
#  'Abundant Productions': 946,
#  'Abundantia Entertainment': 947,
#  'Abus Film': 948,
#  'Abyssmal Entertainment': 949,
#  'Acaba Produzioni': 950,
#  'Acacia Filmed Entertainment': 951,
#  'Academy Film': 952,
#  'Academy Films': 953,
#  'Academy Leader': 954,
#  'Académie Franco-Russe du Cinéma': 955,
#  'Acajams Production': 956,
#  'Acajou Films': 957,
#  'Acamedia Pictures': 958,
#  'Accattone Films': 959,
#  'Accelerated Entertainment': 960,
#  'Accelerated Matter': 961,
#  'Accelerator Films': 962,
#  'Accent Entertainment Corporation': 963,
#  'Accent Films': 964,
#  'Accento Films': 965,
#  'Accentus Music': 966,
#  'Access Entertainment': 967,
#  'Access Films': 968,
#  'Access Industries': 969,
#  'Access Motion Picture Group': 970,
#  'Access Motion Pictures': 971,
#  'Access Pictures': 972,
#  'Accidental Films': 973,
#  'Accio Cine': 974,
#  'Accolade Films': 975,
#  'Accomplice Films': 976,
#  'Accord Productions': 977,
#  'Accorde Filmes': 978,
#  'Accusatory Productions Inc.,': 979,
#  'Ace Deuce Entertainment': 980,
#  'Ace Entertainment': 981,
#  'Ace Entertainment Films': 982,
#  'Ace Film Company': 983,
#  'Ace Films': 984,
#  'Ace Studios': 985,
#  'Ace and Company': 986,
#  'Ace in the Hole Productions': 987,
#  'Acemaker Movieworks': 988,
#  'Acere Produções': 989,
#  'Acevedo Smith Productions': 990,
#  'Achab Film': 991,
#  'Achalchitra': 992,
#  'Achaman Films AIE': 993,
#  'Acheron Films': 994,
#  'Achicha Cinemas': 995,
#  'Achilles Entertainments': 996,
#  'Achim Pictures': 997,
#  'Achoos International': 998,
#  'Acht Frankfurt': 999,
#  ...}

# %%
#extract the necessary columns
title_companies = companies_exploded[['imdb_id', 'production_companies_list']]
title_companies
# Out:
#          imdb_id    production_companies_list
# 0      tt0113026  Sullivan Street Productions
# 0      tt0113026  Michael Ritchie Productions
# 0      tt0113026          Radmin Company, The
# 0      tt0113026               United Artists
# 1      tt0113092              Dimension Films
# ...          ...                          ...
# 61328  tt9898844              Moonphase Media
# 61328  tt9898844          Bright Shiny Things
# 61329  tt9900940                 Lucky Movies
# 61330  tt9907782                  Piste Rouge
# 61330  tt9907782             LD Entertainment
#
# [115070 rows x 2 columns]

# %%
#make new integer production_companies ID
title_companies['company_id'] = title_companies['production_companies_list'].map(company_map)
title_companies
# Out:
# /var/folders/tc/tt7jrftn7g510vxnf1thdhl80000gn/T/ipykernel_11905/2072484741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   title_companies['company_id'] = title_companies['production_companies_list'].map(company_map)
#          imdb_id    production_companies_list  company_id
# 0      tt0113026  Sullivan Street Productions     28664.0
# 0      tt0113026  Michael Ritchie Productions     19449.0
# 0      tt0113026          Radmin Company, The     24326.0
# 0      tt0113026               United Artists     31291.0
# 1      tt0113092              Dimension Films      8362.0
# ...          ...                          ...         ...
# 61328  tt9898844              Moonphase Media     20008.0
# 61328  tt9898844          Bright Shiny Things      4695.0
# 61329  tt9900940                 Lucky Movies     17850.0
# 61330  tt9907782                  Piste Rouge     23106.0
# 61330  tt9907782             LD Entertainment     16454.0
#
# [115070 rows x 3 columns]

# %%
company_lookup = pd.DataFrame({'company_id':company_map.values(), 'company_name':company_map.keys()})
company_lookup
# Out:
#        company_id                   company_name
# 0               0  # Andrea Sperling Productions
# 1               1                 #Sinning Works
# 2               2              #littlesecretfilm
# 3               3                        (주)라인필름
# 4               4                        (주)유비컬쳐
# ...           ...                            ...
# 33861       33861                        타임스토리그룹
# 33862       33862                          파파스필름
# 33863       33863                         플랫폼픽쳐스
# 33864       33864                           한맥문화
# 33865       33865                      환타지엔터테인먼트
#
# [33866 rows x 2 columns]

# %% [markdown]
# ## Saving SQL Database

# %%
##loading sql credentials
with open('/Users/chas/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
# Create connection string using credentials following this format
## Change username and password to match your personal MySQL Server settings
connection_str = f"mysql+pymysql://{login['username']}:{login['password']}@localhost/movies"
engine = create_engine(connection_str)

# %%
# Create Movies database, if it does not already exist
if database_exists(connection_str) == False: create_database(connection_str)
else: print('The database already exists.')

# %%
#create a schemda function (there will be a lot to do)
def get_schema(table,debug=False):
    ## save pandas dtypes in list, make empty dict
    dtypes = table.dtypes
    schema = {}
    
    # for each column
    for col in dtypes.index:
        ## print info if in debug mode
        if debug:
            print(f"{col} = {dtypes.loc[col]}")

        ## if its a string column (object)
        if dtypes.loc[col]=='object':
            
            ## Fill null values and make sure whole column is str
            data = table[col].fillna('').astype(str)
            
            ## get len first
            len_str = data.map(len).max()
            
            ## if the string is shorter than 21845 use String
            # (forget how i knew it was max size)
            if len_str < 21845:
                schema[col] = String( len_str + 1)
                
            ## If longer use Text
            else:
                schema[col] = Text(len_str+1)
        
        # if float make Float
        elif dtypes.loc[col] == 'float':
            schema[col] = Float()

        ## if int make Integer
        elif dtypes.loc[col] == 'int':
            schema[col] = Integer()#Float()#
            
        ## if bool make Boolean
        elif dtypes.loc[col] == 'bool':
            schema[col] = Boolean()
            
    return schema

# %% [markdown]
# ### df_title_basics

# %%
#display datatypes
df_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84508 entries, 0 to 84507
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          84508 non-null  object
#  1   titleType       84508 non-null  object
#  2   primaryTitle    84508 non-null  object
#  3   originalTitle   84508 non-null  object
#  4   isAdult         84508 non-null  int64
#  5   startYear       84508 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  84508 non-null  int64
#  8   genres          84508 non-null  object
#  9   genres_split    84508 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 6.4+ MB

# %%
#drop the unnecessary columns
df_title_basics = df_title_basics.drop(columns = ['titleType', 'originalTitle',
                                                  'isAdult', 'endYear', 'genres', 'genres_split'])
df_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84508 entries, 0 to 84507
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          84508 non-null  object
#  1   primaryTitle    84508 non-null  object
#  2   startYear       84508 non-null  int64
#  3   runtimeMinutes  84508 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 2.6+ MB

# %%
#calculate max string lengths
from sqlalchemy.types import *
#get schema
schema = get_schema(df_title_basics)

# %%
#save the sql with dtype and index=False
df_title_basics.to_sql('title_basics', engine, dtype=schema,
                      if_exists = 'replace', index=False)
# Out:
# 84508

# %%
#update the table and column with sqlalchemy
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %% [markdown]
# ### df_title_ratings

# %%
df_title_ratings = pd.read_csv('Data/title_ratings.csv.gz')

# %%
df_title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483420 entries, 0 to 483419
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         483420 non-null  object
#  1   averageRating  483420 non-null  float64
#  2   numVotes       483420 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.1+ MB

# %%
#get the schema
schema = get_schema(df_title_ratings)
#save to sql with dtype and index=False
df_title_ratings.to_sql('title_ratings', engine, dtype=schema,
                      if_exists = 'replace', index=False)
# Out:
# 483420

# %%
# Use the sqlalchemy engine to update the table and set tconst as the primary key
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`);')

# %% [markdown]
# ### title_genres

# %%
title_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157899 entries, 0 to 84507
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   tconst    157899 non-null  object
#  1   genre_id  157899 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.6+ MB

# %%
#obtain schemas
schema = get_schema(title_genres)

#save to sql with dtype and index=false
title_genres.to_sql('title_genres', engine, dtype=schema, 
                   if_exists = 'replace', index=False)
# Out:
# 157899

# %% [markdown]
# ### genres

# %%
genre_lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   genre_name  26 non-null     object
#  1   genre_id    26 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 544.0+ bytes

# %%
## Calculate max string lengths for object columns
key_len = genre_lookup['genre_name'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "genre_name": String(key_len+1), 
    'genre_id': Integer()}

# %%
#save to sql with dtype and index=false
genre_lookup.to_sql('genres', engine, dtype=df_schema,
                   if_exists = 'replace', index=False)
# Out:
# 26

# %%
# Use the sqlalchemy engine to update the table and set genre_id as the primary key
engine.execute('ALTER TABLE genres ADD PRIMARY KEY (`genre_id`);')

# %% [markdown]
# ### tmdb

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61331 entries, 0 to 61330
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   imdb_id                    61331 non-null  object
#  1   adult                      61331 non-null  float64
#  2   backdrop_path              37569 non-null  object
#  3   belongs_to_collection      3817 non-null   object
#  4   budget                     61331 non-null  float64
#  5   genres                     61331 non-null  object
#  6   homepage                   14864 non-null  object
#  7   id                         61331 non-null  float64
#  8   original_language          61331 non-null  object
#  9   original_title             61331 non-null  object
#  10  overview                   59927 non-null  object
#  11  popularity                 61331 non-null  float64
#  12  poster_path                55391 non-null  object
#  13  production_companies       61331 non-null  object
#  14  production_countries       61331 non-null  object
#  15  release_date               60265 non-null  object
#  16  revenue                    61331 non-null  float64
#  17  runtime                    60464 non-null  float64
#  18  spoken_languages           61331 non-null  object
#  19  status                     61331 non-null  object
#  20  tagline                    22559 non-null  object
#  21  title                      61331 non-null  object
#  22  video                      61331 non-null  float64
#  23  vote_average               61331 non-null  float64
#  24  vote_count                 61331 non-null  float64
#  25  certification              15030 non-null  object
#  26  collection                 3791 non-null   object
#  27  production_companies_list  60908 non-null  object
# dtypes: float64(9), object(19)
# memory usage: 13.1+ MB

# %%
tmdb_df = tmdb_df.drop(columns = ['adult', 'backdrop_path','belongs_to_collection',
                               'genres', 'homepage', 'id', 'original_language', 
                              'original_title', 'overview', 'popularity', 
                              'poster_path', 'production_companies',
                               'production_countries', 'release_date', 
                              'runtime', 'spoken_languages', 'status', 
                              'tagline', 'title', 'video', 'vote_average', 
                              'vote_count', 'production_companies_list'])
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61331 entries, 0 to 61330
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_id        61331 non-null  object
#  1   budget         61331 non-null  float64
#  2   revenue        61331 non-null  float64
#  3   certification  15030 non-null  object
#  4   collection     3791 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 2.3+ MB

# %%
# Calculate max string lengths for object columns ('tconst' and 'primaryTitle')
schema = get_schema(tmdb_df.fillna('MISSING'))

#drop any duplicates
tmdb_df = tmdb_df.drop_duplicates(subset=['imdb_id'])

# %%
tmdb_df.to_sql('tmdb_data', engine, dtype=schema, 
              if_exists='replace', index=False)
# Out:
# 60055

# %%
# Use the sqlalchemy engine to update the table and set imdb_id as the primary key
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %% [markdown]
# ### collection

# %%
collection_lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1846 entries, 0 to 1845
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   collection_id    1846 non-null   int64
#  1   collection_name  1846 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 29.0+ KB

# %%
#make table to sql
schema = get_schema(collection_lookup)
collection_lookup.to_sql('collections',engine, index=False,
                         dtype=schema,
                         if_exists='replace')
# Out:
# 1846

# %% [markdown]
# ### title collection

# %%
df_collections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3791 entries, 5 to 61316
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_id        3791 non-null   object
#  1   collection     3791 non-null   object
#  2   collection_id  3791 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 118.5+ KB

# %%
title_collection = df_collections.drop(columns='collection')
title_collection.dropna()
title_collection['collection_id'] = title_collection['collection_id'].astype(int)
title_collection
# Out:
#          imdb_id  collection_id
# 5      tt0119273            607
# 12     tt0120630            271
# 16     tt0120755            921
# 17     tt0120903           1781
# 19     tt0120917           1452
# ...          ...            ...
# 61274  tt9701942            464
# 61294  tt9777666           1609
# 61306  tt9819258              9
# 61309  tt9844522            440
# 61316  tt9857850              9
#
# [3791 rows x 2 columns]

# %%
#make to sql 
schema = get_schema(title_collection)
title_collection.to_sql('title_collection',engine, index=False,dtype=schema, if_exists='replace')
# Out:
# 3791

# %% [markdown]
# ### title company

# %%
title_companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115070 entries, 0 to 61330
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   imdb_id                    115070 non-null  object
#  1   production_companies_list  93300 non-null   object
#  2   company_id                 93300 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 3.5+ MB

# %%
title_companies = title_companies.drop(columns=['production_companies_list'])
title_companies = title_companies.dropna()
title_companies['company_id'] = title_companies['company_id'].astype(int)
title_companies
# Out:
#          imdb_id  company_id
# 0      tt0113026       28664
# 0      tt0113026       19449
# 0      tt0113026       24326
# 0      tt0113026       31291
# 1      tt0113092        8362
# ...          ...         ...
# 61328  tt9898844       20008
# 61328  tt9898844        4695
# 61329  tt9900940       17850
# 61330  tt9907782       23106
# 61330  tt9907782       16454
#
# [93300 rows x 2 columns]

# %%
#determine key len of the imdb_id
key_len = title_companies['imdb_id'].map(len).max()

## saving schema
data_schema = {'imdb_id':String(key_len+1)}
data_schema

#saving to sql
title_companies.to_sql('title_production_company',engine, 
                           index=False,dtype=data_schema, 
                           if_exists='replace')
# Out:
# 93300

# %% [markdown]
# ### company

# %%
#see the dtypes
company_lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33866 entries, 0 to 33865
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_id    33866 non-null  int64
#  1   company_name  33866 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 529.3+ KB

# %%
company_lookup.to_sql('production_companies',engine, index=False,dtype=data_schema, if_exists='replace')
# Out:
# 33866

# %% [markdown]
# ### Title Crew

# %%
#create sql table
schema = get_schema(table_title_crew)
table_title_crew.to_sql('title_crew',engine, index=False,
                        dtype=schema, if_exists='replace')
# Out:
# 3962601

# %% [markdown]
# ### Name Basics

# %%
#filter only needed columns
name_basics = df_name_basics[['nconst','primaryName','birthYear','deathYear']]
name_basics
# Out:
#              nconst     primaryName  birthYear  deathYear
# 3         nm0000004    John Belushi     1949.0     1982.0
# 4         nm0000005  Ingmar Bergman     1918.0     2007.0
# 7         nm0000008   Marlon Brando     1924.0     2004.0
# 8         nm0000009  Richard Burton     1925.0     1984.0
# 9         nm0000010    James Cagney     1899.0     1986.0
# ...             ...             ...        ...        ...
# 12210045  nm9993657     Jason Green        NaN        NaN
# 12210062  nm9993679       Art Jones        NaN        NaN
# 12210090  nm9993708      Eli Bevins        NaN        NaN
# 12210091  nm9993709       Lu Bevins        NaN        NaN
# 12210095  nm9993713   Sambit Mishra        NaN        NaN
#
# [642949 rows x 4 columns]

# %%
#create sql tables
schema = get_schema(name_basics)

name_basics.to_sql('name_basics',engine,dtype=schema,
                         if_exists='replace',index=False)

## setting title basics as the primary key
engine.execute('ALTER TABLE name_basics ADD PRIMARY KEY (`nconst`);')

# %% [markdown]
# ### professions

# %%
#create schema and make sql table
schema = get_schema(professions)
professions.to_sql('name_professions',engine, index=False,
                        dtype=schema, if_exists='replace')
# Out:
# 1567319

# %% [markdown]
# ### known for titles

# %%
schema = get_schema(known)
known.to_sql('name_knownForTitles',engine, index=False,
                        dtype=schema, if_exists='replace')
# Out:
# 1863152

# %% [markdown]
# ### character names

# %%
schema = get_schema(characters_exploded)

#save to sql
characters_exploded.to_sql('name_characters',engine, index=False,
                        dtype=schema, if_exists='replace')
# Out:
# 4217976

# %% [markdown]
# ### title principals

# %%
principals = principals.drop(columns='characters')

# %%
#create schema
schema = get_schema(principals)

#sae to sql
principals.to_sql('title_principals',engine, index=False,
                        dtype=schema, if_exists='replace')
# Out:
# 8465509

# %% [markdown]
# ### SQL Table and Rows

# %%
# Run show tables query
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#             Tables_in_movies
# 0                collections
# 1                     genres
# 2                name_basics
# 3            name_characters
# 4        name_knownForTitles
# 5           name_professions
# 6       production_companies
# 7               title_basics
# 8           title_collection
# 9                 title_crew
# 10              title_genres
# 11          title_principals
# 12  title_production_company
# 13             title_ratings
# 14                 tmdb_data

# %%
#collections
q = """
SELECT * 
FROM collections LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#    collection_id         collection_name
# 0              0       #TemanTapiMenikah
# 1              1  ... Cameras Collection
# 2              2        .hack Collection

# %%
#genres
q = """
SELECT * 
FROM genres LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2

# %%
#name_basics
q = """
SELECT * 
FROM name_basics LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       nconst     primaryName  birthYear  deathYear
# 0  nm0000004    John Belushi     1949.0     1982.0
# 1  nm0000005  Ingmar Bergman     1918.0     2007.0
# 2  nm0000008   Marlon Brando     1924.0     2004.0

# %%
#name_characters
q = """
SELECT * 
FROM name_characters LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       nconst  characters
# 0  nm1588970        Self
# 1  nm0443482  Blacksmith
# 2  nm0653042   Assistant

# %%
#name_knownForTitles
q = """
SELECT * 
FROM name_knownForTitles LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       nconst knownForTitles
# 0  nm0000004      tt0078723
# 1  nm0000004      tt0072562
# 2  nm0000004      tt0077975

# %%
#name_professions
q = """
SELECT * 
FROM name_professions LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       nconst  profession
# 0  nm0000004       actor
# 1  nm0000004  soundtrack
# 2  nm0000004      writer

# %%
#production_companies
q = """
SELECT * 
FROM production_companies LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#    company_id                   company_name
# 0           0  # Andrea Sperling Productions
# 1           1                 #Sinning Works
# 2           2              #littlesecretfilm

# %%
q = """
SELECT * 
FROM title_basics LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold       2001
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...       2020
# 2  tt0069049                         The Other Side of the Wind       2018
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122

# %%
#title_collection
q = """
SELECT * 
FROM title_collection LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#      imdb_id  collection_id
# 0  tt0119273            607
# 1  tt0120630            271
# 2  tt0120755            921

# %%
#title_crew
q = """
SELECT * 
FROM title_crew LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       tconst      role     nconst
# 0  tt0000001  director  nm0005690
# 1  tt0000002  director  nm0721526
# 2  tt0000005  director  nm0005690

# %%
q = """
SELECT * 
FROM title_genres LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18

# %%
#title_principals
q = """
SELECT * 
FROM title_principals LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       tconst  ordering     nconst         category                      job
# 0  tt0000001         1  nm1588970             self                     None
# 1  tt0000001         2  nm0005690         director                     None
# 2  tt0000001         3  nm0374658  cinematographer  director of photography

# %%
#title_production_company
q = """
SELECT * 
FROM title_production_company LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#      imdb_id  company_id
# 0  tt0113026       28664
# 1  tt0113026       19449
# 2  tt0113026       24326

# %%
q = """
SELECT * 
FROM title_ratings LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1934
# 1  tt0000002            5.8       262
# 2  tt0000005            6.2      2566

# %%
q = """
SELECT * 
FROM tmdb_data LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#      imdb_id      budget     revenue certification collection
# 0  tt0035423  48000000.0  76019000.0         PG-13       None
# 1  tt0062336         0.0         0.0          None       None
# 2  tt0069049  12000000.0         0.0             R       None
