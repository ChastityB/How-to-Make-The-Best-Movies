# %% [markdown]
# # IMDB Project

# %% [markdown]
# ## Part 1: Clean up the data

# %% [markdown]
# ### Link addresses to data
#
# title akas - https://datasets.imdbws.com/title.akas.tsv.gz
#
# title basics - https://datasets.imdbws.com/title.basics.tsv.gz
#
# title ratings - https://datasets.imdbws.com/title.ratings.tsv.gz
#
# title crew - https://datasets.imdbws.com/title.crew.tsv.gz
#
# title principals - https://datasets.imdbws.com/title.principals.tsv.gz
#
# name basics - https://datasets.imdbws.com/name.basics.tsv.gz

# %%
#load necessary libraries
import pandas as pd
import numpy as np

# %%
#give the data links respective variables for easy loading
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
title_crew_url = "https://datasets.imdbws.com/title.crew.tsv.gz"
title_principals_url = "https://datasets.imdbws.com/title.principals.tsv.gz"
name_basics_url = "https://datasets.imdbws.com/name.basics.tsv.gz"

# %%
#load each data
basics = pd.read_csv(basics_url, sep = '\t', low_memory = False)
akas = pd.read_csv(akas_url, sep = '\t', low_memory = False)
ratings = pd.read_csv(ratings_url, sep = '\t', low_memory = False)
crew = pd.read_csv(title_crew_url, sep='\t', low_memory = False)
principals = pd.read_csv(title_principals_url, sep='\t', low_memory = False)
name_basics = pd.read_csv(name_basics_url, sep='\t',low_memory = False)

# %%
#check datasets were loaded
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#check the datasets were loaded
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
#check the datasets were loaded
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1934
# 1  tt0000002            5.8       262
# 2  tt0000003            6.5      1756
# 3  tt0000004            5.6       177
# 4  tt0000005            6.2      2566

# %%
#check the datasets were loaded
crew.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
#check the datasets were loaded
principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                       \N
# 4  tt0000002         2  nm1335271         composer                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
#check the datasets were loaded
name_basics.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0053137,tt0045537,tt0072308
# 1  tt0117057,tt0038355,tt0037382,tt0071877
# 2  tt0056404,tt0054452,tt0049189,tt0057345
# 3  tt0078723,tt0072562,tt0077975,tt0080455
# 4  tt0060827,tt0083922,tt0050986,tt0050976

# %% [markdown]
# #### Title Basics

# %%
#replace \n with np.nan for basics data
basics = basics.replace({'\\N':np.nan})

#ensure it worked
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
#eliminate movies that are null for runtimeMinutes and genres
basics = basics.dropna(subset=['runtimeMinutes', 'genres', 'startYear'])

# %%
#keep only titleType==movie
basics = basics.loc[basics['titleType']=='movie']

# %%
#keep startYear 2000-2022
basics['startYear'] = basics['startYear'].astype(int)
basics = basics.loc[(basics['startYear'] >=2000) & (basics['startYear'] <=2022)]

# %%
#eliminate movies that include 'Documentary' in genre
is_documentary = basics['genres'].str.contains('documentary', case=False)
basics = basics[~is_documentary]

# %% [markdown]
# #### Ratings

# %%
#replace \n with np.nan for ratings data
ratings = ratings.replace({'\\N':np.nan})

#ensure it worked
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1934
# 1  tt0000002            5.8       262
# 2  tt0000003            6.5      1756
# 3  tt0000004            5.6       177
# 4  tt0000005            6.2      2566

# %% [markdown]
# #### Akas

# %%
#replace \n with np. nan for akas data
akas = akas.replace({'\\N':np.nan})

#ensure it worked
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
#for akas, keep only US entries
akas = akas.loc[akas['region']=='US']

# %%
#ensure data is correct
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 34466602  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 34466672  tt9916620         1                          The Copeland Case
# 34466760  tt9916702         1              Loving London: The Playground
# 34466803  tt9916756         1                   Pretty Pretty Black Girl
# 34466819  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 34466602     US      NaN  imdbDisplay                    NaN               0
# 34466672     US      NaN          NaN                    NaN               0
# 34466760     US      NaN          NaN                    NaN               0
# 34466803     US      NaN  imdbDisplay                    NaN               0
# 34466819     US      NaN  imdbDisplay                    NaN               0
#
# [1402479 rows x 8 columns]

# %% [markdown]
# #### Title Crew

# %%
#replace \n with np. nan for title crew data
crew = crew.replace({'\\N':np.nan})

#ensure it worked
crew.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690     NaN
# 1  tt0000002  nm0721526     NaN
# 2  tt0000003  nm0721526     NaN
# 3  tt0000004  nm0721526     NaN
# 4  tt0000005  nm0005690     NaN

# %% [markdown]
# #### Title Principals

# %%
#replace \n with np.nan for title principals data
principals = principals.replace({'\\N':np.nan})

#ensure it worked
principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                      NaN
# 1  tt0000001         2  nm0005690         director                      NaN
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                      NaN
# 4  tt0000002         2  nm1335271         composer                      NaN
#
#   characters
# 0   ["Self"]
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# #### Name Basics

# %%
#replace \n with np.nan for name basics data
name_basics = name_basics.replace({'\\N':np.nan})

#ensure it worked
name_basics.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934       NaN
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0053137,tt0045537,tt0072308
# 1  tt0117057,tt0038355,tt0037382,tt0071877
# 2  tt0056404,tt0054452,tt0049189,tt0057345
# 3  tt0078723,tt0072562,tt0077975,tt0080455
# 4  tt0060827,tt0083922,tt0050986,tt0050976

# %% [markdown]
# ### Filter Non-US Movies

# %%
#Use akas to filter what we want to keep in basics
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34803       True
# 61116       True
# 67669       True
# 77964      False
# 86801       True
#            ...
# 9509313     True
# 9509322     True
# 9509361    False
# 9509406     True
# 9509490    False
# Name: tconst, Length: 146005, dtype: bool

# %%
#filter basics and ensure it is correct
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9508777  tt9914942     movie
# 9509173  tt9915872     movie
# 9509313  tt9916170     movie
# 9509322  tt9916190     movie
# 9509406  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9508777                             Life Without Sara Amat
# 9509173                               The Last White Witch
# 9509313                                      The Rehearsal
# 9509322                                          Safeguard
# 9509406                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34803                               Kate & Leopold       0       2001     NaN
# 61116    El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67669                   The Other Side of the Wind       0       2018     NaN
# 86801                            The Naked Monster       0       2005     NaN
# 93938                         Crime and Punishment       0       2002     NaN
# ...                                            ...     ...        ...     ...
# 9508777                 La vida sense la Sara Amat       0       2019     NaN
# 9509173                  My Girlfriend is a Wizard       0       2019     NaN
# 9509313                                   O Ensaio       0       2019     NaN
# 9509322                                  Safeguard       0       2020     NaN
# 9509406                                   Akelarre       0       2020     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9508777             74                      Drama
# 9509173             97       Comedy,Drama,Fantasy
# 9509313             51                      Drama
# 9509322             95  Action,Adventure,Thriller
# 9509406             92              Drama,History
#
# [84508 rows x 9 columns]

# %%
#Use akas to filter what we want to keep in ratings
keepers = ratings['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1264211    False
# 1264212    False
# 1264213    False
# 1264214    False
# 1264215    False
# Name: tconst, Length: 1264216, dtype: bool

# %%
#filter ratings and ensure it is correct
ratings = ratings[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1934
# 1        tt0000002            5.8       262
# 4        tt0000005            6.2      2566
# 5        tt0000006            5.1       176
# 6        tt0000007            5.4       805
# ...            ...            ...       ...
# 1264190  tt9916200            8.2       220
# 1264191  tt9916204            8.2       251
# 1264197  tt9916348            8.5        17
# 1264198  tt9916362            6.4      5100
# 1264202  tt9916428            3.8        14
#
# [483420 rows x 3 columns]

# %%
#Use akas to filter what we want to keep in title crew
keepers = crew['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 9509635    False
# 9509636    False
# 9509637    False
# 9509638    False
# 9509639    False
# Name: tconst, Length: 9509640, dtype: bool

# %%
#filter title crew and ensure it is correct
crew = crew[keepers]
crew
# Out:
#             tconst            directors  \
# 0        tt0000001            nm0005690
# 1        tt0000002            nm0721526
# 4        tt0000005            nm0005690
# 5        tt0000006            nm0005690
# 6        tt0000007  nm0005690,nm0374658
# ...            ...                  ...
# 9509501  tt9916560            nm0232902
# 9509530  tt9916620                  NaN
# 9509568  tt9916702            nm3038589
# 9509591  tt9916756           nm10538639
# 9509595  tt9916764            nm6685122
#
#                                            writers
# 0                                              NaN
# 1                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# ...                                            ...
# 9509501                                  nm0103043
# 9509530                                  nm7311709
# 9509568                                 nm10538223
# 9509591                                 nm10538639
# 9509595  nm6687687,nm10538642,nm9641593,nm10538643
#
# [1318616 rows x 3 columns]

# %%
#Use akas to filter what we want to keep in title principals
keepers = principals['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#             ...
# 53995160    False
# 53995161    False
# 53995162    False
# 53995163    False
# 53995164    False
# Name: tconst, Length: 53995165, dtype: bool

# %%
#filter title principas and ensure it is correct
principals = principals[keepers]
principals
# Out:
#              tconst  ordering      nconst         category  \
# 0         tt0000001         1   nm1588970             self
# 1         tt0000001         2   nm0005690         director
# 2         tt0000001         3   nm0374658  cinematographer
# 3         tt0000002         1   nm0721526         director
# 4         tt0000002         2   nm1335271         composer
# ...             ...       ...         ...              ...
# 53994755  tt9916764         5   nm6685122         director
# 53994756  tt9916764         6   nm6687687           writer
# 53994757  tt9916764         7  nm10538642           writer
# 53994758  tt9916764         8   nm9641593           writer
# 53994759  tt9916764         9  nm10538643           writer
#
#                               job characters
# 0                             NaN   ["Self"]
# 1                             NaN        NaN
# 2         director of photography        NaN
# 3                             NaN        NaN
# 4                             NaN        NaN
# ...                           ...        ...
# 53994755                      NaN        NaN
# 53994756               written by        NaN
# 53994757               written by        NaN
# 53994758             developed by        NaN
# 53994759               written by        NaN
#
# [8465509 rows x 6 columns]

# %% [markdown]
# ## Creating a 'Data' folder and saving the files

# %%
#import os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['.DS_Store', '.ipynb_checkpoints']

# %%
#save current dataframe to file
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
crew.to_csv("Data/title_crew.csv.gz", compression = 'gzip', index = False)
principals.to_csv("Data/title_principals.csv.gz", compression = "gzip", index = False)
name_basics.to_csv("Data/name_basics.csv.gz", compression = 'gzip', index = False)

# %%
#open saved file and preview again
basics = pd.read_csv('Data/title_basics.csv.gz', low_memory=False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
#open saved file and preview again
akas = pd.read_csv('Data/title_akas.csv.gz', low_memory=False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
#open saved file and preview again
ratings = pd.read_csv('Data/title_ratings.csv.gz', low_memory=False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1934
# 1  tt0000002            5.8       262
# 2  tt0000005            6.2      2566
# 3  tt0000006            5.1       176
# 4  tt0000007            5.4       805

# %%
#open saved file and preview again
crew = pd.read_csv("Data/title_crew.csv.gz", low_memory = False)
crew.head()
# Out:
#       tconst            directors writers
# 0  tt0000001            nm0005690     NaN
# 1  tt0000002            nm0721526     NaN
# 2  tt0000005            nm0005690     NaN
# 3  tt0000006            nm0005690     NaN
# 4  tt0000007  nm0005690,nm0374658     NaN

# %%
principals = pd.read_csv("Data/title_principals.csv.gz", low_memory = False)
principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                      NaN
# 1  tt0000001         2  nm0005690         director                      NaN
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                      NaN
# 4  tt0000002         2  nm1335271         composer                      NaN
#
#   characters
# 0   ["Self"]
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
name_basics = pd.read_csv("Data/name_basics.csv.gz", low_memory = False)
name_basics.head()
# Out:
#       nconst      primaryName  birthYear  deathYear  \
# 0  nm0000001     Fred Astaire     1899.0     1987.0
# 1  nm0000002    Lauren Bacall     1924.0     2014.0
# 2  nm0000003  Brigitte Bardot     1934.0        NaN
# 3  nm0000004     John Belushi     1949.0     1982.0
# 4  nm0000005   Ingmar Bergman     1918.0     2007.0
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0053137,tt0045537,tt0072308
# 1  tt0117057,tt0038355,tt0037382,tt0071877
# 2  tt0056404,tt0054452,tt0049189,tt0057345
# 3  tt0078723,tt0072562,tt0077975,tt0080455
# 4  tt0060827,tt0083922,tt0050986,tt0050976
