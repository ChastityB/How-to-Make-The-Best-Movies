# %% [markdown]
# # How to Make The Best Movies Part 3

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy.types import *
from sqlalchemy_utils import create_database, database_exists

# %% [markdown]
# ## Normalize Genre:
#
# * convert the single string of genres from title basics into 2 new tables
#     * title genres: with the columns:
#         * tconst
#         * genre_id
#     * genres:
#         * genre_id
#         * genre_name

# %% [markdown]
# ### title_basics

# %%
#load file and disply rows
df_title_basics = pd.read_csv('Data/title_basics.csv.gz')
df_title_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0093119     movie                                Grizzly II: Revenge
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                   Grizzly II: The Predator        0       2020      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74   Horror,Music,Thriller

# %%
#create a col with a list of genres
df_title_basics['genres_split'] = df_title_basics['genres'].str.split(',')
df_title_basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0093119     movie                                Grizzly II: Revenge
# ...          ...       ...                                                ...
# 80718  tt9914942     movie                             Life Without Sara Amat
# 80719  tt9915872     movie                               The Last White Witch
# 80720  tt9916170     movie                                      The Rehearsal
# 80721  tt9916190     movie                                          Safeguard
# 80722  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                       Grizzly II: The Predator        0       2020      NaN
# ...                                          ...      ...        ...      ...
# 80718                 La vida sense la Sara Amat        0       2019      NaN
# 80719                  My Girlfriend is a Wizard        0       2019      NaN
# 80720                                   O Ensaio        0       2019      NaN
# 80721                                  Safeguard        0       2020      NaN
# 80722                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                  74      Horror,Music,Thriller
# ...               ...                        ...
# 80718              74                      Drama
# 80719              97       Comedy,Drama,Fantasy
# 80720              51                      Drama
# 80721              90  Action,Adventure,Thriller
# 80722              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4          [Horror, Music, Thriller]
# ...                              ...
# 80718                        [Drama]
# 80719       [Comedy, Drama, Fantasy]
# 80720                        [Drama]
# 80721  [Action, Adventure, Thriller]
# 80722               [Drama, History]
#
# [80723 rows x 10 columns]

# %%
#separate list of genres into new rows
exploded_genres = df_title_basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 80721  tt9916190     movie                                          Safeguard
# 80721  tt9916190     movie                                          Safeguard
# 80721  tt9916190     movie                                          Safeguard
# 80722  tt9916362     movie                                              Coven
# 80722  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 80721                                  Safeguard        0       2020      NaN
# 80721                                  Safeguard        0       2020      NaN
# 80721                                  Safeguard        0       2020      NaN
# 80722                                   Akelarre        0       2020      NaN
# 80722                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 80721              90  Action,Adventure,Thriller       Action
# 80721              90  Action,Adventure,Thriller    Adventure
# 80721              90  Action,Adventure,Thriller     Thriller
# 80722              92              Drama,History        Drama
# 80722              92              Drama,History      History
#
# [150642 rows x 10 columns]

# %%
#display unique genres
unique_genres = sorted(exploded_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
#save just tconst and genres_split as new df
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
#make a genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
#make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)
title_genres = title_genres.drop(columns='genres_split')
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0069049         7

# %%
#manually make dataframe with named cols from the .keyd and .values
genre_lookup = pd.DataFrame({'genre_name': genre_map.keys(),
                            'genre_id': genre_map.values()})
genre_lookup.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# ## Saving SQL Database

# %%
# Create connection string using credentials following this format
## Change username and password to match your personal MySQL Server settings
username = 'root' # default username for MySQL db is root
password = ''
database_name = "Movies"
connection_str = f'mysql+pymysql://{username}:{password}@localhost/Movies'
engine = create_engine(connection_str)

# %%
# Create Movies database, if it does not already exist
if database_exists(connection_str) == False: create_database(connection_str)
else: print('The database already exists.')
